# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from mlxtend.preprocessing import TransactionEncoder
from tabulate import tabulate
import seaborn as sns

import collections
import warnings

import numpy as np
import pandas as pd

warnings.simplefilter("always", DeprecationWarning)

import random
import time

from itertools import groupby
import itertools

import math

# %%
# local file path
df = pd.read_csv('./market_basket_dataset.csv', sep=';', dtype={'BillNo': str}, low_memory=False)

# drop column unnamed (for general purpose)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

df
# Out:
#     BillNo  Itemname  Quantity  Price  CustomerID
# 0     1000    Apples         5   8.30       52299
# 1     1000    Butter         4   6.06       11752
# 2     1000      Eggs         4   2.66       16415
# 3     1000  Potatoes         4   8.10       22889
# 4     1004   Oranges         2   7.26       52255
# ..     ...       ...       ...    ...         ...
# 495   1493     Juice         2   4.24       55321
# 496   1493     Bread         5   7.05       14479
# 497   1497    Coffee         3   2.01       25378
# 498   1497     Pasta         3   2.64       53334
# 499   1497      Eggs         4   7.37       34687
#
# [500 rows x 5 columns]

# %%
def drawLine(length=40):
    print("─" * length)

# %%
#pengecekan tipe data
drawLine()
print("📋 DATA TYPES")
drawLine()
print(df.dtypes.to_string())
drawLine()

# Menghitung jumlah itemname
jumlah_itemname = df['Itemname'].nunique()
print("\n📦  JUMLAH ITEMNAME")
drawLine()
print(f"Total unik: {jumlah_itemname:,}")
drawLine()

# Menghitung jumlah BillNo/transaksi
jumlah_billno = df['BillNo'].nunique()
print("\n🧾  JUMLAH BILLNO / TRANSAKSI")
drawLine()
print(f"Total unik: {jumlah_billno:,}")
drawLine()

# Menampilkan daftar BillNo/transaksi
billno_list = df['BillNo'].unique()
print("\n🧾  DAFTAR BILLNO")
drawLine()
cols = 20
rows = (len(billno_list) + cols - 1) // cols
for r in range(rows):
    line = []
    for c in range(cols):
        idx = r + c * rows
        if idx < len(billno_list):
            line.append(f"{idx + 1:>3}. {billno_list[idx]}")
        else:
            line.append(" " * 12)
    print("  ".join(line))
drawLine()
# Out:
# ────────────────────────────────────────
# 📋 DATA TYPES
# ────────────────────────────────────────
# BillNo         object
# Itemname       object
# Quantity        int64
# Price         float64
# CustomerID      int64
# ────────────────────────────────────────
#
# 📦  JUMLAH ITEMNAME
# ────────────────────────────────────────
# Total unik: 19
# ────────────────────────────────────────
#
# 🧾  JUMLAH BILLNO / TRANSAKSI
# ────────────────────────────────────────
# Total unik: 153
# ────────────────────────────────────────
#
# 🧾  DAFTAR BILLNO
# ────────────────────────────────────────
#   1. 1000    9. 1024   17. 1054   25. 1086   33. 1112   41. 1152   49. 1185   57. 1207   65. 1225   73. 1243   81. 1271   89. 1292   97. 1312  105. 1339  113. 1360  121. 1384  129. 1407  137. 1436  145. 1458  153. 1497
#   2. 1004   10. 1027   18. 1056   26. 1088   34. 1115   42. 1153   50. 1186   58. 1211   66. 1226   74. 1250   82. 1279   90. 1293   98. 1313  106. 1343  114. 1367  122. 1385  130. 1409  138. 1437  146. 1461
#   3. 1005   11. 1033   19. 1063   27. 1101   35. 1120   43. 1160   51. 1190   59. 1214   67. 1230   75. 1252   83. 1280   91. 1297   99. 1320  107. 1348  115. 1369  123. 1386  131. 1412  139. 1442  147. 1463
#   4. 1008   12. 1035   20. 1066   28. 1104   36. 1127   44. 1162   52. 1194   60. 1215   68. 1231   76. 1254   84. 1282   92. 1301  100. 1331  108. 1350  116. 1370  124. 1391  132. 1415  140. 1447  148. 1470
#   5. 1011   13. 1038   21. 1073   29. 1105   37. 1132   45. 1169   53. 1196   61. 1217   69. 1233   77. 1264   85. 1283   93. 1302  101. 1332  109. 1352  117. 1378  125. 1394  133. 1416  141. 1448  149. 1471
#   6. 1012   14. 1042   22. 1075   30. 1106   38. 1139   46. 1170   54. 1198   62. 1219   70. 1235   78. 1266   86. 1285   94. 1304  102. 1333  110. 1355  118. 1380  126. 1398  134. 1422  142. 1451  150. 1483
#   7. 1013   15. 1044   23. 1076   31. 1109   39. 1140   47. 1172   55. 1203   63. 1220   71. 1236   79. 1267   87. 1287   95. 1310  103. 1334  111. 1356  119. 1381  127. 1399  135. 1424  143. 1454  151. 1485
#   8. 1021   16. 1049   24. 1082   32. 1111   40. 1144   48. 1176   56. 1205   64. 1222   72. 1242   80. 1268   88. 1290   96. 1311  104. 1336  112. 1358  120. 1383  128. 1402  136. 1431  144. 1457  152. 1493
# ────────────────────────────────────────

# %%
# Pengecekan nilai kosong
drawLine()
print("🔍 Pengecekan Nilai Kosong (Missing Values)")
drawLine()
print(df.isnull().sum())

# Menampilkan Baris yang Mengandung Nilai Kosong (NaN)
print("\n")
drawLine()
print("⚠️  Baris yang Mengandung Nilai Kosong (NaN)")
drawLine()
print(df[df.isnull().any(axis=1)])
# Out:
# ────────────────────────────────────────
# 🔍 Pengecekan Nilai Kosong (Missing Values)
# ────────────────────────────────────────
# BillNo        0
# Itemname      0
# Quantity      0
# Price         0
# CustomerID    0
# dtype: int64
#
#
# ────────────────────────────────────────
# ⚠️  Baris yang Mengandung Nilai Kosong (NaN)
# ────────────────────────────────────────
# Empty DataFrame
# Columns: [BillNo, Itemname, Quantity, Price, CustomerID]
# Index: []

# %%
# Normalisasi nama barang ke huruf kecil
df['Itemname'] = df['Itemname'].str.lower()

# Mengelompokkan barang per transaksi (BillNo) 
transactions = df.groupby('BillNo')['Itemname'].apply(list).tolist()

# Tampilkan keranjang transaksi hasil pengelompokan
print("\n🛒  Keranjang Transaksi (setiap daftar = satu struk):\n")
# Build a clean table
table = [(f"T{idx:03d}", ", ".join(basket)) for idx, basket in enumerate(transactions, 1)]
print(tabulate(table, headers=["Transaksi", "Daftar Barang"], tablefmt="grid"))
# Out:
# 🛒  Keranjang Transaksi (setiap daftar = satu struk):
#
# +-------------+---------------------------------------------------------------------------------------------------+
# | Transaksi   | Daftar Barang                                                                                     |
# +=============+===================================================================================================+
# | T001        | apples, butter, eggs, potatoes                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T002        | oranges                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T003        | milk, onions, cereal                                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T004        | tomatoes, potatoes, cereal                                                                        |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T005        | bananas                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T006        | tomatoes                                                                                          |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T007        | pasta, onions, bread, bananas, coffee, sugar, potatoes, oranges                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T008        | bananas, oranges, potatoes                                                                        |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T009        | chicken, cereal, bananas                                                                          |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T010        | cheese, pasta, cereal, onions, bananas, chicken                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T011        | sugar, eggs                                                                                       |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T012        | onions, cereal, cheese                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T013        | cereal, coffee, bread, onions                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T014        | chicken, pasta                                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T015        | eggs, butter, bananas, chicken, tomatoes                                                          |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T016        | tea, bananas, pasta, eggs, cereal                                                                 |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T017        | sugar, coffee                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T018        | apples, tomatoes, chicken, pasta, bread, sugar, potatoes                                          |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T019        | yogurt, butter, bananas                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T020        | milk, eggs, sugar, juice, tomatoes, butter, onions                                                |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T021        | coffee, bananas                                                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T022        | onions                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T023        | coffee, tea, bananas, onions, juice, pasta                                                        |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T024        | tea, juice, cereal, butter                                                                        |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T025        | yogurt, juice                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T026        | pasta, onions, chicken, tea, juice, potatoes, sugar, coffee, milk, tomatoes, apples, yogurt, eggs |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T027        | pasta, bread, apples                                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T028        | butter                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T029        | apples                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T030        | tea, juice, butter                                                                                |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T031        | eggs, tomatoes                                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T032        | milk                                                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T033        | milk, bananas, oranges                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T034        | bananas, apples, yogurt, sugar, tomatoes                                                          |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T035        | bread, bananas, potatoes, tomatoes, onions, milk, oranges                                         |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T036        | milk, yogurt, oranges, coffee, bread                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T037        | juice, tomatoes, eggs, potatoes, bananas, milk, butter                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T038        | bananas                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T039        | onions, eggs, juice, cheese                                                                       |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T040        | cheese, oranges, tomatoes, yogurt, potatoes, juice, sugar, bananas                                |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T041        | eggs                                                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T042        | tea, yogurt, eggs, butter, oranges, bread, potatoes                                               |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T043        | cheese, sugar                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T044        | apples, tomatoes, milk, cheese, oranges, yogurt, tea                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T045        | cereal                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T046        | cheese, cereal                                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T047        | pasta, bananas, coffee, yogurt                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T048        | cereal, butter, chicken, juice, oranges, potatoes, tomatoes, coffee, bread                        |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T049        | cereal                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T050        | juice, tea, coffee, pasta                                                                         |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T051        | onions, cheese, tea, apples                                                                       |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T052        | oranges, tea                                                                                      |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T053        | cereal, onions                                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T054        | juice, cheese, tea, cereal, yogurt                                                                |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T055        | bananas, yogurt                                                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T056        | bananas, sugar                                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T057        | tomatoes, chicken, butter, potatoes                                                               |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T058        | tea, milk, oranges                                                                                |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T059        | apples                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T060        | tomatoes, sugar                                                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T061        | tomatoes, cheese                                                                                  |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T062        | oranges                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T063        | tea, yogurt                                                                                       |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T064        | yogurt, oranges, coffee                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T065        | yogurt                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T066        | juice, potatoes, coffee, tea                                                                      |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T067        | bananas                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T068        | sugar, coffee                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T069        | butter, tea                                                                                       |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T070        | butter                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T071        | tomatoes, apples, bread, cheese, sugar, onions                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T072        | potatoes                                                                                          |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T073        | cheese, bananas, butter, cereal, potatoes, tea, bread                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T074        | milk, oranges                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T075        | cereal, bananas                                                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T076        | onions, cheese, apples, eggs, milk, potatoes, cereal, pasta, oranges, chicken                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T077        | bread, cheese                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T078        | sugar                                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T079        | milk                                                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T080        | tomatoes, cereal, chicken                                                                         |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T081        | coffee, cheese, juice, tea, eggs, potatoes, butter, bananas                                       |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T082        | eggs                                                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T083        | cheese, bananas                                                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T084        | juice                                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T085        | eggs, tomatoes                                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T086        | apples, potatoes                                                                                  |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T087        | cheese, bananas, sugar                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T088        | coffee, bread                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T089        | apples                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T090        | bananas, apples, milk, sugar                                                                      |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T091        | coffee, cereal, cheese, oranges                                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T092        | cheese                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T093        | oranges, milk                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T094        | onions, potatoes, coffee, cereal, tea, bread                                                      |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T095        | pasta                                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T096        | eggs                                                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T097        | coffee                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T098        | yogurt, coffee, butter, eggs, onions, cereal, cheese                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T099        | butter, apples, cheese, tea, bread, cereal, pasta, coffee, sugar, yogurt, milk                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T100        | chicken                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T101        | juice                                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T102        | pasta                                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T103        | oranges, cheese                                                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T104        | coffee, tomatoes, bread                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T105        | cereal, cheese, tomatoes, oranges                                                                 |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T106        | milk, tomatoes, cereal, apples, butter                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T107        | onions, yogurt                                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T108        | milk, pasta                                                                                       |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T109        | onions, tea, sugar                                                                                |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T110        | cheese                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T111        | juice, coffee                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T112        | onions, chicken                                                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T113        | potatoes, apples, sugar, bread, yogurt, juice, coffee                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T114        | apples, coffee                                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T115        | butter                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T116        | bread, oranges, cheese, butter, tea, bananas, milk, onions                                        |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T117        | coffee, eggs                                                                                      |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T118        | bananas                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T119        | juice, eggs                                                                                       |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T120        | sugar                                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T121        | coffee                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T122        | apples                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T123        | tea, apples, chicken, pasta, sugar                                                                |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T124        | yogurt, apples, sugar                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T125        | pasta, coffee, bread, milk                                                                        |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T126        | yogurt                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T127        | yogurt, chicken, oranges                                                                          |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T128        | bread, butter, oranges, apples, chicken                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T129        | eggs, cereal                                                                                      |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T130        | sugar, tea, coffee                                                                                |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T131        | potatoes, eggs, cereal                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T132        | pasta                                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T133        | pasta, butter, chicken, potatoes, bananas, tomatoes                                               |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T134        | eggs, apples                                                                                      |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T135        | milk, tomatoes, cheese, onions, sugar, coffee, cereal                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T136        | yogurt, sugar, tomatoes, eggs, bananas                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T137        | eggs                                                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T138        | tomatoes, eggs, cereal, pasta, bananas                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T139        | bananas, cereal, onions, chicken, potatoes                                                        |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T140        | bananas                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T141        | cereal, bananas, juice                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T142        | milk, oranges, butter                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T143        | apples, bread, yogurt                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T144        | oranges                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T145        | sugar, potatoes, pasta                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T146        | oranges, potatoes                                                                                 |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T147        | yogurt, oranges, cheese, apples, milk, potatoes, coffee                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T148        | yogurt                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T149        | butter, bread, cereal, cheese, bananas, yogurt, pasta, chicken, juice, eggs, oranges, coffee      |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T150        | tomatoes, coffee                                                                                  |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T151        | bread, juice, bananas, chicken, butter, oranges, milk, potatoes                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T152        | chicken, bananas, juice, bread                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T153        | coffee, pasta, eggs                                                                               |
# +-------------+---------------------------------------------------------------------------------------------------+

# %% [markdown]
# # Tabu Search Preprocessing

# %%
# ... existing code ...
# Fungsi Tabu Search (jalankan di sel baru sebelum FP-Growth)
def tabu_search(transactions, max_iter=15, tabu_size=5, k=5, threshold=0.5):
    """
    Tabu Search untuk memilih k item fokus dari transaksi dan mem-filter
    transaksi sebelum FP-Growth.

    Args:
        transactions (List[List[str]]): daftar transaksi (list item per struk)
        max_iter (int): jumlah iterasi maksimal
        tabu_size (int): ukuran tabu list (tenure)
        k (int): jumlah item fokus yang dipilih
        threshold (float): minimum support relatif (0..1) untuk kandidat item

    Returns:
        dict: {
          'selected_items': List[str],
          'filtered_transactions': List[List[str]],
          'score': float
        }
    """
    from collections import Counter, deque
    from itertools import combinations

    n = len(transactions)
    if n == 0:
        return {'selected_items': [], 'filtered_transactions': [], 'score': 0.0}

    # Gunakan set per transaksi untuk menghitung presence dengan benar
    trx_sets = [set(t) for t in transactions]

    # Support single items (presence-based)
    item_counts = Counter()
    for s in trx_sets:
        item_counts.update(s)
    item_support = {it: item_counts[it] / n for it in item_counts}

    # Support pasangan (co-occurrence presence-based)
    pair_counts = Counter()
    for s in trx_sets:
        for a, b in combinations(sorted(s), 2):
            pair_counts[(a, b)] += 1
    pair_support = {p: pair_counts[p] / n for p in pair_counts}

    # Kandidat awal berdasar threshold; fallback jika kosong
    universe = [it for it, sup in item_support.items() if sup >= threshold]
    if not universe:
        universe = [it for it, _ in item_counts.most_common()]

    # Inisialisasi solusi dengan top-k by support
    init = [it for it, _ in sorted(((it, item_support[it]) for it in universe),
                                   key=lambda x: (-x[1], x[0]))][:k]
    S = set(init)

    # Objective: gabungan support rata-rata dan ko-occurrence internal
    def score_set(Sset):
        if not Sset:
            return 0.0
        Slist = sorted(Sset)
        s1 = sum(item_support.get(it, 0.0) for it in Slist) / len(Slist)
        if len(Slist) >= 2:
            pairs = list(combinations(Slist, 2))
            s2 = sum(pair_support.get(tuple(sorted(p)), 0.0) for p in pairs)
            s2 = s2 / len(pairs)
        else:
            s2 = 0.0
        # Bobot (bisa di-tune)
        return 0.6 * s1 + 0.4 * s2

    best_S = set(S)
    best_score = score_set(best_S)

    tabu = deque(maxlen=tabu_size)

    for _ in range(max_iter):
        current_best_neighbor = None
        current_best_move = None
        current_best_score = -1.0

        # Generate neighbors: add/remove/swap
        # ADD
        if len(S) < k:
            for x in universe:
                if x in S:
                    continue
                move_token = ("add", x)
                cand = set(S)
                cand.add(x)
                sc = score_set(cand)
                if move_token in tabu and sc <= best_score:
                    continue  # tabu, tidak memenuhi aspiration
                if sc > current_best_score:
                    current_best_score = sc
                    current_best_neighbor = cand
                    current_best_move = move_token

        # REMOVE
        for i in list(S):
            move_token = ("remove", i)
            cand = set(S)
            cand.remove(i)
            sc = score_set(cand)
            if move_token in tabu and sc <= best_score:
                continue
            if sc > current_best_score:
                current_best_score = sc
                current_best_neighbor = cand
                current_best_move = move_token

        # SWAP
        for i in list(S):
            for x in universe:
                if x in S:
                    continue
                move_token = ("swap", i, x)
                cand = set(S)
                cand.remove(i)
                if len(cand) < k:
                    cand.add(x)
                sc = score_set(cand)
                if move_token in tabu and sc <= best_score:
                    continue
                if sc > current_best_score:
                    current_best_score = sc
                    current_best_neighbor = cand
                    current_best_move = move_token

        # Jika tak ada neighbor valid, berhenti
        if current_best_neighbor is None:
            break

        # Apply move
        S = current_best_neighbor
        tabu.append(current_best_move)

        # Update best (global)
        if current_best_score > best_score:
            best_S = set(S)
            best_score = current_best_score

    # Filter transaksi ke item terpilih
    selected_items = sorted(best_S)
    filtered = []
    for t in transactions:
        ft = [it for it in t if it in best_S]
        if ft:
            filtered.append(ft)

    return {
        'selected_items': selected_items,
        'filtered_transactions': filtered,
        'score': best_score
    }
# ... existing code ...

# %%
# ... existing code ...
# Normalisasi nama barang ke huruf kecil
df['Itemname'] = df['Itemname'].str.lower()

# Mengelompokkan barang per transaksi (BillNo) 
transactions = df.groupby('BillNo')['Itemname'].apply(list).tolist()

# Jalankan Tabu Search sebelum FP-Growth
tabu_out = tabu_search(transactions, max_iter=15, tabu_size=5, k=5, threshold=0.5)
transactions_tabu = tabu_out['filtered_transactions']
selected_items = tabu_out['selected_items']
print("\n🔧 Tabu Search: item terpilih →", ", ".join(selected_items))
print(f"Total transaksi setelah filter: {len(transactions_tabu)} dari {len(transactions)}")
# ... existing code ...
# Out:
# 🔧 Tabu Search: item terpilih → bananas, cereal
# Total transaksi setelah filter: 59 dari 153

# %%
# Encode transaksi ke format biner
te = TransactionEncoder()
te_ary = te.fit(transactions_tabu).transform(transactions_tabu)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# Tampilan hasil data encoding
drawLine()
print("TRANSACTION ENCODER RESULTS - BINARY FORMAT")
drawLine()
print(f"Dataset Shape: {df_encoded.shape[0]} transaksi × {df_encoded.shape[1]} item")
print("\n10 Data Pertama:")
drawLine()

print(tabulate(df_encoded.head(10), headers='keys', tablefmt='grid', showindex=True)) # 1 = True, 0 = False
# Out:
# ────────────────────────────────────────
# TRANSACTION ENCODER RESULTS - BINARY FORMAT
# ────────────────────────────────────────
# Dataset Shape: 59 transaksi × 2 item
#
# 10 Data Pertama:
# ────────────────────────────────────────
# +----+-----------+----------+
# |    |   bananas |   cereal |
# +====+===========+==========+
# |  0 |         0 |        1 |
# +----+-----------+----------+
# |  1 |         0 |        1 |
# +----+-----------+----------+
# |  2 |         1 |        0 |
# +----+-----------+----------+
# |  3 |         1 |        0 |
# +----+-----------+----------+
# |  4 |         1 |        0 |
# +----+-----------+----------+
# |  5 |         1 |        1 |
# +----+-----------+----------+
# |  6 |         1 |        1 |
# +----+-----------+----------+
# |  7 |         0 |        1 |
# +----+-----------+----------+
# |  8 |         0 |        1 |
# +----+-----------+----------+
# |  9 |         1 |        0 |
# +----+-----------+----------+

# %% [markdown]
# ## Manual Algorithm FP Growth

# %% [markdown]
# ### Configure FP Common Algorithm

# %%
def setup_fptree(df, min_support):
    """
    Membangun struktur FP-Tree dari DataFrame transaksi.
    
    Langkah-langkah:
    1. Hitung jumlah transaksi (baris).
    2. Deteksi apakah DataFrame dalam format sparse.
    3. Buat matriks 'disabled' untuk menandai nilai yang hilang (NaN) atau tidak valid.
    4. Hitung support relatif setiap item dengan mengabaikan baris yang disabled.
    5. Filter item yang memenuhi min_support.
    6. Urutkan item berdasarkan support (descending) untuk pembangunan tree.
    7. Bangun FP-Tree dengan memasukkan setiap transaksi yang sudah difilter dan diurutkan.
    
    Returns:
        tree: objek FPTree yang sudah terisi
        disabled: ndarray penanda baris/item yang tidak valid
        rank: dict pemetaan item ke urutan prioritas
    """
    num_itemsets = len(df.index)

    # Deteksi format sparse
    is_sparse = False
    if hasattr(df, "sparse"):
        if df.size == 0:
            itemsets = df.values
        else:
            itemsets = df.sparse.to_coo().tocsr()
            is_sparse = True
    else:
        itemsets = df.values

    # Buat masker untuk nilai yang hilang / tidak valid
    disabled = df.copy()
    disabled = np.where(pd.isna(disabled), 1, np.nan) + np.where(
        (disabled == 0) | (disabled == 1), np.nan, 0
    )

    # Hitung support tiap item dengan mengabaikan baris disabled
    item_support = np.array(
        np.nansum(df.values, axis=0)
        / (float(num_itemsets) - np.nansum(disabled, axis=0))
    )
    item_support = item_support.reshape(-1)
    items = np.nonzero(item_support >= min_support)[0]

    # Urutkan item berdasarkan support (descending)
    indices = item_support[items].argsort()
    rank = {item: i for i, item in enumerate(items[indices])}

    # Hapus nilai nol pada sparse matrix untuk efisiensi
    if is_sparse:
        itemsets.eliminate_zeros()

    # Bangun FP-Tree
    tree = FPTree(rank)
    for i in range(num_itemsets):
        if is_sparse:
            nonnull = itemsets.indices[itemsets.indptr[i] : itemsets.indptr[i + 1]]
        else:
            nonnull = np.where(itemsets[i, :])[0]
        # Filter item yang memenuhi min_support lalu urutkan sesuai rank
        itemset = [item for item in nonnull if item in rank]
        itemset.sort(key=rank.get, reverse=True)
        tree.insert_ordered_itemset(itemset)

    return tree, disabled, rank


def generate_itemsets_with_supports(generator, df, disabled, min_support, num_itemsets, colname_map):
    """
    Menghasilkan daftar itemset beserta nilai support-nya dari generator pola yang ditemukan.
    
    Langkah-langkah:
    1. Iterasi setiap (support, itemset) dari generator.
    2. Hitung support yang sudah dikoreksi dengan mengabaikan baris disabled.
       - Untuk itemset tunggal: langsung kurangi jumlah disabled.
       - Untuk itemset >1: periksa tiap baris, hitung penyebut (baris yang valid) dan pembilang (itemset yang valid).
    3. Filter hasil akhir yang memenuhi min_support.
    4. (Opsional) ubah nama kolom sesuai pemetaan yang diberikan.
    
    Returns:
        DataFrame dengan kolom 'support' dan 'itemsets'
    """
    itemsets = []
    supports = []
    for sup, iset in generator:
        itemsets.append(frozenset(iset))
        dec = disabled[:, iset]
        _dec = df.values[:, iset]

        if len(iset) == 1:
            supports.append((sup - np.nansum(dec)) / (num_itemsets - np.nansum(dec)))

        elif len(iset) > 1:
            denom = 0
            num = 0
            for i in range(dec.shape[0]):
                item_dsbl = list(dec[i, :])
                item_orig = list(_dec[i, :])

                if 1 in set(item_dsbl):
                    denom += 1

                    if (0 not in set(item_orig)) or (
                        all(np.isnan(x) for x in item_orig)
                    ):
                        num -= 1

            if num_itemsets - denom == 0:
                supports.append(0)
            else:
                supports.append((sup + num) / (num_itemsets - denom))

    res_df = pd.DataFrame({"support": supports, "itemsets": itemsets})
    res_df = res_df[res_df["support"] >= min_support]

    if colname_map is not None:
        res_df["itemsets"] = res_df["itemsets"].apply(
            lambda x: frozenset([colname_map[i] for i in x])
        )

    return res_df


def check_valid_input(df, null_values=False):
    """
    Validasi keabsahan DataFrame input.
    
    Langkah-langkah:
    1. Lewati jika df None.
    2. Tolak SparseDataFrame yang sudah deprecated.
    3. Untuk sparse matrix, pastikan nama kolom string atau dimulai 0.
    4. Periksa tipe data: semua kolom harus boolean (atau boleh NaN bila null_values=True).
    5. Beri peringatan jika ada tipe non-bool.
    6. Pastikan nilai hanya 0, 1, True, False, (dan NaN bila null_values=True).
    
    Raises:
        TypeError, ValueError bila input tidak valid.
    """
    if df is None:
        return

    # Blokir SparseDataFrame deprecated
    if f"{type(df)}" == "<class 'pandas.core.frame.SparseDataFrame'>":
        msg = (
            "SparseDataFrame sudah kedaluwarsa. Gunakan DataFrame biasa dengan kolom sparse."
        )
        raise TypeError(msg)

    if df.size == 0:
        return
    if hasattr(df, "sparse"):
        if not isinstance(df.columns[0], str) and df.columns[0] != 0:
            raise ValueError(
                "Pembatasan Pandas: nama kolom bertipe int harus diawali 0 atau ubah jadi string: "
                "`df.columns = [str(i) for i in df.columns]`."
            )

    # Cek tipe data: semua boolean (ataboleh NaN bila null_values=True)
    if null_values:
        all_bools = (
            df.apply(lambda col: col.apply(lambda x: pd.isna(x) or isinstance(x, bool)))
            .all()
            .all()
        )
    else:
        all_bools = df.dtypes.apply(pd.api.types.is_bool_dtype).all()

    if not all_bools:
        warnings.warn(
            "Tipe data non-bool memperlambat komputasi. "
            "Gunakan DataFrame bertipe bool.",
            DeprecationWarning,
        )

        has_nans = pd.isna(df).any().any()
        if null_values and not has_nans:
            warnings.warn(
                "null_values=True lambat bila tak ada NaN. Gunakan False."
            )
        if not null_values and has_nans:
            raise ValueError(
                "NaN values are not permitted"
            )

        # Ambil nilai aktual untuk dicek
        if hasattr(df, "sparse"):
            if df.size == 0:
                values = df.values
            else:
                values = df.sparse.to_coo().tocoo().data
        else:
            values = df.values

        if null_values:
            idxs = np.where((values != 1) & (values != 0) & (~np.isnan(values)))
        else:
            idxs = np.where((values != 1) & (values != 0))

        if len(idxs[0]) > 0:
            val = values[tuple(loc[0] for loc in idxs)]
            s = (
                "The allowed values for a DataFrame"
                " are True, False, 0, 1. Found value %s" % (val)
            )

            if null_values:
                s = (
                    "The allowed values for a DataFrame"
                    " are True, False, 0, 1, NaN. Found value %s" % (val)
                )
            raise ValueError(s)


class FPTree(object):
    """
    Struktur data FP-Tree untuk menyimpan transaksi dalam bentuk pohon.
    Setiap node merepresentasikan item dengan count tertentu.
    """
    def __init__(self, rank=None):
        # Root node virtual (item=None)
        self.root = FPNode(None)
        # Dictionary menampung daftar node per item
        self.nodes = collections.defaultdict(list)
        # Item kondisi untuk conditional tree
        self.cond_items = []
        # Urutan prioritas item (support descending)
        self.rank = rank

    def conditional_tree(self, cond_item, minsup):
        """
        Bangun conditional FP-Tree untuk item tertentu.
        
        Langkah-langkah:
        1. Kumpulkan semua path dari root ke node cond_item.
        2. Hitung count tiap item pada path-path tersebut.
        3. Filter item yang memenuhi minsup.
        4. Bangun conditional tree baru dengan item yang sudah difilter & diurutkan.
        
        Returns:
            FPTree baru yang dikondisikan pada cond_item
        """
        branches = []
        count = collections.defaultdict(int)
        for node in self.nodes[cond_item]:
            branch = node.get_item_path_from_root()
            branches.append(branch)
            for item in branch:
                count[item] += node.count

        # Item yang memenuhi minsup, diurutkan ascending (untuk kemudahan)
        items = [item for item in count if count[item] >= minsup]
        items.sort(key=count.get)
        rank = {item: i for i, item in enumerate(items)}

        # Bangun conditional tree
        cond_tree = FPTree(rank)
        for idx, branch in enumerate(branches):
            branch = sorted(
                [i for i in branch if i in rank], key=rank.get, reverse=True
            )
            cond_tree.insert_ordered_itemset(branch, self.nodes[cond_item][idx].count)
        cond_tree.cond_items = self.cond_items + [cond_item]

        return cond_tree

    def insert_ordered_itemset(self, itemset, count=1):
        """
        Masukkan itemset (urutan menurun support) ke dalam tree.
        
        Langkah-langkah:
        1. Naikkan count root.
        2. Untuk setiap item, jika child sudah ada naikkan count, jika tidak buat node baru.
        3. Simpan node pada dictionary nodes untuk akses cepat.
        """
        self.root.count += count

        if len(itemset) == 0:
            return

        index = 0
        node = self.root
        for item in itemset:
            if item in node.children:
                child = node.children[item]
                child.count += count
                node = child
                index += 1
            else:
                break

        # Sisanya buat cabang baru
        for item in itemset[index:]:
            child_node = FPNode(item, count, node)
            self.nodes[item].append(child_node)
            node = child_node

    def is_single_path(self):
        """
        Cek apakah tree hanya berisi satu path lurus (untuk optimasi mining).
        
        Returns:
            bool: True bila tree hanya satu jalur dari root ke leaf
        """
        if len(self.root.children) > 1:
            return False
        for i in self.nodes:
            if len(self.nodes[i]) > 1 or len(self.nodes[i][0].children) > 1:
                return False
        return True

    def print_status(self, count, colnames):
        """
        Cetak status proses mining untuk debugging.
        
        Args:
            count: jumlah itemset yang sudah ditemukan
            colnames: dict pemetaan index ke nama kolom
        """
        cond_items = [str(i) for i in self.cond_items]
        if colnames:
            cond_items = [str(colnames[i]) for i in self.cond_items]
        cond_items = ", ".join(cond_items)
        print(
            "\r%d itemset dari tree yang dikondisikan pada item (%s)" % (count, cond_items),
            end="\n",
        )


class FPNode(object):
    """
    Node individual di dalam FP-Tree.
    """
    def __init__(self, item, count=0, parent=None):
        self.item = item          # Nama item (None untuk root)
        self.count = count        # Jumlah transaksi yang melewati node ini
        self.parent = parent      # Node induk
        self.children = collections.defaultdict(FPNode)  # Child nodes

        if parent is not None:
            parent.children[item] = self

    def get_item_path_from_root(self):
        """
        Ambil path item dari root (tidak termasuk node ini) dalam urutan root -> ... -> parent.
        
        Returns:
            list: item-item pada jalur, sudah diurutkan dari root
        """
        path = []
        if self.item is None:
            return path

        node = self.parent
        while node.item is not None:
            path.append(node.item)
            node = node.parent

        path.reverse()
        return path

# %% [markdown]
# ### Configure FP Growth Algorithm

# %%
def fpgrowth(
    df, min_support=0.5, null_values=False, use_colnames=False, max_len=None, verbose=0
):
    # Langkah 1: Validasi DataFrame masukan dan flag penanganan nilai null
    check_valid_input(df, null_values)

    # Langkah 2: Pastikan min_support berada dalam rentang yang valid (0, 1]
    if min_support <= 0.0:
        raise ValueError(
            "`min_support` harus angka positif "
            "dalam interval `(0, 1]`. "
            "Didapat %s." % min_support
        )

    # Langkah 3: Bangun pemetaan nama kolom jika pengguna ingin menyimpan nama kolom asli
    colname_map = None
    if use_colnames:
        colname_map = {idx: item for idx, item in enumerate(df.columns)}

    # Langkah 4: Bangun FP-tree dan identifikasi item yang dinonaktifkan (di bawah min_support)
    tree, disabled, _ = setup_fptree(df, min_support)

    # Langkah 5: Ubah min_support relatif menjadi hitungan absolut
    minsup = math.ceil(min_support * len(df.index))

    # Langkah 6: Buat generator yang secara malas menghasilkan itemset yang sering
    generator = fpg_step(tree, minsup, colname_map, max_len, verbose)

    # Langkah 7: Pasca-proses generator untuk melampirkan nilai support dan kembalikan hasil akhir
    return generate_itemsets_with_supports(
        generator, df, disabled, min_support, len(df.index), colname_map
    )


def fpg_step(tree, minsup, colnames, max_len, verbose):
    # Langkah 1: Inisialisasi penghitung untuk itemset yang dihasilkan dan ambil item tree saat ini
    count = 0
    items = tree.nodes.keys()

    # Langkah 2: Tangani kasus khusus ketika FP-tree berupa jalur tunggal
    if tree.is_single_path():
        # Tentukan ukuran kombinasi maksimal dengan memperhatikan batasan max_len
        size_remain = len(items) + 1
        if max_len:
            size_remain = max_len - len(tree.cond_items) + 1
        # Hasilkan semua kombinasi non-kosong dari item pada jalur
        for i in range(1, size_remain):
            for itemset in itertools.combinations(items, i):
                count += 1
                # Kombinasi adalah hitungan minimum dari item-itemnya
                support = min([tree.nodes[i][0].count for i in itemset])
                yield support, tree.cond_items + list(itemset)

    # Langkah 3: Jika tree bukan jalur tunggal, hasilkan setiap perluasan item
    elif not max_len or max_len > len(tree.cond_items):
        for item in items:
            count += 1
            # Agregasikan support untuk item di semua nodenya
            support = sum([node.count for node in tree.nodes[item]])
            yield support, tree.cond_items + [item]

    # Langkah 4: print
    if verbose:
        tree.print_status(count, colnames)

    # Langkah 5: Secara rekursif jalankan FP-tree bersyarat untuk setiap item
    if not tree.is_single_path() and (not max_len or max_len > len(tree.cond_items)):
        for item in items:
            # Bangun FP-tree bersyarat untuk item saat ini
            cond_tree = tree.conditional_tree(item, minsup)
            # Secara rekursif hasilkan itemset yang sering dari tree bersyarat
            for sup, iset in fpg_step(cond_tree, minsup, colnames, max_len, verbose):
                yield sup, iset

# %% [markdown]
# ### Implementation FP Growth

# %%
# Hitung frequent itemsets dengan nilai support
frequent_itemsets = fpgrowth(df_encoded, min_support=0.001, use_colnames=True)
print("\nHasil Frequent Itemset dengan nilai support: \n\n", frequent_itemsets)

frequent_itemsets_sorted = frequent_itemsets.sort_values(by='support', ascending=False).head(20)
# Grafik Horizontal
plt.figure(figsize=(10, 8))
sns.barplot(x='support', y='itemsets', data=frequent_itemsets_sorted, palette='viridis')
plt.title('20 Itemset Frekuen Teratas Berdasarkan Support', fontsize=16, fontweight='bold')
plt.xlabel('Support', fontsize=12)
plt.ylabel('Itemsets', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Hasil Frequent Itemset dengan nilai support:
#
#      support           itemsets
# 0  0.525424           (cereal)
# 1  0.627119          (bananas)
# 2  0.152542  (bananas, cereal)
# /var/folders/qk/p1xn12n13qb82ww1m9ffhlkm0000gn/T/ipykernel_73188/1440687802.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='support', y='itemsets', data=frequent_itemsets_sorted, palette='viridis')

# %%
# mengurutkan berdasarkan prioritas 1-itemset
single_items = frequent_itemsets[frequent_itemsets['itemsets'].apply(lambda x: len(x) == 1)]

single_items_sorted = single_items.sort_values(by='support', ascending=False)

# Menampilkan grafik batang dengan keterangan
import matplotlib.pyplot as plt

labels = [list(item)[0] for item in single_items_sorted['itemsets']]
supports = single_items_sorted['support'].values

plt.figure(figsize=(10, 6))
bars = plt.bar(labels, supports, color='skyblue')

# Keterangan
plt.xlabel('Item')
plt.ylabel('Support')
plt.title('Support untuk 1-Itemset')
plt.xticks(rotation=45, ha='right')

for bar, sup in zip(bars, supports):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.001,
             f'{sup:.3f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## CBP (Conditional Pattern Base)

# %%
# Tujuan: Membangun Conditional Pattern Base (CPB) untuk setiap 1-itemset
#          – himpunan jalur prefiks yang muncul bersama item tertentu.
#          CPB ini menjadi masukan untuk menambang pola frekuensi dengan FP-Growth.
from collections import defaultdict

# 1: Hitung frekuensi global setiap item
item_counts = defaultdict(int)
for transaction in transactions:
    for item in transaction:
        item_counts[item] += 1

# 2: Hapus item di bawah ambang minimum support
min_support = 0.01 * len(transactions)
item_counts = {item: count for item, count in item_counts.items() if count >= min_support}

# 3: Urutkan item yang tersisa secara menurun berdasarkan frekuensi
def sort_items(transaction):
    return sorted([item for item in transaction if item in item_counts],
                  key=lambda item: (-item_counts[item], item))

sorted_transactions = [sort_items(t) for t in transactions]

# 4: Bangun FP-Tree
class FPNode:
    def __init__(self, item, count=1):
        self.item = item
        self.count = count
        self.children = {}
        self.parent = None

class FPTree:
    def __init__(self):
        self.root = FPNode(None)
        self.headers = defaultdict(list)

    def insert(self, transaction):
        current = self.root
        for item in transaction:
            if item in current.children:
                current.children[item].count += 1
            else:
                new_node = FPNode(item)
                new_node.parent = current
                current.children[item] = new_node
                self.headers[item].append(new_node)
            current = current.children[item]

    def conditional_pattern_base(self, item):
        patterns = []
        for node in self.headers[item]:
            path = []
            current = node.parent
            while current and current.item is not None:
                path.append(current.item)
                current = current.parent
            if path:
                patterns.append((list(reversed(path)), node.count))
        return patterns

# 5: Isi FP-Tree dengan transaksi yang sudah diurutkan
tree = FPTree()
for transaction in sorted_transactions:
    tree.insert(transaction)

# 6: Tampilkan Conditional Pattern Base untuk setiap 1-itemset yang frekuen
print("\nConditional Pattern Base untuk semua item:")
for item in item_counts.keys():
    cpb = tree.conditional_pattern_base(item)
    print(f"\nItem: {item}")
    if cpb:
        for pattern, count in cpb:
            print(f"  Jalur: {pattern}, Hitungan: {count}")
    else:
        print("  (Tidak ada pola)")
# Out:
# Conditional Pattern Base untuk semua item:
#
# Item: apples
#   Jalur: ['eggs', 'potatoes'], Hitungan: 1
#   Jalur: ['potatoes', 'tomatoes', 'sugar'], Hitungan: 1
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes', 'sugar', 'yogurt'], Hitungan: 1
#   Jalur: ['bananas', 'tomatoes', 'sugar', 'yogurt'], Hitungan: 1
#   Jalur: ['oranges', 'cheese', 'tomatoes', 'yogurt'], Hitungan: 1
#   Jalur: ['cheese'], Hitungan: 1
#   Jalur: ['cheese', 'tomatoes', 'sugar'], Hitungan: 1
#   Jalur: ['cereal', 'oranges', 'cheese', 'eggs', 'potatoes'], Hitungan: 1
#   Jalur: ['potatoes'], Hitungan: 1
#   Jalur: ['bananas', 'sugar'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'sugar', 'yogurt'], Hitungan: 1
#   Jalur: ['cereal', 'tomatoes'], Hitungan: 1
#   Jalur: ['coffee', 'potatoes', 'sugar', 'yogurt'], Hitungan: 1
#   Jalur: ['coffee'], Hitungan: 1
#   Jalur: ['sugar'], Hitungan: 1
#   Jalur: ['sugar', 'yogurt'], Hitungan: 1
#   Jalur: ['oranges'], Hitungan: 1
#   Jalur: ['eggs'], Hitungan: 1
#   Jalur: ['yogurt'], Hitungan: 1
#   Jalur: ['coffee', 'oranges', 'cheese', 'potatoes', 'yogurt'], Hitungan: 1
#
# Item: butter
#   Jalur: ['eggs', 'potatoes', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'eggs', 'tomatoes'], Hitungan: 1
#   Jalur: ['bananas', 'yogurt'], Hitungan: 1
#   Jalur: ['eggs', 'tomatoes', 'sugar'], Hitungan: 1
#   Jalur: ['cereal'], Hitungan: 1
#   Jalur: ['bananas', 'eggs', 'potatoes', 'tomatoes'], Hitungan: 1
#   Jalur: ['oranges', 'eggs', 'potatoes', 'yogurt'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'oranges', 'potatoes', 'tomatoes'], Hitungan: 1
#   Jalur: ['potatoes', 'tomatoes'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'cheese', 'potatoes'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cheese', 'eggs', 'potatoes'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'eggs', 'yogurt'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'sugar', 'yogurt', 'apples'], Hitungan: 1
#   Jalur: ['cereal', 'tomatoes', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese'], Hitungan: 1
#   Jalur: ['oranges', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'potatoes', 'tomatoes'], Hitungan: 1
#   Jalur: ['oranges'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cereal', 'oranges', 'cheese', 'eggs', 'yogurt'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes'], Hitungan: 1
#
# Item: eggs
#   Jalur: ['bananas'], Hitungan: 3
#   Jalur: ['bananas', 'cereal'], Hitungan: 2
#   Jalur: ['coffee'], Hitungan: 3
#   Jalur: ['cheese'], Hitungan: 1
#   Jalur: ['oranges'], Hitungan: 1
#   Jalur: ['cereal', 'oranges', 'cheese'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cheese'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese'], Hitungan: 1
#   Jalur: ['cereal'], Hitungan: 2
#   Jalur: ['bananas', 'coffee', 'cereal', 'oranges', 'cheese'], Hitungan: 1
#
# Item: potatoes
#   Jalur: ['eggs'], Hitungan: 1
#   Jalur: ['cereal'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'oranges'], Hitungan: 1
#   Jalur: ['bananas', 'oranges'], Hitungan: 3
#   Jalur: ['coffee', 'eggs'], Hitungan: 1
#   Jalur: ['bananas', 'eggs'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese'], Hitungan: 1
#   Jalur: ['oranges', 'eggs'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'oranges'], Hitungan: 1
#   Jalur: ['coffee'], Hitungan: 2
#   Jalur: ['bananas', 'cereal', 'cheese'], Hitungan: 1
#   Jalur: ['cereal', 'oranges', 'cheese', 'eggs'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cheese', 'eggs'], Hitungan: 1
#   Jalur: ['coffee', 'cereal'], Hitungan: 1
#   Jalur: ['cereal', 'eggs'], Hitungan: 1
#   Jalur: ['bananas'], Hitungan: 1
#   Jalur: ['bananas', 'cereal'], Hitungan: 1
#   Jalur: ['oranges'], Hitungan: 1
#   Jalur: ['coffee', 'oranges', 'cheese'], Hitungan: 1
#
# Item: oranges
#   Jalur: ['bananas', 'coffee'], Hitungan: 1
#   Jalur: ['bananas'], Hitungan: 6
#   Jalur: ['coffee'], Hitungan: 3
#   Jalur: ['coffee', 'cereal'], Hitungan: 2
#   Jalur: ['cereal'], Hitungan: 2
#   Jalur: ['bananas', 'coffee', 'cereal'], Hitungan: 1
#
# Item: milk
#   Jalur: ['cereal'], Hitungan: 1
#   Jalur: ['eggs', 'tomatoes', 'sugar', 'butter'], Hitungan: 1
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes', 'sugar', 'yogurt', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'oranges'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes', 'tomatoes'], Hitungan: 1
#   Jalur: ['coffee', 'oranges', 'yogurt'], Hitungan: 1
#   Jalur: ['bananas', 'eggs', 'potatoes', 'tomatoes', 'butter'], Hitungan: 1
#   Jalur: ['oranges', 'cheese', 'tomatoes', 'yogurt', 'apples'], Hitungan: 1
#   Jalur: ['oranges'], Hitungan: 3
#   Jalur: ['cereal', 'oranges', 'cheese', 'eggs', 'potatoes', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'sugar', 'apples'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'sugar', 'yogurt', 'apples', 'butter'], Hitungan: 1
#   Jalur: ['cereal', 'tomatoes', 'apples', 'butter'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese', 'butter'], Hitungan: 1
#   Jalur: ['coffee'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'tomatoes', 'sugar'], Hitungan: 1
#   Jalur: ['oranges', 'butter'], Hitungan: 1
#   Jalur: ['coffee', 'oranges', 'cheese', 'potatoes', 'yogurt', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes', 'butter'], Hitungan: 1
#
# Item: onions
#   Jalur: ['cereal', 'milk'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'oranges', 'potatoes', 'sugar', 'bread'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'cheese'], Hitungan: 1
#   Jalur: ['cereal', 'cheese'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'bread'], Hitungan: 1
#   Jalur: ['eggs', 'tomatoes', 'sugar', 'butter', 'milk', 'juice'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'juice'], Hitungan: 1
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes', 'sugar', 'yogurt', 'apples', 'milk', 'juice'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes', 'tomatoes', 'milk', 'bread'], Hitungan: 1
#   Jalur: ['cheese', 'eggs', 'juice'], Hitungan: 1
#   Jalur: ['cheese', 'apples'], Hitungan: 1
#   Jalur: ['cereal'], Hitungan: 1
#   Jalur: ['cheese', 'tomatoes', 'sugar', 'apples', 'bread'], Hitungan: 1
#   Jalur: ['cereal', 'oranges', 'cheese', 'eggs', 'potatoes', 'apples', 'milk'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'potatoes', 'bread'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'eggs', 'yogurt', 'butter'], Hitungan: 1
#   Jalur: ['yogurt'], Hitungan: 1
#   Jalur: ['sugar'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese', 'butter', 'milk', 'bread'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'tomatoes', 'sugar', 'milk'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'potatoes'], Hitungan: 1
#
# Item: cereal
#   Jalur: ['bananas'], Hitungan: 8
#   Jalur: ['coffee'], Hitungan: 7
#   Jalur: ['bananas', 'coffee'], Hitungan: 1
#
# Item: tomatoes
#   Jalur: ['cereal', 'potatoes'], Hitungan: 1
#   Jalur: ['bananas', 'eggs'], Hitungan: 2
#   Jalur: ['potatoes'], Hitungan: 2
#   Jalur: ['eggs'], Hitungan: 3
#   Jalur: ['coffee', 'eggs', 'potatoes'], Hitungan: 1
#   Jalur: ['bananas'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes'], Hitungan: 1
#   Jalur: ['bananas', 'eggs', 'potatoes'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese', 'potatoes'], Hitungan: 1
#   Jalur: ['oranges', 'cheese'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'oranges', 'potatoes'], Hitungan: 1
#   Jalur: ['cheese'], Hitungan: 2
#   Jalur: ['cereal'], Hitungan: 2
#   Jalur: ['coffee'], Hitungan: 2
#   Jalur: ['cereal', 'oranges', 'cheese'], Hitungan: 1
#   Jalur: ['bananas', 'potatoes'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'eggs'], Hitungan: 1
#
# Item: bananas
#   (Tidak ada pola)
#
# Item: pasta
#   Jalur: ['bananas', 'coffee', 'oranges', 'potatoes', 'sugar', 'bread', 'onions'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'cheese', 'onions'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'eggs'], Hitungan: 1
#   Jalur: ['potatoes', 'tomatoes', 'sugar', 'apples', 'bread'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'juice', 'onions'], Hitungan: 1
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes', 'sugar', 'yogurt', 'apples', 'milk', 'juice', 'onions'], Hitungan: 1
#   Jalur: ['apples', 'bread'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'yogurt'], Hitungan: 1
#   Jalur: ['coffee', 'juice'], Hitungan: 1
#   Jalur: ['cereal', 'oranges', 'cheese', 'eggs', 'potatoes', 'apples', 'milk', 'onions'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'sugar', 'yogurt', 'apples', 'butter', 'milk', 'bread'], Hitungan: 1
#   Jalur: ['milk'], Hitungan: 1
#   Jalur: ['sugar', 'apples'], Hitungan: 1
#   Jalur: ['coffee', 'milk', 'bread'], Hitungan: 1
#   Jalur: ['bananas', 'potatoes', 'tomatoes', 'butter'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'eggs', 'tomatoes'], Hitungan: 1
#   Jalur: ['potatoes', 'sugar'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cereal', 'oranges', 'cheese', 'eggs', 'yogurt', 'butter', 'bread', 'juice'], Hitungan: 1
#   Jalur: ['coffee', 'eggs'], Hitungan: 1
#
# Item: bread
#   Jalur: ['bananas', 'coffee', 'oranges', 'potatoes', 'sugar'], Hitungan: 1
#   Jalur: ['coffee', 'cereal'], Hitungan: 1
#   Jalur: ['potatoes', 'tomatoes', 'sugar', 'apples'], Hitungan: 1
#   Jalur: ['apples'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes', 'tomatoes', 'milk'], Hitungan: 1
#   Jalur: ['coffee', 'oranges', 'yogurt', 'milk'], Hitungan: 1
#   Jalur: ['oranges', 'eggs', 'potatoes', 'yogurt', 'butter'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'oranges', 'potatoes', 'tomatoes', 'butter'], Hitungan: 1
#   Jalur: ['cheese', 'tomatoes', 'sugar', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'cheese', 'potatoes', 'butter'], Hitungan: 1
#   Jalur: ['cheese'], Hitungan: 1
#   Jalur: ['coffee'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'potatoes'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'sugar', 'yogurt', 'apples', 'butter', 'milk'], Hitungan: 1
#   Jalur: ['coffee', 'tomatoes'], Hitungan: 1
#   Jalur: ['coffee', 'potatoes', 'sugar', 'yogurt', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese', 'butter', 'milk'], Hitungan: 1
#   Jalur: ['coffee', 'milk'], Hitungan: 1
#   Jalur: ['oranges', 'apples', 'butter'], Hitungan: 1
#   Jalur: ['yogurt', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cereal', 'oranges', 'cheese', 'eggs', 'yogurt', 'butter'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes', 'butter', 'milk'], Hitungan: 1
#   Jalur: ['bananas'], Hitungan: 1
#
# Item: coffee
#   Jalur: ['bananas'], Hitungan: 6
#
# Item: sugar
#   Jalur: ['bananas', 'coffee', 'oranges', 'potatoes'], Hitungan: 1
#   Jalur: ['eggs'], Hitungan: 1
#   Jalur: ['coffee'], Hitungan: 3
#   Jalur: ['potatoes', 'tomatoes'], Hitungan: 1
#   Jalur: ['eggs', 'tomatoes'], Hitungan: 1
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes'], Hitungan: 1
#   Jalur: ['bananas', 'tomatoes'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese', 'potatoes', 'tomatoes'], Hitungan: 1
#   Jalur: ['cheese'], Hitungan: 1
#   Jalur: ['bananas'], Hitungan: 2
#   Jalur: ['tomatoes'], Hitungan: 1
#   Jalur: ['cheese', 'tomatoes'], Hitungan: 1
#   Jalur: ['bananas', 'cheese'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese'], Hitungan: 1
#   Jalur: ['coffee', 'potatoes'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'tomatoes'], Hitungan: 1
#   Jalur: ['bananas', 'eggs', 'tomatoes'], Hitungan: 1
#   Jalur: ['potatoes'], Hitungan: 1
#
# Item: chicken
#   Jalur: ['bananas', 'cereal'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'cheese', 'onions', 'pasta'], Hitungan: 1
#   Jalur: ['pasta'], Hitungan: 1
#   Jalur: ['bananas', 'eggs', 'tomatoes', 'butter'], Hitungan: 1
#   Jalur: ['potatoes', 'tomatoes', 'sugar', 'apples', 'bread', 'pasta'], Hitungan: 1
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes', 'sugar', 'yogurt', 'apples', 'milk', 'juice', 'onions', 'pasta', 'tea'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'oranges', 'potatoes', 'tomatoes', 'butter', 'bread', 'juice'], Hitungan: 1
#   Jalur: ['potatoes', 'tomatoes', 'butter'], Hitungan: 1
#   Jalur: ['cereal', 'oranges', 'cheese', 'eggs', 'potatoes', 'apples', 'milk', 'onions', 'pasta'], Hitungan: 1
#   Jalur: ['cereal', 'tomatoes'], Hitungan: 1
#   Jalur: ['onions'], Hitungan: 1
#   Jalur: ['sugar', 'apples', 'pasta', 'tea'], Hitungan: 1
#   Jalur: ['oranges', 'yogurt'], Hitungan: 1
#   Jalur: ['oranges', 'apples', 'butter', 'bread'], Hitungan: 1
#   Jalur: ['bananas', 'potatoes', 'tomatoes', 'butter', 'pasta'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'potatoes', 'onions'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cereal', 'oranges', 'cheese', 'eggs', 'yogurt', 'butter', 'bread', 'juice', 'pasta'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes', 'butter', 'milk', 'bread', 'juice'], Hitungan: 1
#   Jalur: ['bananas', 'bread', 'juice'], Hitungan: 1
#
# Item: cheese
#   Jalur: ['bananas', 'cereal'], Hitungan: 2
#   Jalur: ['cereal'], Hitungan: 3
#   Jalur: ['bananas', 'oranges'], Hitungan: 2
#   Jalur: ['oranges'], Hitungan: 2
#   Jalur: ['cereal', 'oranges'], Hitungan: 2
#   Jalur: ['bananas', 'coffee'], Hitungan: 1
#   Jalur: ['bananas'], Hitungan: 2
#   Jalur: ['coffee', 'cereal', 'oranges'], Hitungan: 1
#   Jalur: ['coffee', 'cereal'], Hitungan: 3
#   Jalur: ['coffee', 'oranges'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cereal', 'oranges'], Hitungan: 1
#
# Item: tea
#   Jalur: ['bananas', 'cereal', 'eggs', 'pasta'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'juice', 'onions', 'pasta'], Hitungan: 1
#   Jalur: ['cereal', 'butter', 'juice'], Hitungan: 1
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes', 'sugar', 'yogurt', 'apples', 'milk', 'juice', 'onions', 'pasta'], Hitungan: 1
#   Jalur: ['butter', 'juice'], Hitungan: 1
#   Jalur: ['oranges', 'eggs', 'potatoes', 'yogurt', 'butter', 'bread'], Hitungan: 1
#   Jalur: ['oranges', 'cheese', 'tomatoes', 'yogurt', 'apples', 'milk'], Hitungan: 1
#   Jalur: ['coffee', 'juice', 'pasta'], Hitungan: 1
#   Jalur: ['cheese', 'apples', 'onions'], Hitungan: 1
#   Jalur: ['oranges'], Hitungan: 1
#   Jalur: ['cereal', 'cheese', 'yogurt', 'juice'], Hitungan: 1
#   Jalur: ['oranges', 'milk'], Hitungan: 1
#   Jalur: ['yogurt'], Hitungan: 1
#   Jalur: ['coffee', 'potatoes', 'juice'], Hitungan: 1
#   Jalur: ['butter'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'cheese', 'potatoes', 'butter', 'bread'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cheese', 'eggs', 'potatoes', 'butter', 'juice'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'potatoes', 'bread', 'onions'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'sugar', 'yogurt', 'apples', 'butter', 'milk', 'bread', 'pasta'], Hitungan: 1
#   Jalur: ['sugar', 'onions'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese', 'butter', 'milk', 'bread', 'onions'], Hitungan: 1
#   Jalur: ['sugar', 'apples', 'pasta'], Hitungan: 1
#   Jalur: ['coffee', 'sugar'], Hitungan: 1
#
# Item: yogurt
#   Jalur: ['bananas'], Hitungan: 2
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes', 'sugar'], Hitungan: 1
#   Jalur: ['bananas', 'tomatoes', 'sugar'], Hitungan: 1
#   Jalur: ['coffee', 'oranges'], Hitungan: 2
#   Jalur: ['bananas', 'oranges', 'cheese', 'potatoes', 'tomatoes', 'sugar'], Hitungan: 1
#   Jalur: ['oranges', 'eggs', 'potatoes'], Hitungan: 1
#   Jalur: ['oranges', 'cheese', 'tomatoes'], Hitungan: 1
#   Jalur: ['bananas', 'coffee'], Hitungan: 1
#   Jalur: ['cereal', 'cheese'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'eggs'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'sugar'], Hitungan: 1
#   Jalur: ['coffee', 'potatoes', 'sugar'], Hitungan: 1
#   Jalur: ['sugar'], Hitungan: 1
#   Jalur: ['oranges'], Hitungan: 1
#   Jalur: ['bananas', 'eggs', 'tomatoes', 'sugar'], Hitungan: 1
#   Jalur: ['coffee', 'oranges', 'cheese', 'potatoes'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cereal', 'oranges', 'cheese', 'eggs'], Hitungan: 1
#
# Item: juice
#   Jalur: ['eggs', 'tomatoes', 'sugar', 'butter', 'milk'], Hitungan: 1
#   Jalur: ['bananas', 'coffee'], Hitungan: 1
#   Jalur: ['cereal', 'butter'], Hitungan: 1
#   Jalur: ['yogurt'], Hitungan: 1
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes', 'sugar', 'yogurt', 'apples', 'milk'], Hitungan: 1
#   Jalur: ['butter'], Hitungan: 1
#   Jalur: ['bananas', 'eggs', 'potatoes', 'tomatoes', 'butter', 'milk'], Hitungan: 1
#   Jalur: ['cheese', 'eggs'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese', 'potatoes', 'tomatoes', 'sugar', 'yogurt'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'oranges', 'potatoes', 'tomatoes', 'butter', 'bread'], Hitungan: 1
#   Jalur: ['coffee'], Hitungan: 2
#   Jalur: ['cereal', 'cheese', 'yogurt'], Hitungan: 1
#   Jalur: ['coffee', 'potatoes'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cheese', 'eggs', 'potatoes', 'butter'], Hitungan: 1
#   Jalur: ['coffee', 'potatoes', 'sugar', 'yogurt', 'apples', 'bread'], Hitungan: 1
#   Jalur: ['eggs'], Hitungan: 1
#   Jalur: ['bananas', 'cereal'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cereal', 'oranges', 'cheese', 'eggs', 'yogurt', 'butter', 'bread'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes', 'butter', 'milk', 'bread'], Hitungan: 1
#   Jalur: ['bananas', 'bread'], Hitungan: 1

# %% [markdown]
# ## Conditional FP TREE

# %%
# pembentukan conditional FP-TREE
# Tujuan: membangun sub-pohon (conditional FP-Tree) untuk setiap item yang sering muncul
#         sehingga bisa menemukan semua pola (frequent itemset) yang mengandung item tersebut
#         tanpa harus memindai seluruh database lagi.

from collections import defaultdict

# 1: Hitung frekuensi tiap item dan simpan semua transaksi
item_counts = defaultdict(int)
for transaction in transactions:
    for item in transaction:
        item_counts[item] += 1

# 2: Hapus item yang tidak memenuhi min_support
min_support = 0.01 * len(transactions)  # min_support absolut, bukan proporsi
item_counts = {item: count for item, count in item_counts.items() if count >= min_support}

# Step 3: Sort item dalam transaksi berdasarkan frekuensi
def sort_items(transaction):
    return sorted(
        [item for item in transaction if item in item_counts],
        key=lambda item: (-item_counts[item], item)
    )

sorted_transactions = [sort_items(t) for t in transactions]

# 4: Bangun FP-Tree
class FPNode:
    def __init__(self, item, count=1):
        self.item = item
        self.count = count
        self.children = {}
        self.parent = None

class FPTree:
    def __init__(self):
        self.root = FPNode(None)
        self.headers = defaultdict(list)

    def insert(self, transaction):
        current = self.root
        for item in transaction:
            if item in current.children:
                current.children[item].count += 1
            else:
                new_node = FPNode(item)
                new_node.parent = current
                current.children[item] = new_node
                self.headers[item].append(new_node)
            current = current.children[item]

    def conditional_pattern_base(self, item):
        patterns = []
        for node in self.headers[item]:
            path = []
            current = node.parent
            while current and current.item is not None:
                path.append(current.item)
                current = current.parent
            if path:
                patterns.append((list(reversed(path)), node.count))
        return patterns

# 5: Masukkan transaksi ke dalam FP-Tree
tree = FPTree()
for transaction in sorted_transactions:
    tree.insert(transaction)

# 6: Conditional FP-Tree untuk setiap item
def build_conditional_fptree(cpb, min_support):
    # Step 1: Hitung frekuensi item dari CPB
    item_freq = defaultdict(int)
    for pattern, count in cpb:
        for item in pattern:
            item_freq[item] += count

    # Step 2: Filter berdasarkan min_support
    frequent_items = {item: freq for item, freq in item_freq.items() if freq >= min_support}

    # Step 3: Urutkan item dalam setiap pattern berdasarkan frekuensi (descending)
    def sort_pattern(pattern):
        return sorted([item for item in pattern if item in frequent_items],
                      key=lambda x: (-frequent_items[x], x))

    sorted_patterns = [(sort_pattern(pattern), count) for pattern, count in cpb]

    # Step 4: Bangun Conditional FP-Tree
    root = FPNode(None)
    for pattern, count in sorted_patterns:
        current_node = root
        for item in pattern:
            current_node = current_node.children.get(item, FPNode(item))
            current_node.count += count
            current_node.parent = root
            root.children[item] = current_node

    return root

# 7: Loop untuk membangun Conditional FP-Tree untuk semua item
print("\nConditional FP-Tree untuk setiap item:")
for item in item_counts.keys():
    cpb = tree.conditional_pattern_base(item)
    if cpb:
        print(f"\nItem: {item}")
        root = build_conditional_fptree(cpb, min_support)

        # Fungsi untuk mencetak tree
        def print_tree(node, indent=0):
            for child in node.children.values():
                print('  ' * indent + f"{child.item} ({child.count})")
                print_tree(child, indent + 1)

        # Tampilkan hasil
        print_tree(root)
    else:
        print(f"  Tidak ada Conditional Pattern Base untuk item '{item}'")
# Out:
# Conditional FP-Tree untuk setiap item:
#
# Item: apples
# potatoes (2)
# eggs (3)
# sugar (10)
# tomatoes (3)
# yogurt (4)
# coffee (2)
# bananas (2)
# cheese (2)
# oranges (2)
# cereal (2)
#
# Item: butter
# potatoes (2)
# eggs (2)
# apples (2)
# bananas (10)
# tomatoes (2)
# yogurt (2)
# sugar (2)
# cereal (2)
# oranges (2)
# coffee (2)
# cheese (2)
#
# Item: eggs
# bananas (8)
# cereal (2)
# coffee (2)
# cheese (2)
# oranges (2)
#
# Item: potatoes
# eggs (2)
# cereal (2)
# bananas (11)
# oranges (7)
# coffee (2)
# cheese (2)
#
# Item: oranges
# bananas (9)
# coffee (2)
# cereal (2)
#
# Item: milk
# cereal (2)
# butter (2)
# tomatoes (3)
# sugar (2)
# eggs (2)
# apples (2)
# coffee (2)
# potatoes (2)
# yogurt (2)
# oranges (13)
# bananas (2)
# cheese (2)
#
# Item: onions
# cereal (11)
# milk (2)
# coffee (2)
# bananas (2)
# bread (2)
# potatoes (2)
# sugar (2)
# oranges (2)
# cheese (2)
# eggs (2)
# tomatoes (2)
# juice (2)
# butter (2)
# apples (2)
# yogurt (3)
#
# Item: cereal
# bananas (10)
# coffee (2)
#
# Item: tomatoes
# potatoes (10)
# cereal (2)
# bananas (3)
# eggs (2)
# coffee (2)
# oranges (2)
# cheese (2)
#   Tidak ada Conditional Pattern Base untuk item 'bananas'
#
# Item: pasta
# coffee (10)
# bananas (2)
# bread (2)
# potatoes (3)
# sugar (2)
# onions (2)
# oranges (2)
# cereal (2)
# cheese (2)
# eggs (2)
# apples (3)
# tomatoes (2)
# juice (2)
# milk (2)
# yogurt (2)
# butter (2)
#
# Item: bread
# coffee (12)
# oranges (3)
# potatoes (2)
# bananas (3)
# sugar (2)
# cereal (2)
# apples (3)
# tomatoes (2)
# milk (2)
# yogurt (2)
# butter (2)
# eggs (2)
# cheese (2)
#
# Item: coffee
# bananas (7)
#
# Item: sugar
# coffee (2)
# bananas (2)
# potatoes (3)
# oranges (2)
# eggs (2)
# tomatoes (10)
# cheese (2)
# cereal (2)
#
# Item: chicken
# bananas (9)
# cereal (2)
# pasta (2)
# onions (2)
# cheese (2)
# butter (2)
# tomatoes (2)
# eggs (2)
# potatoes (2)
# bread (2)
# apples (2)
# sugar (2)
# juice (2)
# coffee (2)
# milk (2)
# yogurt (2)
# tea (2)
# oranges (2)
#
# Item: cheese
# cereal (13)
# bananas (2)
# oranges (2)
# coffee (2)
#
# Item: tea
# cereal (2)
# pasta (3)
# bananas (2)
# eggs (2)
# coffee (3)
# juice (2)
# onions (2)
# butter (9)
# potatoes (2)
# yogurt (2)
# apples (2)
# milk (2)
# sugar (2)
# tomatoes (2)
# bread (2)
# oranges (2)
# cheese (2)
#
# Item: yogurt
# bananas (2)
# coffee (10)
# sugar (2)
# eggs (2)
# potatoes (2)
# tomatoes (2)
# oranges (2)
# cheese (2)
# cereal (2)
#
# Item: juice
# butter (2)
# eggs (2)
# tomatoes (2)
# milk (2)
# sugar (2)
# coffee (10)
# bananas (4)
# cereal (2)
# yogurt (2)
# potatoes (2)
# apples (2)
# cheese (2)
# oranges (2)
# bread (2)

# %%
# mencari conditional frequent itemset
# Fungsi untuk menambang frequent itemsets dari FP-Tree secara rekursif
def mine_tree(tree, suffix, min_support, frequent_patterns):
    for item in tree.headers:
        new_suffix = suffix.copy()
        new_suffix.add(item)

        # Hitung total support item dari header
        support = sum(node.count for node in tree.headers[item])

        if support >= min_support:
            frequent_patterns[frozenset(new_suffix)] = support

            # Bangun CPB dari node
            cpb = tree.conditional_pattern_base(item)

            # Bangun conditional FP-Tree
            conditional_tree = FPTree()
            for path, count in cpb:
                sorted_path = sorted(
                    [i for i in path],
                    key=lambda i: (-item_counts.get(i, 0), i)
                )
                for _ in range(count):  # Tambahkan sesuai count
                    conditional_tree.insert(sorted_path)

            # Rekursif ke bawah pohon
            mine_tree(conditional_tree, new_suffix, min_support, frequent_patterns)

# Menambang frequent itemsets dari pohon utama
frequent_patterns = {}
mine_tree(tree, set(), min_support, frequent_patterns)

# Tampilkan hasil
print("\nFrequent itemsets yang ditemukan (FP-Growth):")
for itemset, support in frequent_patterns.items():
    print(f"{set(itemset)}: {support}")
# Out:
# Frequent itemsets yang ditemukan (FP-Growth):
# {'eggs'}: 27
# {'bananas', 'eggs'}: 7
# {'cereal', 'eggs'}: 7
# {'bananas', 'cereal', 'eggs'}: 3
# {'coffee', 'cereal', 'eggs'}: 2
# {'coffee', 'eggs'}: 6
# {'bananas', 'coffee', 'eggs'}: 2
# {'cheese', 'eggs'}: 5
# {'cheese', 'cereal', 'eggs'}: 3
# {'coffee', 'cheese', 'cereal', 'eggs'}: 2
# {'oranges', 'cheese', 'eggs'}: 2
# {'oranges', 'cheese', 'cereal', 'eggs'}: 2
# {'bananas', 'cheese', 'eggs'}: 2
# {'coffee', 'cheese', 'eggs'}: 3
# {'bananas', 'coffee', 'cheese', 'eggs'}: 2
# {'oranges', 'eggs'}: 3
# {'oranges', 'cereal', 'eggs'}: 2
# {'potatoes'}: 27
# {'potatoes', 'eggs'}: 7
# {'coffee', 'potatoes', 'eggs'}: 2
# {'bananas', 'potatoes', 'eggs'}: 2
# {'oranges', 'potatoes', 'eggs'}: 2
# {'potatoes', 'cereal', 'eggs'}: 2
# {'cheese', 'potatoes', 'eggs'}: 2
# {'potatoes', 'cereal'}: 7
# {'coffee', 'potatoes', 'cereal'}: 2
# {'bananas', 'potatoes', 'cereal'}: 2
# {'bananas', 'potatoes'}: 10
# {'coffee', 'potatoes'}: 8
# {'bananas', 'coffee', 'potatoes'}: 2
# {'oranges', 'potatoes'}: 10
# {'oranges', 'potatoes', 'bananas'}: 5
# {'oranges', 'coffee', 'potatoes'}: 3
# {'oranges', 'potatoes', 'cereal'}: 2
# {'cheese', 'potatoes'}: 5
# {'bananas', 'cheese', 'potatoes'}: 3
# {'oranges', 'cheese', 'potatoes'}: 3
# {'cheese', 'potatoes', 'cereal'}: 2
# {'coffee', 'cheese', 'potatoes'}: 2
# {'apples'}: 25
# {'apples', 'eggs'}: 4
# {'apples', 'potatoes'}: 7
# {'apples', 'eggs', 'potatoes'}: 3
# {'coffee', 'apples', 'potatoes'}: 3
# {'oranges', 'apples', 'potatoes'}: 2
# {'cheese', 'apples', 'potatoes'}: 2
# {'oranges', 'cheese', 'apples', 'potatoes'}: 2
# {'apples', 'tomatoes'}: 6
# {'apples', 'tomatoes', 'potatoes'}: 2
# {'cheese', 'apples', 'tomatoes'}: 2
# {'apples', 'sugar'}: 9
# {'apples', 'sugar', 'potatoes'}: 3
# {'coffee', 'apples', 'sugar', 'potatoes'}: 2
# {'apples', 'sugar', 'tomatoes'}: 4
# {'apples', 'sugar', 'tomatoes', 'potatoes'}: 2
# {'coffee', 'apples', 'sugar'}: 3
# {'bananas', 'apples', 'sugar'}: 2
# {'cheese', 'apples', 'sugar'}: 2
# {'coffee', 'apples'}: 5
# {'apples', 'yogurt'}: 8
# {'coffee', 'apples', 'yogurt'}: 4
# {'apples', 'yogurt', 'potatoes'}: 3
# {'coffee', 'apples', 'yogurt', 'potatoes'}: 3
# {'apples', 'yogurt', 'tomatoes'}: 3
# {'sugar', 'apples', 'yogurt'}: 5
# {'sugar', 'coffee', 'apples', 'yogurt'}: 3
# {'sugar', 'apples', 'yogurt', 'potatoes'}: 2
# {'potatoes', 'yogurt', 'apples', 'coffee', 'sugar'}: 2
# {'sugar', 'apples', 'yogurt', 'tomatoes'}: 2
# {'oranges', 'apples', 'yogurt'}: 2
# {'cheese', 'apples', 'yogurt'}: 3
# {'oranges', 'cheese', 'apples', 'yogurt'}: 2
# {'coffee', 'cheese', 'apples', 'yogurt'}: 2
# {'bananas', 'apples'}: 2
# {'oranges', 'apples'}: 4
# {'cheese', 'apples'}: 6
# {'oranges', 'cheese', 'apples'}: 3
# {'cheese', 'apples', 'cereal'}: 2
# {'coffee', 'cheese', 'apples'}: 2
# {'apples', 'cereal'}: 3
# {'butter'}: 25
# {'butter', 'eggs'}: 8
# {'bananas', 'butter', 'eggs'}: 4
# {'oranges', 'butter', 'eggs'}: 2
# {'butter', 'coffee', 'eggs'}: 3
# {'bananas', 'butter', 'coffee', 'eggs'}: 2
# {'butter', 'cheese', 'eggs'}: 3
# {'bananas', 'butter', 'cheese', 'eggs'}: 2
# {'butter', 'cheese', 'coffee', 'eggs'}: 3
# {'cheese', 'coffee', 'bananas', 'butter', 'eggs'}: 2
# {'butter', 'cheese', 'cereal', 'eggs'}: 2
# {'cheese', 'coffee', 'butter', 'cereal', 'eggs'}: 2
# {'butter', 'cereal', 'eggs'}: 2
# {'butter', 'coffee', 'cereal', 'eggs'}: 2
# {'butter', 'potatoes'}: 9
# {'butter', 'potatoes', 'eggs'}: 4
# {'bananas', 'butter', 'potatoes', 'eggs'}: 2
# {'bananas', 'butter', 'potatoes'}: 5
# {'oranges', 'butter', 'potatoes'}: 3
# {'butter', 'potatoes', 'coffee'}: 2
# {'butter', 'potatoes', 'cereal'}: 2
# {'butter', 'cheese', 'potatoes'}: 2
# {'bananas', 'butter', 'cheese', 'potatoes'}: 2
# {'butter', 'apples'}: 4
# {'butter', 'apples', 'cereal'}: 2
# {'bananas', 'butter'}: 9
# {'butter', 'tomatoes'}: 7
# {'bananas', 'butter', 'tomatoes'}: 3
# {'butter', 'tomatoes', 'eggs'}: 3
# {'bananas', 'butter', 'tomatoes', 'eggs'}: 2
# {'butter', 'potatoes', 'tomatoes'}: 4
# {'bananas', 'butter', 'potatoes', 'tomatoes'}: 2
# {'butter', 'cereal', 'tomatoes'}: 2
# {'butter', 'yogurt'}: 5
# {'bananas', 'butter', 'yogurt'}: 2
# {'oranges', 'butter', 'yogurt'}: 2
# {'butter', 'yogurt', 'eggs'}: 3
# {'oranges', 'butter', 'yogurt', 'eggs'}: 2
# {'butter', 'coffee', 'yogurt', 'eggs'}: 2
# {'butter', 'yogurt', 'cereal', 'eggs'}: 2
# {'coffee', 'yogurt', 'butter', 'cereal', 'eggs'}: 2
# {'butter', 'cheese', 'yogurt', 'eggs'}: 2
# {'cheese', 'coffee', 'yogurt', 'butter', 'eggs'}: 2
# {'cheese', 'yogurt', 'butter', 'cereal', 'eggs'}: 2
# {'cheese', 'coffee', 'yogurt', 'butter', 'cereal', 'eggs'}: 2
# {'butter', 'coffee', 'yogurt'}: 3
# {'butter', 'yogurt', 'cereal'}: 3
# {'butter', 'coffee', 'yogurt', 'cereal'}: 3
# {'butter', 'cheese', 'yogurt'}: 3
# {'butter', 'cheese', 'coffee', 'yogurt'}: 3
# {'butter', 'cheese', 'yogurt', 'cereal'}: 3
# {'cheese', 'coffee', 'yogurt', 'butter', 'cereal'}: 3
# {'butter', 'sugar'}: 2
# {'butter', 'cereal'}: 7
# {'butter', 'coffee', 'cereal'}: 4
# {'bananas', 'butter', 'cereal'}: 2
# {'oranges', 'butter'}: 7
# {'oranges', 'butter', 'coffee'}: 2
# {'oranges', 'butter', 'cereal'}: 2
# {'oranges', 'butter', 'coffee', 'cereal'}: 2
# {'oranges', 'butter', 'bananas'}: 3
# {'butter', 'coffee'}: 5
# {'bananas', 'butter', 'coffee'}: 2
# {'butter', 'cheese'}: 6
# {'bananas', 'butter', 'cheese'}: 4
# {'butter', 'cheese', 'cereal'}: 4
# {'bananas', 'butter', 'cheese', 'cereal'}: 2
# {'butter', 'cheese', 'coffee', 'cereal'}: 3
# {'butter', 'cheese', 'coffee'}: 4
# {'bananas', 'butter', 'cheese', 'coffee'}: 2
# {'oranges', 'butter', 'cheese'}: 2
# {'oranges', 'butter', 'cheese', 'bananas'}: 2
# {'oranges'}: 29
# {'oranges', 'bananas'}: 8
# {'oranges', 'coffee'}: 7
# {'oranges', 'coffee', 'bananas'}: 2
# {'oranges', 'cereal'}: 5
# {'oranges', 'coffee', 'cereal'}: 3
# {'cereal'}: 31
# {'bananas', 'cereal'}: 9
# {'coffee', 'cereal'}: 8
# {'milk'}: 24
# {'milk', 'cereal'}: 5
# {'milk', 'coffee', 'cereal'}: 2
# {'milk', 'eggs'}: 4
# {'milk', 'tomatoes'}: 7
# {'milk', 'tomatoes', 'eggs'}: 3
# {'milk', 'coffee', 'tomatoes'}: 2
# {'milk', 'potatoes', 'tomatoes'}: 3
# {'milk', 'potatoes', 'tomatoes', 'eggs'}: 2
# {'milk', 'bananas', 'potatoes', 'tomatoes'}: 2
# {'milk', 'bananas', 'tomatoes'}: 2
# {'milk', 'oranges', 'tomatoes'}: 2
# {'milk', 'cheese', 'tomatoes'}: 2
# {'milk', 'cereal', 'tomatoes'}: 2
# {'milk', 'sugar'}: 5
# {'milk', 'sugar', 'eggs'}: 2
# {'milk', 'sugar', 'tomatoes'}: 3
# {'milk', 'sugar', 'tomatoes', 'eggs'}: 2
# {'milk', 'coffee', 'sugar', 'tomatoes'}: 2
# {'milk', 'coffee', 'sugar'}: 3
# {'milk', 'sugar', 'cereal'}: 2
# {'milk', 'coffee', 'sugar', 'cereal'}: 2
# {'milk', 'cheese', 'sugar'}: 2
# {'milk', 'coffee', 'cheese', 'sugar'}: 2
# {'milk', 'cheese', 'sugar', 'cereal'}: 2
# {'cheese', 'milk', 'coffee', 'sugar', 'cereal'}: 2
# {'milk', 'butter'}: 7
# {'milk', 'butter', 'eggs'}: 2
# {'milk', 'butter', 'tomatoes'}: 3
# {'milk', 'butter', 'tomatoes', 'eggs'}: 2
# {'milk', 'butter', 'sugar'}: 2
# {'milk', 'butter', 'bananas'}: 3
# {'milk', 'butter', 'potatoes'}: 2
# {'milk', 'butter', 'potatoes', 'bananas'}: 2
# {'milk', 'butter', 'cereal'}: 2
# {'milk', 'butter', 'cheese'}: 2
# {'milk', 'butter', 'apples'}: 2
# {'milk', 'butter', 'apples', 'cereal'}: 2
# {'milk', 'butter', 'oranges'}: 3
# {'milk', 'butter', 'oranges', 'bananas'}: 2
# {'milk', 'coffee'}: 6
# {'milk', 'potatoes'}: 6
# {'milk', 'coffee', 'potatoes'}: 2
# {'milk', 'potatoes', 'eggs'}: 3
# {'milk', 'potatoes', 'bananas'}: 3
# {'milk', 'oranges', 'potatoes'}: 4
# {'milk', 'oranges', 'potatoes', 'bananas'}: 2
# {'milk', 'cheese', 'potatoes'}: 2
# {'milk', 'cheese', 'potatoes', 'oranges'}: 2
# {'milk', 'yogurt'}: 5
# {'milk', 'coffee', 'yogurt'}: 4
# {'milk', 'potatoes', 'yogurt'}: 2
# {'milk', 'coffee', 'potatoes', 'yogurt'}: 2
# {'milk', 'yogurt', 'tomatoes'}: 2
# {'milk', 'sugar', 'yogurt'}: 2
# {'milk', 'sugar', 'coffee', 'yogurt'}: 2
# {'milk', 'oranges', 'yogurt'}: 3
# {'milk', 'coffee', 'oranges', 'yogurt'}: 2
# {'milk', 'cheese', 'yogurt'}: 3
# {'milk', 'cheese', 'yogurt', 'oranges'}: 2
# {'milk', 'coffee', 'cheese', 'yogurt'}: 2
# {'milk', 'apples'}: 7
# {'milk', 'coffee', 'apples'}: 3
# {'milk', 'apples', 'eggs'}: 2
# {'milk', 'apples', 'potatoes'}: 3
# {'milk', 'coffee', 'apples', 'potatoes'}: 2
# {'milk', 'apples', 'eggs', 'potatoes'}: 2
# {'milk', 'oranges', 'apples', 'potatoes'}: 2
# {'milk', 'cheese', 'apples', 'potatoes'}: 2
# {'cheese', 'potatoes', 'apples', 'oranges', 'milk'}: 2
# {'milk', 'apples', 'tomatoes'}: 3
# {'milk', 'apples', 'sugar'}: 3
# {'milk', 'coffee', 'apples', 'sugar'}: 2
# {'milk', 'apples', 'yogurt'}: 4
# {'milk', 'coffee', 'apples', 'yogurt'}: 3
# {'milk', 'apples', 'yogurt', 'potatoes'}: 2
# {'potatoes', 'yogurt', 'apples', 'milk', 'coffee'}: 2
# {'milk', 'apples', 'yogurt', 'tomatoes'}: 2
# {'milk', 'sugar', 'apples', 'yogurt'}: 2
# {'apples', 'yogurt', 'milk', 'coffee', 'sugar'}: 2
# {'milk', 'oranges', 'apples', 'yogurt'}: 2
# {'milk', 'cheese', 'apples', 'yogurt'}: 3
# {'cheese', 'apples', 'yogurt', 'oranges', 'milk'}: 2
# {'cheese', 'apples', 'yogurt', 'milk', 'coffee'}: 2
# {'milk', 'oranges', 'apples'}: 3
# {'milk', 'cheese', 'apples'}: 4
# {'milk', 'cheese', 'apples', 'oranges'}: 3
# {'milk', 'cheese', 'apples', 'cereal'}: 2
# {'milk', 'coffee', 'cheese', 'apples'}: 2
# {'milk', 'apples', 'cereal'}: 3
# {'milk', 'bananas'}: 6
# {'milk', 'oranges'}: 12
# {'milk', 'oranges', 'bananas'}: 4
# {'milk', 'coffee', 'oranges'}: 2
# {'milk', 'cheese'}: 6
# {'milk', 'cheese', 'oranges'}: 4
# {'milk', 'cheese', 'cereal'}: 3
# {'milk', 'coffee', 'cheese', 'cereal'}: 2
# {'milk', 'coffee', 'cheese'}: 3
# {'onions'}: 23
# {'cereal', 'onions'}: 10
# {'bananas', 'cereal', 'onions'}: 2
# {'coffee', 'cereal', 'onions'}: 4
# {'milk', 'onions'}: 7
# {'milk', 'cereal', 'onions'}: 3
# {'milk', 'eggs', 'onions'}: 3
# {'milk', 'tomatoes', 'onions'}: 4
# {'milk', 'eggs', 'tomatoes', 'onions'}: 2
# {'milk', 'coffee', 'tomatoes', 'onions'}: 2
# {'milk', 'potatoes', 'tomatoes', 'onions'}: 2
# {'milk', 'sugar', 'onions'}: 3
# {'milk', 'sugar', 'eggs', 'onions'}: 2
# {'milk', 'sugar', 'tomatoes', 'onions'}: 3
# {'onions', 'milk', 'sugar', 'tomatoes', 'eggs'}: 2
# {'onions', 'milk', 'coffee', 'sugar', 'tomatoes'}: 2
# {'milk', 'coffee', 'sugar', 'onions'}: 2
# {'milk', 'butter', 'onions'}: 2
# {'milk', 'coffee', 'onions'}: 2
# {'milk', 'potatoes', 'onions'}: 3
# {'milk', 'potatoes', 'eggs', 'onions'}: 2
# {'milk', 'oranges', 'potatoes', 'onions'}: 2
# {'milk', 'apples', 'onions'}: 2
# {'milk', 'apples', 'eggs', 'onions'}: 2
# {'milk', 'apples', 'potatoes', 'onions'}: 2
# {'potatoes', 'apples', 'onions', 'milk', 'eggs'}: 2
# {'milk', 'bananas', 'onions'}: 2
# {'milk', 'oranges', 'onions'}: 3
# {'milk', 'oranges', 'bananas', 'onions'}: 2
# {'milk', 'cheese', 'onions'}: 3
# {'milk', 'cheese', 'cereal', 'onions'}: 2
# {'milk', 'cheese', 'oranges', 'onions'}: 2
# {'bananas', 'onions'}: 6
# {'coffee', 'onions'}: 7
# {'bananas', 'coffee', 'onions'}: 2
# {'oranges', 'onions'}: 4
# {'oranges', 'bananas', 'onions'}: 3
# {'potatoes', 'onions'}: 6
# {'bananas', 'potatoes', 'onions'}: 3
# {'coffee', 'potatoes', 'onions'}: 3
# {'oranges', 'potatoes', 'onions'}: 3
# {'oranges', 'potatoes', 'bananas', 'onions'}: 2
# {'potatoes', 'eggs', 'onions'}: 2
# {'potatoes', 'cereal', 'onions'}: 3
# {'sugar', 'onions'}: 6
# {'coffee', 'sugar', 'onions'}: 3
# {'potatoes', 'sugar', 'onions'}: 2
# {'coffee', 'potatoes', 'sugar', 'onions'}: 2
# {'sugar', 'eggs', 'onions'}: 2
# {'sugar', 'tomatoes', 'onions'}: 4
# {'eggs', 'sugar', 'tomatoes', 'onions'}: 2
# {'coffee', 'sugar', 'tomatoes', 'onions'}: 2
# {'cheese', 'sugar', 'tomatoes', 'onions'}: 2
# {'cheese', 'sugar', 'onions'}: 2
# {'bread', 'onions'}: 6
# {'bananas', 'bread', 'onions'}: 3
# {'coffee', 'bread', 'onions'}: 3
# {'oranges', 'bread', 'onions'}: 3
# {'oranges', 'bread', 'bananas', 'onions'}: 3
# {'bread', 'potatoes', 'onions'}: 3
# {'bananas', 'bread', 'potatoes', 'onions'}: 2
# {'coffee', 'bread', 'potatoes', 'onions'}: 2
# {'oranges', 'bread', 'potatoes', 'onions'}: 2
# {'oranges', 'bread', 'potatoes', 'onions', 'bananas'}: 2
# {'bread', 'sugar', 'onions'}: 2
# {'bread', 'cereal', 'onions'}: 2
# {'coffee', 'bread', 'cereal', 'onions'}: 2
# {'bread', 'tomatoes', 'onions'}: 2
# {'milk', 'bread', 'onions'}: 2
# {'milk', 'bread', 'bananas', 'onions'}: 2
# {'milk', 'oranges', 'bread', 'onions'}: 2
# {'milk', 'oranges', 'bread', 'onions', 'bananas'}: 2
# {'cheese', 'bread', 'onions'}: 2
# {'cheese', 'onions'}: 9
# {'bananas', 'cheese', 'onions'}: 2
# {'cheese', 'cereal', 'onions'}: 5
# {'coffee', 'cheese', 'cereal', 'onions'}: 2
# {'oranges', 'cheese', 'onions'}: 2
# {'coffee', 'cheese', 'onions'}: 2
# {'eggs', 'onions'}: 5
# {'coffee', 'eggs', 'onions'}: 2
# {'cheese', 'eggs', 'onions'}: 3
# {'cheese', 'cereal', 'eggs', 'onions'}: 2
# {'cereal', 'eggs', 'onions'}: 2
# {'tomatoes', 'onions'}: 5
# {'eggs', 'tomatoes', 'onions'}: 2
# {'coffee', 'tomatoes', 'onions'}: 2
# {'potatoes', 'tomatoes', 'onions'}: 2
# {'cheese', 'tomatoes', 'onions'}: 2
# {'butter', 'onions'}: 3
# {'butter', 'eggs', 'onions'}: 2
# {'butter', 'cheese', 'onions'}: 2
# {'juice', 'onions'}: 4
# {'juice', 'eggs', 'onions'}: 3
# {'juice', 'tomatoes', 'onions'}: 2
# {'juice', 'eggs', 'tomatoes', 'onions'}: 2
# {'juice', 'sugar', 'onions'}: 2
# {'juice', 'sugar', 'eggs', 'onions'}: 2
# {'juice', 'sugar', 'tomatoes', 'onions'}: 2
# {'juice', 'onions', 'sugar', 'tomatoes', 'eggs'}: 2
# {'juice', 'milk', 'onions'}: 2
# {'juice', 'milk', 'eggs', 'onions'}: 2
# {'juice', 'milk', 'tomatoes', 'onions'}: 2
# {'juice', 'onions', 'milk', 'tomatoes', 'eggs'}: 2
# {'juice', 'milk', 'sugar', 'onions'}: 2
# {'juice', 'onions', 'milk', 'sugar', 'eggs'}: 2
# {'juice', 'onions', 'milk', 'sugar', 'tomatoes'}: 2
# {'juice', 'onions', 'milk', 'sugar', 'tomatoes', 'eggs'}: 2
# {'juice', 'coffee', 'onions'}: 2
# {'yogurt', 'onions'}: 3
# {'coffee', 'yogurt', 'onions'}: 2
# {'yogurt', 'eggs', 'onions'}: 2
# {'coffee', 'yogurt', 'eggs', 'onions'}: 2
# {'apples', 'onions'}: 4
# {'apples', 'eggs', 'onions'}: 2
# {'apples', 'potatoes', 'onions'}: 2
# {'eggs', 'apples', 'potatoes', 'onions'}: 2
# {'apples', 'tomatoes', 'onions'}: 2
# {'apples', 'sugar', 'onions'}: 2
# {'apples', 'sugar', 'tomatoes', 'onions'}: 2
# {'cheese', 'apples', 'onions'}: 3
# {'tomatoes'}: 27
# {'cereal', 'tomatoes'}: 7
# {'coffee', 'cereal', 'tomatoes'}: 2
# {'potatoes', 'tomatoes'}: 9
# {'potatoes', 'cereal', 'tomatoes'}: 2
# {'coffee', 'potatoes', 'tomatoes'}: 2
# {'potatoes', 'tomatoes', 'eggs'}: 2
# {'bananas', 'potatoes', 'tomatoes'}: 4
# {'oranges', 'potatoes', 'tomatoes'}: 3
# {'oranges', 'bananas', 'potatoes', 'tomatoes'}: 2
# {'bananas', 'tomatoes'}: 8
# {'tomatoes', 'eggs'}: 8
# {'bananas', 'tomatoes', 'eggs'}: 4
# {'coffee', 'tomatoes'}: 5
# {'oranges', 'tomatoes'}: 5
# {'oranges', 'bananas', 'tomatoes'}: 2
# {'oranges', 'cereal', 'tomatoes'}: 2
# {'cheese', 'tomatoes'}: 6
# {'oranges', 'cheese', 'tomatoes'}: 3
# {'cheese', 'cereal', 'tomatoes'}: 2
# {'bananas'}: 37
# {'coffee'}: 33
# {'bananas', 'coffee'}: 6
# {'sugar'}: 26
# {'bananas', 'sugar'}: 7
# {'coffee', 'sugar'}: 8
# {'oranges', 'sugar'}: 2
# {'oranges', 'sugar', 'bananas'}: 2
# {'potatoes', 'sugar'}: 6
# {'bananas', 'potatoes', 'sugar'}: 2
# {'coffee', 'potatoes', 'sugar'}: 3
# {'oranges', 'potatoes', 'sugar'}: 2
# {'oranges', 'potatoes', 'sugar', 'bananas'}: 2
# {'sugar', 'eggs'}: 4
# {'sugar', 'tomatoes'}: 9
# {'potatoes', 'sugar', 'tomatoes'}: 3
# {'sugar', 'tomatoes', 'eggs'}: 3
# {'coffee', 'sugar', 'tomatoes'}: 2
# {'bananas', 'sugar', 'tomatoes'}: 3
# {'cheese', 'sugar', 'tomatoes'}: 3
# {'cheese', 'sugar'}: 6
# {'bananas', 'cheese', 'sugar'}: 2
# {'coffee', 'cheese', 'sugar'}: 2
# {'cheese', 'sugar', 'cereal'}: 2
# {'coffee', 'cheese', 'sugar', 'cereal'}: 2
# {'sugar', 'cereal'}: 2
# {'coffee', 'sugar', 'cereal'}: 2
# {'bread'}: 23
# {'bananas', 'bread'}: 7
# {'coffee', 'bread'}: 11
# {'bananas', 'coffee', 'bread'}: 2
# {'oranges', 'bread'}: 9
# {'oranges', 'bread', 'bananas'}: 5
# {'oranges', 'coffee', 'bread'}: 4
# {'oranges', 'coffee', 'bread', 'bananas'}: 2
# {'oranges', 'bread', 'cereal'}: 2
# {'oranges', 'coffee', 'bread', 'cereal'}: 2
# {'bread', 'potatoes'}: 9
# {'bananas', 'bread', 'potatoes'}: 4
# {'coffee', 'bread', 'potatoes'}: 4
# {'oranges', 'bread', 'potatoes'}: 5
# {'oranges', 'bread', 'bananas', 'potatoes'}: 3
# {'oranges', 'coffee', 'bread', 'potatoes'}: 2
# {'bread', 'cereal', 'potatoes'}: 3
# {'coffee', 'bread', 'cereal', 'potatoes'}: 2
# {'bread', 'sugar'}: 5
# {'coffee', 'bread', 'sugar'}: 3
# {'bread', 'sugar', 'potatoes'}: 3
# {'coffee', 'bread', 'sugar', 'potatoes'}: 2
# {'bread', 'sugar', 'tomatoes'}: 2
# {'cheese', 'bread', 'sugar'}: 2
# {'bread', 'cereal'}: 6
# {'coffee', 'bread', 'cereal'}: 5
# {'bananas', 'bread', 'cereal'}: 2
# {'bread', 'tomatoes'}: 5
# {'bread', 'tomatoes', 'potatoes'}: 3
# {'oranges', 'bread', 'tomatoes', 'potatoes'}: 2
# {'oranges', 'bread', 'tomatoes'}: 2
# {'coffee', 'bread', 'tomatoes'}: 2
# {'apples', 'bread'}: 7
# {'apples', 'bread', 'potatoes'}: 2
# {'apples', 'bread', 'tomatoes'}: 2
# {'apples', 'bread', 'sugar'}: 4
# {'apples', 'bread', 'sugar', 'potatoes'}: 2
# {'apples', 'bread', 'sugar', 'tomatoes'}: 2
# {'apples', 'cheese', 'bread', 'sugar'}: 2
# {'apples', 'coffee', 'bread', 'sugar'}: 2
# {'apples', 'cheese', 'bread'}: 2
# {'apples', 'bread', 'coffee'}: 2
# {'apples', 'bread', 'yogurt'}: 3
# {'apples', 'coffee', 'bread', 'yogurt'}: 2
# {'sugar', 'apples', 'bread', 'yogurt'}: 2
# {'bread', 'yogurt', 'apples', 'coffee', 'sugar'}: 2
# {'milk', 'bread'}: 6
# {'milk', 'bread', 'bananas'}: 3
# {'milk', 'oranges', 'bread'}: 4
# {'milk', 'oranges', 'bread', 'bananas'}: 3
# {'milk', 'bread', 'potatoes'}: 2
# {'milk', 'bread', 'bananas', 'potatoes'}: 2
# {'milk', 'oranges', 'bread', 'potatoes'}: 2
# {'milk', 'oranges', 'bread', 'potatoes', 'bananas'}: 2
# {'milk', 'coffee', 'bread'}: 3
# {'milk', 'bread', 'yogurt'}: 2
# {'milk', 'coffee', 'bread', 'yogurt'}: 2
# {'milk', 'cheese', 'bread'}: 2
# {'milk', 'butter', 'bread'}: 3
# {'milk', 'butter', 'cheese', 'bread'}: 2
# {'milk', 'butter', 'bread', 'bananas'}: 2
# {'milk', 'butter', 'oranges', 'bread'}: 2
# {'milk', 'oranges', 'bread', 'bananas', 'butter'}: 2
# {'bread', 'yogurt'}: 6
# {'coffee', 'bread', 'yogurt'}: 4
# {'oranges', 'bread', 'yogurt'}: 3
# {'oranges', 'coffee', 'bread', 'yogurt'}: 2
# {'bread', 'yogurt', 'eggs'}: 2
# {'oranges', 'bread', 'yogurt', 'eggs'}: 2
# {'bread', 'yogurt', 'potatoes'}: 2
# {'bread', 'yogurt', 'cereal'}: 2
# {'coffee', 'bread', 'yogurt', 'cereal'}: 2
# {'cheese', 'bread', 'yogurt'}: 2
# {'coffee', 'cheese', 'bread', 'yogurt'}: 2
# {'cheese', 'bread', 'yogurt', 'cereal'}: 2
# {'cheese', 'bread', 'yogurt', 'coffee', 'cereal'}: 2
# {'sugar', 'bread', 'yogurt'}: 2
# {'sugar', 'coffee', 'bread', 'yogurt'}: 2
# {'bread', 'eggs'}: 2
# {'oranges', 'bread', 'eggs'}: 2
# {'butter', 'bread'}: 8
# {'oranges', 'butter', 'bread'}: 6
# {'oranges', 'butter', 'bread', 'coffee'}: 2
# {'oranges', 'butter', 'bread', 'cereal'}: 2
# {'bread', 'coffee', 'oranges', 'butter', 'cereal'}: 2
# {'oranges', 'butter', 'bread', 'bananas'}: 3
# {'butter', 'bread', 'eggs'}: 2
# {'oranges', 'butter', 'bread', 'eggs'}: 2
# {'butter', 'bread', 'potatoes'}: 4
# {'oranges', 'butter', 'bread', 'potatoes'}: 3
# {'butter', 'bread', 'cereal', 'potatoes'}: 2
# {'bananas', 'butter', 'bread', 'potatoes'}: 2
# {'butter', 'bread', 'yogurt'}: 3
# {'oranges', 'butter', 'bread', 'yogurt'}: 2
# {'butter', 'bread', 'yogurt', 'eggs'}: 2
# {'bread', 'yogurt', 'oranges', 'butter', 'eggs'}: 2
# {'butter', 'coffee', 'bread', 'yogurt'}: 2
# {'butter', 'bread', 'yogurt', 'cereal'}: 2
# {'bread', 'yogurt', 'coffee', 'butter', 'cereal'}: 2
# {'butter', 'cheese', 'bread', 'yogurt'}: 2
# {'cheese', 'bread', 'yogurt', 'coffee', 'butter'}: 2
# {'cheese', 'bread', 'yogurt', 'butter', 'cereal'}: 2
# {'cheese', 'bread', 'yogurt', 'coffee', 'butter', 'cereal'}: 2
# {'butter', 'bread', 'coffee'}: 3
# {'butter', 'bread', 'cereal'}: 4
# {'butter', 'bread', 'coffee', 'cereal'}: 3
# {'bananas', 'butter', 'bread', 'cereal'}: 2
# {'bananas', 'butter', 'bread'}: 4
# {'butter', 'cheese', 'bread'}: 4
# {'bananas', 'butter', 'cheese', 'bread'}: 3
# {'butter', 'cheese', 'bread', 'cereal'}: 3
# {'cheese', 'bread', 'bananas', 'butter', 'cereal'}: 2
# {'cheese', 'bread', 'coffee', 'butter', 'cereal'}: 2
# {'butter', 'cheese', 'bread', 'coffee'}: 2
# {'oranges', 'butter', 'cheese', 'bread'}: 2
# {'cheese', 'bread', 'oranges', 'bananas', 'butter'}: 2
# {'butter', 'apples', 'bread'}: 2
# {'cheese', 'bread'}: 6
# {'bananas', 'cheese', 'bread'}: 3
# {'cheese', 'bread', 'cereal'}: 3
# {'bananas', 'cheese', 'bread', 'cereal'}: 2
# {'coffee', 'cheese', 'bread', 'cereal'}: 2
# {'coffee', 'cheese', 'bread'}: 2
# {'oranges', 'cheese', 'bread'}: 2
# {'oranges', 'cheese', 'bread', 'bananas'}: 2
# {'pasta'}: 23
# {'bananas', 'pasta'}: 8
# {'coffee', 'pasta'}: 9
# {'bananas', 'coffee', 'pasta'}: 4
# {'oranges', 'pasta'}: 3
# {'oranges', 'bananas', 'pasta'}: 2
# {'oranges', 'coffee', 'pasta'}: 2
# {'oranges', 'coffee', 'bananas', 'pasta'}: 2
# {'oranges', 'cereal', 'pasta'}: 2
# {'potatoes', 'pasta'}: 6
# {'bananas', 'potatoes', 'pasta'}: 2
# {'coffee', 'potatoes', 'pasta'}: 2
# {'oranges', 'potatoes', 'pasta'}: 2
# {'potatoes', 'pasta', 'eggs'}: 2
# {'sugar', 'pasta'}: 6
# {'coffee', 'sugar', 'pasta'}: 3
# {'potatoes', 'sugar', 'pasta'}: 4
# {'coffee', 'potatoes', 'sugar', 'pasta'}: 2
# {'sugar', 'tomatoes', 'pasta'}: 2
# {'potatoes', 'sugar', 'tomatoes', 'pasta'}: 2
# {'bread', 'pasta'}: 6
# {'bananas', 'bread', 'pasta'}: 2
# {'coffee', 'bread', 'pasta'}: 4
# {'bananas', 'coffee', 'bread', 'pasta'}: 2
# {'oranges', 'bread', 'pasta'}: 2
# {'oranges', 'bananas', 'bread', 'pasta'}: 2
# {'oranges', 'coffee', 'bread', 'pasta'}: 2
# {'oranges', 'bread', 'pasta', 'bananas', 'coffee'}: 2
# {'bread', 'pasta', 'potatoes'}: 2
# {'bread', 'sugar', 'pasta'}: 3
# {'coffee', 'bread', 'sugar', 'pasta'}: 2
# {'bread', 'sugar', 'pasta', 'potatoes'}: 2
# {'apples', 'bread', 'pasta'}: 3
# {'apples', 'bread', 'sugar', 'pasta'}: 2
# {'bread', 'cereal', 'pasta'}: 2
# {'coffee', 'bread', 'cereal', 'pasta'}: 2
# {'cheese', 'bread', 'pasta'}: 2
# {'coffee', 'cheese', 'bread', 'pasta'}: 2
# {'cheese', 'bread', 'cereal', 'pasta'}: 2
# {'cheese', 'bread', 'pasta', 'coffee', 'cereal'}: 2
# {'bread', 'yogurt', 'pasta'}: 2
# {'coffee', 'bread', 'yogurt', 'pasta'}: 2
# {'bread', 'yogurt', 'cereal', 'pasta'}: 2
# {'bread', 'yogurt', 'pasta', 'coffee', 'cereal'}: 2
# {'cheese', 'bread', 'yogurt', 'pasta'}: 2
# {'cheese', 'bread', 'yogurt', 'pasta', 'coffee'}: 2
# {'cheese', 'bread', 'yogurt', 'pasta', 'cereal'}: 2
# {'cheese', 'bread', 'yogurt', 'pasta', 'coffee', 'cereal'}: 2
# {'butter', 'bread', 'pasta'}: 2
# {'butter', 'bread', 'coffee', 'pasta'}: 2
# {'butter', 'bread', 'cereal', 'pasta'}: 2
# {'bread', 'coffee', 'pasta', 'butter', 'cereal'}: 2
# {'butter', 'cheese', 'bread', 'pasta'}: 2
# {'cheese', 'bread', 'coffee', 'pasta', 'butter'}: 2
# {'cheese', 'bread', 'pasta', 'butter', 'cereal'}: 2
# {'cheese', 'bread', 'coffee', 'pasta', 'butter', 'cereal'}: 2
# {'butter', 'bread', 'yogurt', 'pasta'}: 2
# {'bread', 'yogurt', 'coffee', 'pasta', 'butter'}: 2
# {'bread', 'yogurt', 'pasta', 'butter', 'cereal'}: 2
# {'bread', 'yogurt', 'coffee', 'pasta', 'butter', 'cereal'}: 2
# {'cheese', 'bread', 'yogurt', 'pasta', 'butter'}: 2
# {'cheese', 'bread', 'yogurt', 'coffee', 'pasta', 'butter'}: 2
# {'cheese', 'bread', 'yogurt', 'pasta', 'butter', 'cereal'}: 2
# {'cheese', 'bread', 'yogurt', 'coffee', 'pasta', 'butter', 'cereal'}: 2
# {'milk', 'bread', 'pasta'}: 2
# {'milk', 'coffee', 'bread', 'pasta'}: 2
# {'pasta', 'onions'}: 5
# {'bananas', 'pasta', 'onions'}: 3
# {'coffee', 'pasta', 'onions'}: 3
# {'bananas', 'coffee', 'pasta', 'onions'}: 2
# {'oranges', 'pasta', 'onions'}: 2
# {'potatoes', 'pasta', 'onions'}: 3
# {'coffee', 'potatoes', 'pasta', 'onions'}: 2
# {'oranges', 'potatoes', 'pasta', 'onions'}: 2
# {'eggs', 'potatoes', 'pasta', 'onions'}: 2
# {'sugar', 'pasta', 'onions'}: 2
# {'coffee', 'sugar', 'pasta', 'onions'}: 2
# {'potatoes', 'sugar', 'pasta', 'onions'}: 2
# {'potatoes', 'pasta', 'onions', 'coffee', 'sugar'}: 2
# {'cereal', 'pasta', 'onions'}: 2
# {'cheese', 'pasta', 'onions'}: 2
# {'cheese', 'cereal', 'pasta', 'onions'}: 2
# {'juice', 'pasta', 'onions'}: 2
# {'juice', 'coffee', 'pasta', 'onions'}: 2
# {'eggs', 'pasta', 'onions'}: 2
# {'apples', 'pasta', 'onions'}: 2
# {'eggs', 'apples', 'pasta', 'onions'}: 2
# {'apples', 'potatoes', 'pasta', 'onions'}: 2
# {'potatoes', 'apples', 'pasta', 'onions', 'eggs'}: 2
# {'milk', 'pasta', 'onions'}: 2
# {'milk', 'eggs', 'pasta', 'onions'}: 2
# {'milk', 'potatoes', 'pasta', 'onions'}: 2
# {'potatoes', 'pasta', 'onions', 'milk', 'eggs'}: 2
# {'milk', 'apples', 'pasta', 'onions'}: 2
# {'apples', 'pasta', 'onions', 'milk', 'eggs'}: 2
# {'potatoes', 'apples', 'pasta', 'onions', 'milk'}: 2
# {'potatoes', 'apples', 'pasta', 'onions', 'milk', 'eggs'}: 2
# {'cereal', 'pasta'}: 6
# {'bananas', 'cereal', 'pasta'}: 4
# {'coffee', 'cereal', 'pasta'}: 2
# {'cheese', 'pasta'}: 4
# {'bananas', 'cheese', 'pasta'}: 2
# {'cheese', 'cereal', 'pasta'}: 4
# {'bananas', 'cheese', 'cereal', 'pasta'}: 2
# {'coffee', 'cheese', 'cereal', 'pasta'}: 2
# {'oranges', 'cheese', 'pasta'}: 2
# {'oranges', 'cheese', 'cereal', 'pasta'}: 2
# {'coffee', 'cheese', 'pasta'}: 2
# {'pasta', 'eggs'}: 6
# {'bananas', 'pasta', 'eggs'}: 3
# {'cereal', 'pasta', 'eggs'}: 4
# {'bananas', 'cereal', 'pasta', 'eggs'}: 3
# {'coffee', 'pasta', 'eggs'}: 3
# {'oranges', 'pasta', 'eggs'}: 2
# {'oranges', 'cereal', 'pasta', 'eggs'}: 2
# {'cheese', 'pasta', 'eggs'}: 2
# {'cheese', 'cereal', 'pasta', 'eggs'}: 2
# {'oranges', 'cheese', 'pasta', 'eggs'}: 2
# {'cheese', 'pasta', 'oranges', 'cereal', 'eggs'}: 2
# {'tomatoes', 'pasta'}: 4
# {'potatoes', 'tomatoes', 'pasta'}: 3
# {'tomatoes', 'pasta', 'eggs'}: 2
# {'bananas', 'tomatoes', 'pasta'}: 2
# {'apples', 'pasta'}: 6
# {'apples', 'pasta', 'potatoes'}: 3
# {'eggs', 'apples', 'pasta', 'potatoes'}: 2
# {'apples', 'tomatoes', 'pasta'}: 2
# {'apples', 'tomatoes', 'pasta', 'potatoes'}: 2
# {'apples', 'sugar', 'pasta'}: 4
# {'apples', 'sugar', 'pasta', 'potatoes'}: 2
# {'apples', 'sugar', 'tomatoes', 'pasta'}: 2
# {'potatoes', 'apples', 'pasta', 'sugar', 'tomatoes'}: 2
# {'coffee', 'apples', 'sugar', 'pasta'}: 2
# {'coffee', 'apples', 'pasta'}: 2
# {'apples', 'pasta', 'eggs'}: 2
# {'apples', 'yogurt', 'pasta'}: 2
# {'coffee', 'apples', 'yogurt', 'pasta'}: 2
# {'sugar', 'apples', 'yogurt', 'pasta'}: 2
# {'apples', 'yogurt', 'pasta', 'coffee', 'sugar'}: 2
# {'apples', 'cereal', 'pasta'}: 2
# {'cheese', 'apples', 'pasta'}: 2
# {'cheese', 'apples', 'cereal', 'pasta'}: 2
# {'juice', 'pasta'}: 4
# {'juice', 'bananas', 'pasta'}: 2
# {'juice', 'coffee', 'pasta'}: 4
# {'juice', 'coffee', 'bananas', 'pasta'}: 2
# {'juice', 'pasta', 'eggs'}: 2
# {'juice', 'coffee', 'pasta', 'eggs'}: 2
# {'juice', 'yogurt', 'pasta'}: 2
# {'juice', 'coffee', 'yogurt', 'pasta'}: 2
# {'juice', 'yogurt', 'pasta', 'eggs'}: 2
# {'juice', 'yogurt', 'pasta', 'coffee', 'eggs'}: 2
# {'yogurt', 'pasta'}: 4
# {'coffee', 'yogurt', 'pasta'}: 4
# {'bananas', 'coffee', 'yogurt', 'pasta'}: 2
# {'yogurt', 'pasta', 'eggs'}: 2
# {'coffee', 'yogurt', 'pasta', 'eggs'}: 2
# {'sugar', 'yogurt', 'pasta'}: 2
# {'sugar', 'coffee', 'yogurt', 'pasta'}: 2
# {'bananas', 'yogurt', 'pasta'}: 2
# {'yogurt', 'cereal', 'pasta'}: 2
# {'coffee', 'yogurt', 'cereal', 'pasta'}: 2
# {'cheese', 'yogurt', 'pasta'}: 2
# {'coffee', 'cheese', 'yogurt', 'pasta'}: 2
# {'cheese', 'yogurt', 'cereal', 'pasta'}: 2
# {'cheese', 'yogurt', 'pasta', 'coffee', 'cereal'}: 2
# {'milk', 'pasta'}: 5
# {'milk', 'coffee', 'pasta'}: 3
# {'milk', 'pasta', 'eggs'}: 2
# {'milk', 'potatoes', 'pasta'}: 2
# {'milk', 'potatoes', 'pasta', 'eggs'}: 2
# {'milk', 'sugar', 'pasta'}: 2
# {'milk', 'coffee', 'sugar', 'pasta'}: 2
# {'milk', 'yogurt', 'pasta'}: 2
# {'milk', 'coffee', 'yogurt', 'pasta'}: 2
# {'milk', 'sugar', 'yogurt', 'pasta'}: 2
# {'yogurt', 'pasta', 'milk', 'coffee', 'sugar'}: 2
# {'milk', 'apples', 'pasta'}: 3
# {'milk', 'coffee', 'apples', 'pasta'}: 2
# {'milk', 'apples', 'pasta', 'eggs'}: 2
# {'milk', 'apples', 'pasta', 'potatoes'}: 2
# {'potatoes', 'apples', 'pasta', 'milk', 'eggs'}: 2
# {'milk', 'apples', 'sugar', 'pasta'}: 2
# {'apples', 'pasta', 'milk', 'coffee', 'sugar'}: 2
# {'milk', 'apples', 'yogurt', 'pasta'}: 2
# {'apples', 'yogurt', 'pasta', 'milk', 'coffee'}: 2
# {'apples', 'yogurt', 'pasta', 'milk', 'sugar'}: 2
# {'apples', 'yogurt', 'pasta', 'milk', 'coffee', 'sugar'}: 2
# {'milk', 'apples', 'cereal', 'pasta'}: 2
# {'milk', 'cheese', 'apples', 'pasta'}: 2
# {'cheese', 'apples', 'pasta', 'milk', 'cereal'}: 2
# {'milk', 'cereal', 'pasta'}: 2
# {'milk', 'cheese', 'pasta'}: 2
# {'milk', 'cheese', 'cereal', 'pasta'}: 2
# {'butter', 'pasta'}: 3
# {'butter', 'coffee', 'pasta'}: 2
# {'butter', 'cereal', 'pasta'}: 2
# {'butter', 'coffee', 'cereal', 'pasta'}: 2
# {'butter', 'cheese', 'pasta'}: 2
# {'butter', 'cheese', 'coffee', 'pasta'}: 2
# {'butter', 'cheese', 'cereal', 'pasta'}: 2
# {'cheese', 'coffee', 'pasta', 'butter', 'cereal'}: 2
# {'butter', 'yogurt', 'pasta'}: 2
# {'butter', 'coffee', 'yogurt', 'pasta'}: 2
# {'butter', 'yogurt', 'cereal', 'pasta'}: 2
# {'coffee', 'yogurt', 'pasta', 'butter', 'cereal'}: 2
# {'butter', 'cheese', 'yogurt', 'pasta'}: 2
# {'cheese', 'coffee', 'yogurt', 'pasta', 'butter'}: 2
# {'cheese', 'yogurt', 'pasta', 'butter', 'cereal'}: 2
# {'cheese', 'coffee', 'yogurt', 'pasta', 'butter', 'cereal'}: 2
# {'bananas', 'butter', 'pasta'}: 2
# {'chicken'}: 20
# {'bananas', 'chicken'}: 8
# {'chicken', 'cereal'}: 7
# {'bananas', 'chicken', 'cereal'}: 4
# {'coffee', 'chicken', 'cereal'}: 2
# {'cheese', 'chicken'}: 3
# {'bananas', 'cheese', 'chicken'}: 2
# {'cheese', 'chicken', 'cereal'}: 3
# {'bananas', 'cheese', 'chicken', 'cereal'}: 2
# {'oranges', 'cheese', 'chicken'}: 2
# {'oranges', 'cheese', 'chicken', 'cereal'}: 2
# {'chicken', 'onions'}: 5
# {'bananas', 'chicken', 'onions'}: 2
# {'chicken', 'cereal', 'onions'}: 3
# {'bananas', 'chicken', 'cereal', 'onions'}: 2
# {'cheese', 'chicken', 'onions'}: 2
# {'cheese', 'chicken', 'cereal', 'onions'}: 2
# {'chicken', 'eggs', 'onions'}: 2
# {'potatoes', 'chicken', 'onions'}: 3
# {'potatoes', 'chicken', 'eggs', 'onions'}: 2
# {'potatoes', 'chicken', 'cereal', 'onions'}: 2
# {'apples', 'chicken', 'onions'}: 2
# {'apples', 'chicken', 'eggs', 'onions'}: 2
# {'apples', 'chicken', 'potatoes', 'onions'}: 2
# {'potatoes', 'apples', 'onions', 'chicken', 'eggs'}: 2
# {'milk', 'chicken', 'onions'}: 2
# {'milk', 'chicken', 'eggs', 'onions'}: 2
# {'milk', 'potatoes', 'chicken', 'onions'}: 2
# {'potatoes', 'onions', 'milk', 'chicken', 'eggs'}: 2
# {'milk', 'apples', 'chicken', 'onions'}: 2
# {'apples', 'onions', 'milk', 'chicken', 'eggs'}: 2
# {'potatoes', 'apples', 'onions', 'milk', 'chicken'}: 2
# {'potatoes', 'apples', 'onions', 'milk', 'chicken', 'eggs'}: 2
# {'chicken', 'pasta'}: 8
# {'bananas', 'chicken', 'pasta'}: 3
# {'chicken', 'cereal', 'pasta'}: 3
# {'bananas', 'chicken', 'cereal', 'pasta'}: 2
# {'cheese', 'chicken', 'pasta'}: 3
# {'bananas', 'cheese', 'chicken', 'pasta'}: 2
# {'cheese', 'chicken', 'cereal', 'pasta'}: 3
# {'cheese', 'pasta', 'bananas', 'chicken', 'cereal'}: 2
# {'oranges', 'cheese', 'chicken', 'pasta'}: 2
# {'cheese', 'pasta', 'oranges', 'chicken', 'cereal'}: 2
# {'chicken', 'pasta', 'onions'}: 3
# {'chicken', 'cereal', 'pasta', 'onions'}: 2
# {'cheese', 'chicken', 'pasta', 'onions'}: 2
# {'cheese', 'pasta', 'onions', 'chicken', 'cereal'}: 2
# {'eggs', 'chicken', 'pasta', 'onions'}: 2
# {'potatoes', 'chicken', 'pasta', 'onions'}: 2
# {'potatoes', 'pasta', 'onions', 'chicken', 'eggs'}: 2
# {'apples', 'chicken', 'pasta', 'onions'}: 2
# {'apples', 'pasta', 'onions', 'chicken', 'eggs'}: 2
# {'potatoes', 'apples', 'pasta', 'onions', 'chicken'}: 2
# {'potatoes', 'apples', 'pasta', 'onions', 'chicken', 'eggs'}: 2
# {'milk', 'chicken', 'pasta', 'onions'}: 2
# {'pasta', 'onions', 'milk', 'chicken', 'eggs'}: 2
# {'potatoes', 'pasta', 'onions', 'milk', 'chicken'}: 2
# {'potatoes', 'pasta', 'onions', 'milk', 'chicken', 'eggs'}: 2
# {'apples', 'pasta', 'onions', 'milk', 'chicken'}: 2
# {'apples', 'pasta', 'onions', 'milk', 'chicken', 'eggs'}: 2
# {'apples', 'potatoes', 'pasta', 'onions', 'milk', 'chicken'}: 2
# {'apples', 'potatoes', 'pasta', 'onions', 'milk', 'chicken', 'eggs'}: 2
# {'potatoes', 'chicken', 'pasta'}: 4
# {'potatoes', 'chicken', 'pasta', 'eggs'}: 2
# {'chicken', 'tomatoes', 'pasta'}: 3
# {'potatoes', 'chicken', 'tomatoes', 'pasta'}: 3
# {'sugar', 'chicken', 'pasta'}: 3
# {'sugar', 'potatoes', 'chicken', 'pasta'}: 2
# {'sugar', 'chicken', 'tomatoes', 'pasta'}: 2
# {'potatoes', 'pasta', 'sugar', 'chicken', 'tomatoes'}: 2
# {'apples', 'chicken', 'pasta'}: 4
# {'apples', 'chicken', 'pasta', 'potatoes'}: 3
# {'potatoes', 'apples', 'pasta', 'chicken', 'eggs'}: 2
# {'apples', 'chicken', 'tomatoes', 'pasta'}: 2
# {'potatoes', 'apples', 'pasta', 'chicken', 'tomatoes'}: 2
# {'sugar', 'apples', 'chicken', 'pasta'}: 3
# {'potatoes', 'apples', 'pasta', 'sugar', 'chicken'}: 2
# {'apples', 'pasta', 'sugar', 'chicken', 'tomatoes'}: 2
# {'apples', 'potatoes', 'pasta', 'sugar', 'chicken', 'tomatoes'}: 2
# {'apples', 'chicken', 'pasta', 'eggs'}: 2
# {'bread', 'chicken', 'pasta'}: 2
# {'coffee', 'chicken', 'pasta'}: 2
# {'chicken', 'pasta', 'eggs'}: 3
# {'coffee', 'chicken', 'pasta', 'eggs'}: 2
# {'chicken', 'cereal', 'pasta', 'eggs'}: 2
# {'oranges', 'chicken', 'pasta', 'eggs'}: 2
# {'pasta', 'oranges', 'chicken', 'cereal', 'eggs'}: 2
# {'cheese', 'chicken', 'pasta', 'eggs'}: 2
# {'cheese', 'pasta', 'chicken', 'cereal', 'eggs'}: 2
# {'cheese', 'pasta', 'oranges', 'chicken', 'eggs'}: 2
# {'cheese', 'pasta', 'oranges', 'chicken', 'cereal', 'eggs'}: 2
# {'yogurt', 'chicken', 'pasta'}: 2
# {'yogurt', 'coffee', 'chicken', 'pasta'}: 2
# {'yogurt', 'chicken', 'pasta', 'eggs'}: 2
# {'yogurt', 'pasta', 'coffee', 'chicken', 'eggs'}: 2
# {'milk', 'chicken', 'pasta'}: 2
# {'milk', 'chicken', 'pasta', 'eggs'}: 2
# {'milk', 'potatoes', 'chicken', 'pasta'}: 2
# {'potatoes', 'pasta', 'milk', 'chicken', 'eggs'}: 2
# {'milk', 'apples', 'chicken', 'pasta'}: 2
# {'apples', 'pasta', 'milk', 'chicken', 'eggs'}: 2
# {'potatoes', 'apples', 'pasta', 'milk', 'chicken'}: 2
# {'potatoes', 'apples', 'pasta', 'milk', 'chicken', 'eggs'}: 2
# {'juice', 'chicken', 'pasta'}: 2
# {'juice', 'coffee', 'chicken', 'pasta'}: 2
# {'juice', 'chicken', 'pasta', 'eggs'}: 2
# {'juice', 'pasta', 'coffee', 'chicken', 'eggs'}: 2
# {'juice', 'yogurt', 'chicken', 'pasta'}: 2
# {'juice', 'yogurt', 'pasta', 'coffee', 'chicken'}: 2
# {'juice', 'yogurt', 'pasta', 'chicken', 'eggs'}: 2
# {'juice', 'yogurt', 'pasta', 'coffee', 'chicken', 'eggs'}: 2
# {'oranges', 'chicken', 'pasta'}: 2
# {'oranges', 'chicken', 'cereal', 'pasta'}: 2
# {'butter', 'chicken', 'pasta'}: 2
# {'bananas', 'butter', 'chicken', 'pasta'}: 2
# {'chicken', 'eggs'}: 4
# {'bananas', 'chicken', 'eggs'}: 2
# {'coffee', 'chicken', 'eggs'}: 2
# {'chicken', 'cereal', 'eggs'}: 2
# {'oranges', 'chicken', 'eggs'}: 2
# {'oranges', 'chicken', 'cereal', 'eggs'}: 2
# {'cheese', 'chicken', 'eggs'}: 2
# {'cheese', 'chicken', 'cereal', 'eggs'}: 2
# {'oranges', 'cheese', 'chicken', 'eggs'}: 2
# {'cheese', 'oranges', 'chicken', 'cereal', 'eggs'}: 2
# {'chicken', 'tomatoes'}: 7
# {'bananas', 'chicken', 'tomatoes'}: 2
# {'chicken', 'tomatoes', 'eggs'}: 2
# {'potatoes', 'chicken', 'tomatoes'}: 5
# {'coffee', 'potatoes', 'chicken', 'tomatoes'}: 2
# {'coffee', 'chicken', 'tomatoes'}: 2
# {'chicken', 'cereal', 'tomatoes'}: 2
# {'butter', 'chicken'}: 7
# {'bananas', 'butter', 'chicken'}: 4
# {'butter', 'chicken', 'eggs'}: 2
# {'bananas', 'butter', 'chicken', 'eggs'}: 2
# {'butter', 'chicken', 'tomatoes'}: 4
# {'bananas', 'butter', 'chicken', 'tomatoes'}: 2
# {'butter', 'potatoes', 'chicken', 'tomatoes'}: 3
# {'butter', 'coffee', 'chicken'}: 2
# {'butter', 'chicken', 'cereal'}: 2
# {'butter', 'coffee', 'chicken', 'cereal'}: 2
# {'oranges', 'butter', 'chicken'}: 4
# {'oranges', 'butter', 'coffee', 'chicken'}: 2
# {'oranges', 'butter', 'chicken', 'cereal'}: 2
# {'coffee', 'oranges', 'butter', 'chicken', 'cereal'}: 2
# {'oranges', 'butter', 'chicken', 'bananas'}: 2
# {'butter', 'potatoes', 'chicken'}: 4
# {'oranges', 'butter', 'potatoes', 'chicken'}: 2
# {'bananas', 'butter', 'potatoes', 'chicken'}: 2
# {'potatoes', 'chicken'}: 8
# {'coffee', 'potatoes', 'chicken'}: 2
# {'potatoes', 'chicken', 'eggs'}: 2
# {'potatoes', 'chicken', 'cereal'}: 3
# {'oranges', 'potatoes', 'chicken'}: 3
# {'oranges', 'potatoes', 'chicken', 'cereal'}: 2
# {'bananas', 'potatoes', 'chicken'}: 3
# {'sugar', 'chicken'}: 3
# {'sugar', 'potatoes', 'chicken'}: 2
# {'sugar', 'chicken', 'tomatoes'}: 2
# {'sugar', 'potatoes', 'chicken', 'tomatoes'}: 2
# {'apples', 'chicken'}: 5
# {'apples', 'chicken', 'potatoes'}: 3
# {'apples', 'chicken', 'eggs', 'potatoes'}: 2
# {'apples', 'chicken', 'tomatoes'}: 2
# {'apples', 'chicken', 'tomatoes', 'potatoes'}: 2
# {'sugar', 'apples', 'chicken'}: 3
# {'sugar', 'apples', 'chicken', 'potatoes'}: 2
# {'sugar', 'apples', 'chicken', 'tomatoes'}: 2
# {'potatoes', 'apples', 'sugar', 'chicken', 'tomatoes'}: 2
# {'apples', 'chicken', 'eggs'}: 2
# {'oranges', 'apples', 'chicken'}: 2
# {'bread', 'chicken'}: 6
# {'bread', 'chicken', 'potatoes'}: 3
# {'oranges', 'bread', 'chicken', 'potatoes'}: 2
# {'bread', 'chicken', 'tomatoes'}: 2
# {'bread', 'chicken', 'tomatoes', 'potatoes'}: 2
# {'apples', 'bread', 'chicken'}: 2
# {'coffee', 'bread', 'chicken'}: 2
# {'bread', 'chicken', 'cereal'}: 2
# {'coffee', 'bread', 'chicken', 'cereal'}: 2
# {'oranges', 'bread', 'chicken'}: 4
# {'oranges', 'coffee', 'bread', 'chicken'}: 2
# {'oranges', 'bread', 'chicken', 'cereal'}: 2
# {'bread', 'oranges', 'coffee', 'chicken', 'cereal'}: 2
# {'oranges', 'bread', 'chicken', 'bananas'}: 2
# {'butter', 'bread', 'chicken'}: 4
# {'butter', 'coffee', 'bread', 'chicken'}: 2
# {'butter', 'bread', 'chicken', 'cereal'}: 2
# {'bread', 'coffee', 'butter', 'chicken', 'cereal'}: 2
# {'oranges', 'butter', 'bread', 'chicken'}: 4
# {'bread', 'coffee', 'oranges', 'butter', 'chicken'}: 2
# {'bread', 'oranges', 'butter', 'chicken', 'cereal'}: 2
# {'bread', 'coffee', 'oranges', 'butter', 'chicken', 'cereal'}: 2
# {'oranges', 'bread', 'bananas', 'butter', 'chicken'}: 2
# {'butter', 'bread', 'chicken', 'potatoes'}: 2
# {'bread', 'potatoes', 'oranges', 'butter', 'chicken'}: 2
# {'bananas', 'butter', 'bread', 'chicken'}: 2
# {'bananas', 'bread', 'chicken'}: 3
# {'coffee', 'chicken'}: 3
# {'yogurt', 'chicken'}: 3
# {'yogurt', 'coffee', 'chicken'}: 2
# {'yogurt', 'chicken', 'eggs'}: 2
# {'yogurt', 'coffee', 'chicken', 'eggs'}: 2
# {'oranges', 'yogurt', 'chicken'}: 2
# {'milk', 'chicken'}: 3
# {'milk', 'chicken', 'eggs'}: 2
# {'milk', 'potatoes', 'chicken'}: 3
# {'milk', 'potatoes', 'chicken', 'eggs'}: 2
# {'milk', 'oranges', 'potatoes', 'chicken'}: 2
# {'milk', 'apples', 'chicken'}: 2
# {'milk', 'apples', 'chicken', 'eggs'}: 2
# {'milk', 'apples', 'chicken', 'potatoes'}: 2
# {'potatoes', 'apples', 'milk', 'chicken', 'eggs'}: 2
# {'milk', 'oranges', 'chicken'}: 2
# {'juice', 'chicken'}: 5
# {'juice', 'coffee', 'chicken'}: 3
# {'juice', 'chicken', 'eggs'}: 2
# {'juice', 'coffee', 'chicken', 'eggs'}: 2
# {'juice', 'potatoes', 'chicken'}: 3
# {'juice', 'coffee', 'potatoes', 'chicken'}: 2
# {'juice', 'oranges', 'potatoes', 'chicken'}: 2
# {'juice', 'chicken', 'tomatoes'}: 2
# {'juice', 'coffee', 'chicken', 'tomatoes'}: 2
# {'juice', 'potatoes', 'chicken', 'tomatoes'}: 2
# {'juice', 'potatoes', 'coffee', 'chicken', 'tomatoes'}: 2
# {'juice', 'yogurt', 'chicken'}: 2
# {'juice', 'yogurt', 'coffee', 'chicken'}: 2
# {'juice', 'yogurt', 'chicken', 'eggs'}: 2
# {'juice', 'yogurt', 'coffee', 'chicken', 'eggs'}: 2
# {'juice', 'milk', 'chicken'}: 2
# {'juice', 'milk', 'chicken', 'potatoes'}: 2
# {'juice', 'chicken', 'cereal'}: 2
# {'juice', 'coffee', 'chicken', 'cereal'}: 2
# {'juice', 'oranges', 'chicken'}: 3
# {'juice', 'coffee', 'oranges', 'chicken'}: 2
# {'juice', 'oranges', 'chicken', 'cereal'}: 2
# {'juice', 'oranges', 'coffee', 'chicken', 'cereal'}: 2
# {'juice', 'oranges', 'chicken', 'bananas'}: 2
# {'juice', 'butter', 'chicken'}: 3
# {'juice', 'butter', 'coffee', 'chicken'}: 2
# {'juice', 'butter', 'chicken', 'cereal'}: 2
# {'juice', 'coffee', 'butter', 'chicken', 'cereal'}: 2
# {'juice', 'butter', 'oranges', 'chicken'}: 3
# {'juice', 'coffee', 'oranges', 'butter', 'chicken'}: 2
# {'juice', 'oranges', 'butter', 'chicken', 'cereal'}: 2
# {'juice', 'coffee', 'oranges', 'butter', 'chicken', 'cereal'}: 2
# {'juice', 'oranges', 'bananas', 'butter', 'chicken'}: 2
# {'juice', 'butter', 'potatoes', 'chicken'}: 2
# {'juice', 'potatoes', 'oranges', 'butter', 'chicken'}: 2
# {'juice', 'butter', 'chicken', 'bananas'}: 2
# {'juice', 'bread', 'chicken'}: 4
# {'juice', 'coffee', 'bread', 'chicken'}: 2
# {'juice', 'bread', 'chicken', 'cereal'}: 2
# {'juice', 'bread', 'coffee', 'chicken', 'cereal'}: 2
# {'juice', 'oranges', 'bread', 'chicken'}: 3
# {'juice', 'bread', 'oranges', 'coffee', 'chicken'}: 2
# {'juice', 'bread', 'oranges', 'chicken', 'cereal'}: 2
# {'juice', 'bread', 'oranges', 'coffee', 'chicken', 'cereal'}: 2
# {'juice', 'oranges', 'bread', 'bananas', 'chicken'}: 2
# {'juice', 'bread', 'chicken', 'potatoes'}: 2
# {'juice', 'bread', 'potatoes', 'oranges', 'chicken'}: 2
# {'juice', 'butter', 'bread', 'chicken'}: 3
# {'juice', 'bread', 'coffee', 'butter', 'chicken'}: 2
# {'juice', 'bread', 'butter', 'chicken', 'cereal'}: 2
# {'juice', 'bread', 'coffee', 'butter', 'chicken', 'cereal'}: 2
# {'juice', 'bread', 'oranges', 'butter', 'chicken'}: 3
# {'juice', 'bread', 'coffee', 'oranges', 'butter', 'chicken'}: 2
# {'juice', 'bread', 'oranges', 'butter', 'chicken', 'cereal'}: 2
# {'juice', 'bread', 'coffee', 'oranges', 'butter', 'chicken', 'cereal'}: 2
# {'juice', 'bread', 'bananas', 'oranges', 'butter', 'chicken'}: 2
# {'juice', 'bread', 'potatoes', 'butter', 'chicken'}: 2
# {'juice', 'bread', 'potatoes', 'oranges', 'butter', 'chicken'}: 2
# {'juice', 'bread', 'bananas', 'butter', 'chicken'}: 2
# {'juice', 'bread', 'chicken', 'bananas'}: 3
# {'juice', 'chicken', 'bananas'}: 3
# {'tea', 'chicken'}: 2
# {'sugar', 'tea', 'chicken'}: 2
# {'apples', 'tea', 'chicken'}: 2
# {'sugar', 'apples', 'tea', 'chicken'}: 2
# {'tea', 'chicken', 'pasta'}: 2
# {'sugar', 'tea', 'chicken', 'pasta'}: 2
# {'apples', 'tea', 'chicken', 'pasta'}: 2
# {'tea', 'apples', 'pasta', 'sugar', 'chicken'}: 2
# {'oranges', 'chicken'}: 6
# {'oranges', 'coffee', 'chicken'}: 2
# {'oranges', 'chicken', 'cereal'}: 3
# {'oranges', 'coffee', 'chicken', 'cereal'}: 2
# {'oranges', 'chicken', 'bananas'}: 2
# {'cheese'}: 28
# {'bananas', 'cheese'}: 8
# {'cheese', 'cereal'}: 12
# {'bananas', 'cheese', 'cereal'}: 3
# {'coffee', 'cheese', 'cereal'}: 5
# {'oranges', 'cheese'}: 9
# {'oranges', 'cheese', 'bananas'}: 3
# {'oranges', 'cheese', 'cereal'}: 4
# {'oranges', 'coffee', 'cheese', 'cereal'}: 2
# {'oranges', 'coffee', 'cheese'}: 3
# {'coffee', 'cheese'}: 7
# {'bananas', 'coffee', 'cheese'}: 2
# {'tea'}: 23
# {'bananas', 'tea'}: 5
# {'tea', 'cereal'}: 6
# {'bananas', 'tea', 'cereal'}: 2
# {'coffee', 'tea', 'cereal'}: 2
# {'tea', 'eggs'}: 4
# {'bananas', 'tea', 'eggs'}: 2
# {'coffee', 'tea', 'eggs'}: 2
# {'tea', 'pasta'}: 6
# {'bananas', 'tea', 'pasta'}: 2
# {'tea', 'cereal', 'pasta'}: 2
# {'tea', 'pasta', 'eggs'}: 2
# {'coffee', 'tea', 'pasta'}: 4
# {'juice', 'tea', 'pasta'}: 3
# {'juice', 'coffee', 'tea', 'pasta'}: 3
# {'tea', 'pasta', 'onions'}: 2
# {'coffee', 'tea', 'pasta', 'onions'}: 2
# {'juice', 'tea', 'pasta', 'onions'}: 2
# {'juice', 'tea', 'pasta', 'onions', 'coffee'}: 2
# {'tea', 'sugar', 'pasta'}: 3
# {'coffee', 'tea', 'sugar', 'pasta'}: 2
# {'tea', 'yogurt', 'pasta'}: 2
# {'coffee', 'tea', 'yogurt', 'pasta'}: 2
# {'sugar', 'tea', 'yogurt', 'pasta'}: 2
# {'tea', 'yogurt', 'pasta', 'coffee', 'sugar'}: 2
# {'apples', 'tea', 'pasta'}: 3
# {'apples', 'tea', 'coffee', 'pasta'}: 2
# {'apples', 'tea', 'sugar', 'pasta'}: 3
# {'tea', 'apples', 'pasta', 'coffee', 'sugar'}: 2
# {'apples', 'tea', 'yogurt', 'pasta'}: 2
# {'tea', 'yogurt', 'apples', 'pasta', 'coffee'}: 2
# {'tea', 'yogurt', 'apples', 'pasta', 'sugar'}: 2
# {'tea', 'yogurt', 'apples', 'pasta', 'coffee', 'sugar'}: 2
# {'milk', 'tea', 'pasta'}: 2
# {'milk', 'coffee', 'tea', 'pasta'}: 2
# {'milk', 'tea', 'sugar', 'pasta'}: 2
# {'tea', 'pasta', 'milk', 'coffee', 'sugar'}: 2
# {'milk', 'tea', 'yogurt', 'pasta'}: 2
# {'tea', 'yogurt', 'pasta', 'milk', 'coffee'}: 2
# {'tea', 'yogurt', 'pasta', 'milk', 'sugar'}: 2
# {'tea', 'yogurt', 'pasta', 'milk', 'coffee', 'sugar'}: 2
# {'milk', 'apples', 'tea', 'pasta'}: 2
# {'tea', 'apples', 'pasta', 'milk', 'coffee'}: 2
# {'tea', 'apples', 'pasta', 'milk', 'sugar'}: 2
# {'tea', 'apples', 'pasta', 'milk', 'coffee', 'sugar'}: 2
# {'tea', 'yogurt', 'apples', 'pasta', 'milk'}: 2
# {'tea', 'yogurt', 'apples', 'pasta', 'milk', 'coffee'}: 2
# {'tea', 'yogurt', 'apples', 'pasta', 'milk', 'sugar'}: 2
# {'tea', 'yogurt', 'apples', 'pasta', 'milk', 'coffee', 'sugar'}: 2
# {'coffee', 'tea'}: 8
# {'bananas', 'coffee', 'tea'}: 2
# {'juice', 'tea'}: 8
# {'juice', 'tea', 'bananas'}: 2
# {'juice', 'coffee', 'tea'}: 5
# {'juice', 'coffee', 'tea', 'bananas'}: 2
# {'juice', 'tea', 'cereal'}: 2
# {'juice', 'butter', 'tea'}: 3
# {'juice', 'tea', 'eggs'}: 2
# {'juice', 'coffee', 'tea', 'eggs'}: 2
# {'juice', 'tea', 'potatoes'}: 3
# {'juice', 'coffee', 'tea', 'potatoes'}: 3
# {'juice', 'tea', 'eggs', 'potatoes'}: 2
# {'juice', 'tea', 'potatoes', 'coffee', 'eggs'}: 2
# {'juice', 'tea', 'yogurt'}: 2
# {'juice', 'cheese', 'tea'}: 2
# {'tea', 'onions'}: 6
# {'bananas', 'tea', 'onions'}: 2
# {'coffee', 'tea', 'onions'}: 3
# {'juice', 'tea', 'onions'}: 2
# {'juice', 'coffee', 'tea', 'onions'}: 2
# {'tea', 'potatoes', 'onions'}: 2
# {'coffee', 'tea', 'potatoes', 'onions'}: 2
# {'tea', 'sugar', 'onions'}: 2
# {'apples', 'tea', 'onions'}: 2
# {'milk', 'tea', 'onions'}: 2
# {'cheese', 'tea', 'onions'}: 2
# {'tea', 'bread', 'onions'}: 2
# {'butter', 'tea'}: 8
# {'butter', 'tea', 'cereal'}: 3
# {'oranges', 'butter', 'tea'}: 2
# {'butter', 'tea', 'eggs'}: 2
# {'butter', 'tea', 'potatoes'}: 3
# {'butter', 'tea', 'eggs', 'potatoes'}: 2
# {'bananas', 'butter', 'tea', 'potatoes'}: 2
# {'butter', 'cheese', 'tea', 'potatoes'}: 2
# {'cheese', 'tea', 'potatoes', 'bananas', 'butter'}: 2
# {'butter', 'tea', 'yogurt'}: 2
# {'bananas', 'butter', 'tea'}: 3
# {'butter', 'cheese', 'tea'}: 4
# {'bananas', 'butter', 'cheese', 'tea'}: 3
# {'butter', 'cheese', 'tea', 'cereal'}: 2
# {'butter', 'cheese', 'tea', 'coffee'}: 2
# {'butter', 'tea', 'coffee'}: 2
# {'tea', 'potatoes'}: 6
# {'coffee', 'tea', 'potatoes'}: 4
# {'tea', 'eggs', 'potatoes'}: 3
# {'coffee', 'tea', 'eggs', 'potatoes'}: 2
# {'bananas', 'tea', 'potatoes'}: 2
# {'tea', 'cereal', 'potatoes'}: 2
# {'cheese', 'tea', 'potatoes'}: 2
# {'bananas', 'cheese', 'tea', 'potatoes'}: 2
# {'tea', 'tomatoes'}: 2
# {'tea', 'sugar'}: 5
# {'coffee', 'tea', 'sugar'}: 3
# {'tea', 'yogurt'}: 6
# {'coffee', 'tea', 'yogurt'}: 2
# {'tea', 'yogurt', 'eggs'}: 2
# {'tea', 'yogurt', 'potatoes'}: 2
# {'tea', 'yogurt', 'eggs', 'potatoes'}: 2
# {'tea', 'yogurt', 'tomatoes'}: 2
# {'sugar', 'tea', 'yogurt'}: 2
# {'sugar', 'coffee', 'tea', 'yogurt'}: 2
# {'oranges', 'tea', 'yogurt'}: 2
# {'cheese', 'tea', 'yogurt'}: 3
# {'cheese', 'tea', 'yogurt', 'cereal'}: 2
# {'tea', 'yogurt', 'cereal'}: 2
# {'apples', 'tea'}: 5
# {'apples', 'tea', 'coffee'}: 2
# {'apples', 'tea', 'tomatoes'}: 2
# {'apples', 'tea', 'sugar'}: 3
# {'apples', 'coffee', 'tea', 'sugar'}: 2
# {'apples', 'tea', 'yogurt'}: 3
# {'apples', 'coffee', 'tea', 'yogurt'}: 2
# {'apples', 'tea', 'yogurt', 'tomatoes'}: 2
# {'sugar', 'apples', 'tea', 'yogurt'}: 2
# {'tea', 'yogurt', 'apples', 'coffee', 'sugar'}: 2
# {'apples', 'cheese', 'tea', 'yogurt'}: 2
# {'apples', 'cheese', 'tea'}: 3
# {'milk', 'tea'}: 5
# {'milk', 'coffee', 'tea'}: 2
# {'milk', 'tea', 'tomatoes'}: 2
# {'milk', 'tea', 'sugar'}: 2
# {'milk', 'coffee', 'tea', 'sugar'}: 2
# {'milk', 'tea', 'yogurt'}: 3
# {'milk', 'coffee', 'tea', 'yogurt'}: 2
# {'milk', 'tea', 'yogurt', 'tomatoes'}: 2
# {'milk', 'sugar', 'tea', 'yogurt'}: 2
# {'tea', 'yogurt', 'milk', 'coffee', 'sugar'}: 2
# {'milk', 'cheese', 'tea', 'yogurt'}: 2
# {'milk', 'apples', 'tea'}: 3
# {'milk', 'apples', 'tea', 'coffee'}: 2
# {'milk', 'apples', 'tea', 'tomatoes'}: 2
# {'milk', 'apples', 'tea', 'sugar'}: 2
# {'tea', 'apples', 'milk', 'coffee', 'sugar'}: 2
# {'milk', 'apples', 'tea', 'yogurt'}: 3
# {'tea', 'yogurt', 'apples', 'milk', 'coffee'}: 2
# {'tea', 'yogurt', 'apples', 'milk', 'tomatoes'}: 2
# {'tea', 'yogurt', 'apples', 'milk', 'sugar'}: 2
# {'tea', 'yogurt', 'apples', 'milk', 'coffee', 'sugar'}: 2
# {'cheese', 'tea', 'yogurt', 'apples', 'milk'}: 2
# {'milk', 'apples', 'cheese', 'tea'}: 2
# {'milk', 'oranges', 'tea'}: 3
# {'milk', 'cheese', 'tea'}: 3
# {'milk', 'cheese', 'tea', 'oranges'}: 2
# {'milk', 'butter', 'tea'}: 2
# {'milk', 'butter', 'cheese', 'tea'}: 2
# {'oranges', 'tea'}: 5
# {'tea', 'bread'}: 5
# {'oranges', 'tea', 'bread'}: 2
# {'tea', 'bread', 'potatoes'}: 3
# {'tea', 'bread', 'cereal', 'potatoes'}: 2
# {'yogurt', 'tea', 'bread'}: 2
# {'butter', 'tea', 'bread'}: 4
# {'oranges', 'butter', 'tea', 'bread'}: 2
# {'butter', 'tea', 'bread', 'potatoes'}: 2
# {'butter', 'tea', 'bread', 'yogurt'}: 2
# {'bananas', 'butter', 'tea', 'bread'}: 2
# {'butter', 'tea', 'bread', 'cereal'}: 2
# {'butter', 'cheese', 'tea', 'bread'}: 3
# {'cheese', 'tea', 'bread', 'bananas', 'butter'}: 2
# {'cheese', 'tea', 'bread', 'butter', 'cereal'}: 2
# {'bananas', 'tea', 'bread'}: 2
# {'tea', 'bread', 'cereal'}: 3
# {'coffee', 'tea', 'bread', 'cereal'}: 2
# {'cheese', 'tea', 'bread'}: 3
# {'bananas', 'cheese', 'tea', 'bread'}: 2
# {'cheese', 'tea', 'bread', 'cereal'}: 2
# {'coffee', 'tea', 'bread'}: 2
# {'milk', 'tea', 'bread'}: 2
# {'milk', 'cheese', 'tea', 'bread'}: 2
# {'milk', 'butter', 'tea', 'bread'}: 2
# {'cheese', 'tea', 'bread', 'milk', 'butter'}: 2
# {'cheese', 'tea'}: 7
# {'oranges', 'cheese', 'tea'}: 2
# {'cheese', 'tea', 'cereal'}: 3
# {'bananas', 'cheese', 'tea'}: 3
# {'coffee', 'cheese', 'tea'}: 2
# {'yogurt'}: 26
# {'bananas', 'yogurt'}: 7
# {'coffee', 'yogurt'}: 9
# {'bananas', 'coffee', 'yogurt'}: 2
# {'yogurt', 'eggs'}: 5
# {'coffee', 'yogurt', 'eggs'}: 3
# {'oranges', 'yogurt', 'eggs'}: 2
# {'yogurt', 'cereal', 'eggs'}: 2
# {'coffee', 'yogurt', 'cereal', 'eggs'}: 2
# {'cheese', 'yogurt', 'eggs'}: 2
# {'coffee', 'cheese', 'yogurt', 'eggs'}: 2
# {'cheese', 'yogurt', 'cereal', 'eggs'}: 2
# {'cheese', 'yogurt', 'coffee', 'cereal', 'eggs'}: 2
# {'bananas', 'yogurt', 'eggs'}: 2
# {'potatoes', 'yogurt'}: 5
# {'coffee', 'potatoes', 'yogurt'}: 3
# {'potatoes', 'yogurt', 'eggs'}: 2
# {'oranges', 'potatoes', 'yogurt'}: 3
# {'cheese', 'potatoes', 'yogurt'}: 2
# {'oranges', 'cheese', 'potatoes', 'yogurt'}: 2
# {'yogurt', 'tomatoes'}: 5
# {'yogurt', 'tomatoes', 'eggs'}: 2
# {'potatoes', 'yogurt', 'tomatoes'}: 2
# {'bananas', 'yogurt', 'tomatoes'}: 3
# {'oranges', 'yogurt', 'tomatoes'}: 2
# {'cheese', 'yogurt', 'tomatoes'}: 2
# {'oranges', 'cheese', 'yogurt', 'tomatoes'}: 2
# {'sugar', 'yogurt'}: 7
# {'sugar', 'coffee', 'yogurt'}: 3
# {'sugar', 'yogurt', 'eggs'}: 2
# {'sugar', 'potatoes', 'yogurt'}: 3
# {'sugar', 'coffee', 'potatoes', 'yogurt'}: 2
# {'sugar', 'yogurt', 'tomatoes'}: 4
# {'sugar', 'yogurt', 'tomatoes', 'eggs'}: 2
# {'sugar', 'potatoes', 'yogurt', 'tomatoes'}: 2
# {'bananas', 'sugar', 'yogurt', 'tomatoes'}: 3
# {'bananas', 'sugar', 'yogurt'}: 3
# {'sugar', 'cheese', 'yogurt'}: 2
# {'oranges', 'yogurt'}: 8
# {'oranges', 'coffee', 'yogurt'}: 4
# {'oranges', 'yogurt', 'bananas'}: 2
# {'cheese', 'yogurt'}: 7
# {'bananas', 'cheese', 'yogurt'}: 2
# {'oranges', 'cheese', 'yogurt'}: 4
# {'oranges', 'cheese', 'yogurt', 'bananas'}: 2
# {'oranges', 'coffee', 'cheese', 'yogurt'}: 2
# {'cheese', 'yogurt', 'cereal'}: 4
# {'coffee', 'cheese', 'yogurt', 'cereal'}: 3
# {'coffee', 'cheese', 'yogurt'}: 4
# {'yogurt', 'cereal'}: 4
# {'coffee', 'yogurt', 'cereal'}: 3
# {'juice'}: 23
# {'juice', 'eggs'}: 7
# {'juice', 'coffee', 'eggs'}: 3
# {'juice', 'coffee', 'bananas', 'eggs'}: 2
# {'juice', 'bananas', 'eggs'}: 3
# {'juice', 'cheese', 'eggs'}: 3
# {'juice', 'cheese', 'bananas', 'eggs'}: 2
# {'juice', 'coffee', 'cheese', 'eggs'}: 2
# {'juice', 'cheese', 'bananas', 'coffee', 'eggs'}: 2
# {'juice', 'tomatoes'}: 5
# {'juice', 'tomatoes', 'eggs'}: 3
# {'juice', 'coffee', 'tomatoes'}: 2
# {'juice', 'potatoes', 'tomatoes'}: 4
# {'juice', 'coffee', 'potatoes', 'tomatoes'}: 2
# {'juice', 'potatoes', 'tomatoes', 'eggs'}: 2
# {'juice', 'bananas', 'potatoes', 'tomatoes'}: 2
# {'juice', 'oranges', 'potatoes', 'tomatoes'}: 2
# {'juice', 'bananas', 'tomatoes'}: 2
# {'juice', 'oranges', 'tomatoes'}: 2
# {'juice', 'sugar'}: 4
# {'juice', 'sugar', 'eggs'}: 2
# {'juice', 'sugar', 'tomatoes'}: 3
# {'juice', 'sugar', 'tomatoes', 'eggs'}: 2
# {'juice', 'potatoes', 'sugar', 'tomatoes'}: 2
# {'juice', 'coffee', 'sugar'}: 2
# {'juice', 'potatoes', 'sugar'}: 3
# {'juice', 'coffee', 'potatoes', 'sugar'}: 2
# {'juice', 'butter'}: 8
# {'juice', 'butter', 'eggs'}: 4
# {'juice', 'butter', 'bananas', 'eggs'}: 3
# {'juice', 'butter', 'coffee', 'eggs'}: 2
# {'juice', 'coffee', 'bananas', 'butter', 'eggs'}: 2
# {'juice', 'butter', 'cheese', 'eggs'}: 2
# {'juice', 'cheese', 'bananas', 'butter', 'eggs'}: 2
# {'juice', 'cheese', 'coffee', 'butter', 'eggs'}: 2
# {'juice', 'cheese', 'coffee', 'bananas', 'butter', 'eggs'}: 2
# {'juice', 'butter', 'tomatoes'}: 3
# {'juice', 'butter', 'tomatoes', 'eggs'}: 2
# {'juice', 'butter', 'potatoes', 'tomatoes'}: 2
# {'juice', 'butter', 'cereal'}: 3
# {'juice', 'butter', 'coffee', 'cereal'}: 2
# {'juice', 'butter', 'bananas'}: 4
# {'juice', 'butter', 'potatoes'}: 4
# {'juice', 'butter', 'potatoes', 'bananas'}: 3
# {'juice', 'butter', 'potatoes', 'eggs'}: 2
# {'juice', 'potatoes', 'bananas', 'butter', 'eggs'}: 2
# {'juice', 'butter', 'potatoes', 'coffee'}: 2
# {'juice', 'butter', 'oranges', 'potatoes'}: 2
# {'juice', 'butter', 'coffee'}: 3
# {'juice', 'butter', 'coffee', 'bananas'}: 2
# {'juice', 'butter', 'oranges'}: 3
# {'juice', 'butter', 'oranges', 'coffee'}: 2
# {'juice', 'butter', 'oranges', 'cereal'}: 2
# {'juice', 'coffee', 'oranges', 'butter', 'cereal'}: 2
# {'juice', 'butter', 'oranges', 'bananas'}: 2
# {'juice', 'butter', 'cheese'}: 2
# {'juice', 'butter', 'cheese', 'bananas'}: 2
# {'juice', 'butter', 'cheese', 'coffee'}: 2
# {'juice', 'cheese', 'coffee', 'bananas', 'butter'}: 2
# {'juice', 'milk'}: 4
# {'juice', 'milk', 'eggs'}: 3
# {'juice', 'milk', 'tomatoes'}: 3
# {'juice', 'milk', 'tomatoes', 'eggs'}: 3
# {'juice', 'milk', 'tomatoes', 'potatoes'}: 2
# {'juice', 'potatoes', 'milk', 'tomatoes', 'eggs'}: 2
# {'juice', 'milk', 'sugar'}: 2
# {'juice', 'milk', 'sugar', 'eggs'}: 2
# {'juice', 'milk', 'sugar', 'tomatoes'}: 2
# {'juice', 'milk', 'sugar', 'tomatoes', 'eggs'}: 2
# {'juice', 'butter', 'milk'}: 3
# {'juice', 'butter', 'milk', 'eggs'}: 2
# {'juice', 'butter', 'milk', 'tomatoes'}: 2
# {'juice', 'milk', 'butter', 'tomatoes', 'eggs'}: 2
# {'juice', 'butter', 'milk', 'bananas'}: 2
# {'juice', 'butter', 'milk', 'potatoes'}: 2
# {'juice', 'potatoes', 'bananas', 'milk', 'butter'}: 2
# {'juice', 'milk', 'potatoes'}: 3
# {'juice', 'milk', 'eggs', 'potatoes'}: 2
# {'juice', 'milk', 'bananas', 'potatoes'}: 2
# {'juice', 'milk', 'bananas'}: 2
# {'juice', 'bananas'}: 8
# {'juice', 'coffee'}: 9
# {'juice', 'coffee', 'bananas'}: 3
# {'juice', 'cereal'}: 5
# {'juice', 'coffee', 'cereal'}: 2
# {'juice', 'cereal', 'bananas'}: 2
# {'juice', 'yogurt'}: 6
# {'juice', 'coffee', 'yogurt'}: 3
# {'juice', 'yogurt', 'eggs'}: 2
# {'juice', 'coffee', 'yogurt', 'eggs'}: 2
# {'juice', 'potatoes', 'yogurt'}: 3
# {'juice', 'coffee', 'potatoes', 'yogurt'}: 2
# {'juice', 'yogurt', 'tomatoes'}: 2
# {'juice', 'potatoes', 'yogurt', 'tomatoes'}: 2
# {'juice', 'sugar', 'yogurt'}: 3
# {'juice', 'sugar', 'coffee', 'yogurt'}: 2
# {'juice', 'sugar', 'potatoes', 'yogurt'}: 3
# {'juice', 'potatoes', 'yogurt', 'coffee', 'sugar'}: 2
# {'juice', 'sugar', 'yogurt', 'tomatoes'}: 2
# {'juice', 'potatoes', 'yogurt', 'sugar', 'tomatoes'}: 2
# {'juice', 'yogurt', 'bananas'}: 2
# {'juice', 'oranges', 'yogurt'}: 2
# {'juice', 'oranges', 'yogurt', 'bananas'}: 2
# {'juice', 'cheese', 'yogurt'}: 3
# {'juice', 'cheese', 'yogurt', 'bananas'}: 2
# {'juice', 'cheese', 'yogurt', 'oranges'}: 2
# {'juice', 'cheese', 'oranges', 'yogurt', 'bananas'}: 2
# {'juice', 'cheese', 'yogurt', 'cereal'}: 2
# {'juice', 'yogurt', 'cereal'}: 2
# {'juice', 'potatoes'}: 8
# {'juice', 'coffee', 'potatoes'}: 5
# {'juice', 'potatoes', 'eggs'}: 3
# {'juice', 'coffee', 'potatoes', 'eggs'}: 2
# {'juice', 'potatoes', 'bananas', 'eggs'}: 2
# {'juice', 'potatoes', 'bananas'}: 4
# {'juice', 'oranges', 'potatoes'}: 3
# {'juice', 'oranges', 'potatoes', 'bananas'}: 2
# {'juice', 'cheese', 'potatoes'}: 2
# {'juice', 'cheese', 'potatoes', 'bananas'}: 2
# {'juice', 'apples'}: 2
# {'juice', 'coffee', 'apples'}: 2
# {'juice', 'apples', 'potatoes'}: 2
# {'juice', 'coffee', 'apples', 'potatoes'}: 2
# {'juice', 'apples', 'sugar'}: 2
# {'juice', 'coffee', 'apples', 'sugar'}: 2
# {'juice', 'apples', 'sugar', 'potatoes'}: 2
# {'juice', 'potatoes', 'apples', 'coffee', 'sugar'}: 2
# {'juice', 'apples', 'yogurt'}: 2
# {'juice', 'coffee', 'apples', 'yogurt'}: 2
# {'juice', 'apples', 'yogurt', 'potatoes'}: 2
# {'juice', 'potatoes', 'yogurt', 'apples', 'coffee'}: 2
# {'juice', 'sugar', 'apples', 'yogurt'}: 2
# {'juice', 'apples', 'yogurt', 'coffee', 'sugar'}: 2
# {'juice', 'potatoes', 'yogurt', 'apples', 'sugar'}: 2
# {'juice', 'potatoes', 'yogurt', 'apples', 'coffee', 'sugar'}: 2
# {'juice', 'cheese'}: 5
# {'juice', 'cheese', 'bananas'}: 3
# {'juice', 'cheese', 'oranges'}: 2
# {'juice', 'cheese', 'oranges', 'bananas'}: 2
# {'juice', 'cheese', 'cereal'}: 2
# {'juice', 'coffee', 'cheese'}: 2
# {'juice', 'coffee', 'cheese', 'bananas'}: 2
# {'juice', 'oranges'}: 4
# {'juice', 'oranges', 'bananas'}: 3
# {'juice', 'coffee', 'oranges'}: 2
# {'juice', 'oranges', 'cereal'}: 2
# {'juice', 'coffee', 'oranges', 'cereal'}: 2
# {'juice', 'bread'}: 5
# {'juice', 'coffee', 'bread'}: 3
# {'juice', 'bread', 'cereal'}: 2
# {'juice', 'coffee', 'bread', 'cereal'}: 2
# {'juice', 'oranges', 'bread'}: 3
# {'juice', 'coffee', 'oranges', 'bread'}: 2
# {'juice', 'oranges', 'bread', 'cereal'}: 2
# {'juice', 'bread', 'oranges', 'coffee', 'cereal'}: 2
# {'juice', 'oranges', 'bread', 'bananas'}: 2
# {'juice', 'bread', 'potatoes'}: 3
# {'juice', 'coffee', 'bread', 'potatoes'}: 2
# {'juice', 'oranges', 'bread', 'potatoes'}: 2
# {'juice', 'butter', 'bread'}: 3
# {'juice', 'butter', 'bread', 'coffee'}: 2
# {'juice', 'butter', 'bread', 'cereal'}: 2
# {'juice', 'bread', 'coffee', 'butter', 'cereal'}: 2
# {'juice', 'butter', 'oranges', 'bread'}: 3
# {'juice', 'bread', 'coffee', 'oranges', 'butter'}: 2
# {'juice', 'bread', 'oranges', 'butter', 'cereal'}: 2
# {'juice', 'bread', 'coffee', 'oranges', 'butter', 'cereal'}: 2
# {'juice', 'oranges', 'bread', 'bananas', 'butter'}: 2
# {'juice', 'butter', 'bread', 'potatoes'}: 2
# {'juice', 'bread', 'potatoes', 'oranges', 'butter'}: 2
# {'juice', 'butter', 'bread', 'bananas'}: 2
# {'juice', 'bread', 'yogurt'}: 2
# {'juice', 'coffee', 'bread', 'yogurt'}: 2
# {'juice', 'bread', 'bananas'}: 3

# %% [markdown]
# ## Implementasi Assosiasi

# %%
# mencari aturan asosiasi
from mlxtend.frequent_patterns import association_rules

# Buat aturan asosiasi dengan minimum confidence 0.1
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

print("\nAturan Asosiasi:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])

# Visualisasi scatter plot confidence vs lift
plt.figure(figsize=(8, 5))
sns.scatterplot(data=rules, x='confidence', y='lift', size='support', sizes=(20, 200), alpha=0.7)
plt.title('Confidence vs Lift of Association Rules')
plt.xlabel('Confidence')
plt.ylabel('Lift')
plt.grid(True)
plt.tight_layout()
plt.show()

# Visualisasi top 10 aturan berdasarkan lift
top_rules = rules.nlargest(10, 'lift')
plt.figure(figsize=(10, 6))
y_pos = range(len(top_rules))
plt.barh(y_pos, top_rules['lift'], color='skyblue')
plt.yticks(y_pos, [f"{set(row['antecedents'])} → {set(row['consequents'])}" for _, row in top_rules.iterrows()])
plt.xlabel('Lift')
plt.title('Top 10 Association Rules by Lift')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# Aturan Asosiasi:
#                          antecedents  \
# 0        (oranges, potatoes, cereal)
# 1         (coffee, potatoes, cereal)
# 2                 (bananas, oranges)
# 3                (bananas, potatoes)
# 4                (oranges, potatoes)
# ...                              ...
# 1838664        (juice, yogurt, eggs)
# 1838665      (bananas, yogurt, eggs)
# 1838666    (bananas, butter, coffee)
# 1838667      (bananas, coffee, eggs)
# 1838668                (bread, eggs)
#
#                                       consequents   support  confidence  \
# 0                                        (coffee)  0.006536       0.500
# 1                                       (oranges)  0.006536       0.500
# 2                                      (potatoes)  0.032680       0.625
# 3                                       (oranges)  0.032680       0.500
# 4                                       (bananas)  0.032680       0.500
# ...                                           ...       ...         ...
# 1838664          (bananas, butter, bread, coffee)  0.006536       0.500
# 1838665            (juice, butter, bread, coffee)  0.006536       0.500
# 1838666              (juice, bread, yogurt, eggs)  0.006536       0.500
# 1838667            (juice, butter, bread, yogurt)  0.006536       0.500
# 1838668  (yogurt, butter, coffee, juice, bananas)  0.006536       0.500
#
#               lift
# 0         2.318182
# 1         2.637931
# 2         3.541667
# 3         2.637931
# 4         2.067568
# ...            ...
# 1838664  76.500000
# 1838665  38.250000
# 1838666  76.500000
# 1838667  76.500000
# 1838668  76.500000
#
# [1838669 rows x 5 columns]

# %%
# mencari nilai lift ratio
# Menyaring aturan dengan lift > 1 (hubungan yang kuat)
strong_rules = rules[rules['lift'] > 1]
print("\nAturan asosiasi dengan hubungan yang kuat (lift > 1):")
print(strong_rules[['antecedents', 'consequents', 'confidence', 'lift']])

# Visualisasi hubungan lift dan confidence
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
sns.scatterplot(data=strong_rules, x='confidence', y='lift', hue='lift', palette='viridis', s=100)
plt.title('Visualisasi Hubungan Confidence vs Lift')
plt.xlabel('Confidence')
plt.ylabel('Lift')
plt.legend(title='Lift')
plt.grid(True)
plt.show()
# Out:
# Aturan asosiasi dengan hubungan yang kuat (lift > 1):
#                          antecedents  \
# 0         (coffee, cereal, potatoes)
# 1        (oranges, cereal, potatoes)
# 2                (oranges, potatoes)
# 3                 (oranges, bananas)
# 4                (potatoes, bananas)
# ...                              ...
# 1838664        (eggs, yogurt, bread)
# 1838665      (eggs, yogurt, bananas)
# 1838666       (eggs, bread, bananas)
# 1838667     (yogurt, bread, bananas)
# 1838668                (eggs, bread)
#
#                                       consequents  confidence        lift
# 0                                       (oranges)       0.500    2.637931
# 1                                        (coffee)       0.500    2.318182
# 2                                       (bananas)       0.500    2.067568
# 3                                      (potatoes)       0.625    3.541667
# 4                                       (oranges)       0.500    2.637931
# ...                                           ...         ...         ...
# 1838664          (coffee, juice, butter, bananas)       0.500   38.250000
# 1838665            (coffee, juice, bread, butter)       0.500   38.250000
# 1838666           (coffee, yogurt, juice, butter)       1.000  153.000000
# 1838667             (coffee, eggs, juice, butter)       1.000   76.500000
# 1838668  (coffee, juice, butter, yogurt, bananas)       0.500   76.500000
#
# [1838669 rows x 4 columns]

# %% [markdown]
# # Kesimpulan Sementara

# %% [markdown]
# ## 1. Preprocessing Data
# - Dataset berisi 153 transaksi dengan 19 item unik (produk makanan)
# - Data sudah bersih tanpa nilai null
# - Item names dinormalisasi ke lowercase untuk konsistensi
# - Data dikonversi ke format binary encoding untuk algoritma FP-Growth
#
# ## 2. Implementasi FP-Growth Algorithm
# - Minimum Support : 2 (item harus muncul minimal 2 kali)
# - Minimum Confidence : 0.5 (50%)
# - Algoritma berhasil menemukan frequent itemsets dengan berbagai kombinasi item
# - Implementasi menggunakan struktur data FP-Tree
#
# ## 3. Hasil Frequent Itemsets
# Beberapa frequent itemsets yang ditemukan:
#
# - Single items: eggs (27), coffee (24), butter (23)
# - Kombinasi 2 items: {eggs, bananas} (7), {juice, butter} (8)
# - Kombinasi kompleks: {coffee, cheese, butter, yogurt, eggs, cereal} (2)
#
# ## 4. Association Rules
# - Ditemukan 1,838,669 aturan asosiasi dengan confidence ≥ 0.5
# - Semua aturan memiliki lift > 1, menunjukkan hubungan positif antar item
# - Contoh aturan kuat: {bananas, tomatoes, oranges} → {potatoes} dengan confidence 100% dan lift 5.67

# %%
# Tambahkan cell baru untuk analisis dan visualisasi kesimpulan
from collections import Counter

# 1. Visualisasi Top 10 Frequent Items
item_support = {}
for itemset, support in frequent_patterns.items():
    if len(itemset) == 1:
        item_support[list(itemset)[0]] = support

top_items = sorted(item_support.items(), key=lambda x: x[1], reverse=True)[:10]

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
items, supports = zip(*top_items)
plt.bar(items, supports, color='skyblue')
plt.title('Top 10 Most Frequent Items')
plt.xlabel('Items')
plt.ylabel('Support Count')
plt.xticks(rotation=45)

# 2. Distribusi Ukuran Itemsets
itemset_sizes = [len(itemset) for itemset in frequent_patterns.keys()]
size_counts = Counter(itemset_sizes)

plt.subplot(1, 2, 2)
sizes = list(size_counts.keys())
counts = list(size_counts.values())
plt.bar(sizes, counts, color='lightcoral')
plt.title('Distribution of Frequent Itemset Sizes')
plt.xlabel('Itemset Size')
plt.ylabel('Number of Itemsets')

plt.tight_layout()
plt.show()

# 3. Analisis Top Association Rules
print("\n=== ANALISIS KESIMPULAN ===")
print(f"Total transaksi: {len(transactions)}")
print(f"Total item unik: {len(set([item for transaction in transactions for item in transaction]))}")
print(f"Total frequent itemsets: {len(frequent_patterns)}")
print(f"Total association rules: {len(rules)}")

# Top 10 rules berdasarkan lift
top_rules = rules.nlargest(10, 'lift')
print("\nTop 10 Association Rules (berdasarkan lift):")
for idx, rule in top_rules.iterrows():
    antecedents = ', '.join(list(rule['antecedents']))
    consequents = ', '.join(list(rule['consequents']))
    print(f"{antecedents} → {consequents}")
    print(f"  Support: {rule['support']:.3f}, Confidence: {rule['confidence']:.3f}, Lift: {rule['lift']:.3f}")
    print()

# 4. Visualisasi Confidence vs Lift
plt.figure(figsize=(10, 6))
plt.scatter(rules['confidence'], rules['lift'], alpha=0.6, s=30)
plt.xlabel('Confidence')
plt.ylabel('Lift')
plt.title('Association Rules: Confidence vs Lift')
plt.axhline(y=1, color='red', linestyle='--', alpha=0.7, label='Lift = 1')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# 5. Heatmap untuk item co-occurrence
from itertools import combinations

# Buat matrix co-occurrence untuk top items
top_item_names = [item for item, _ in top_items[:8]]  # Ambil 8 item teratas
co_occurrence = np.zeros((len(top_item_names), len(top_item_names)))

for i, item1 in enumerate(top_item_names):
    for j, item2 in enumerate(top_item_names):
        if i != j:
            # Cari support untuk pasangan item
            pair = frozenset([item1, item2])
            if pair in frequent_patterns:
                co_occurrence[i][j] = frequent_patterns[pair]

plt.figure(figsize=(10, 8))
sns.heatmap(co_occurrence, 
            xticklabels=top_item_names, 
            yticklabels=top_item_names,
            annot=True, 
            fmt='.0f',
            cmap='YlOrRd')
plt.title('Co-occurrence Heatmap of Top Items')
plt.show()

# 6. Summary Statistics
print("\n=== STATISTIK RINGKASAN ===")
print(f"Rata-rata confidence: {rules['confidence'].mean():.3f}")
print(f"Rata-rata lift: {rules['lift'].mean():.3f}")
print(f"Rata-rata support: {rules['support'].mean():.3f}")
print(f"Jumlah rules dengan lift > 2: {len(rules[rules['lift'] > 2])}")
print(f"Jumlah rules dengan confidence > 0.8: {len(rules[rules['confidence'] > 0.8])}")

# 7. Rekomendasi Bisnis
print("\n=== REKOMENDASI BISNIS ===")
print("1. Item yang sering dibeli bersama:")
for itemset, support in list(frequent_patterns.items())[:10]:
    if len(itemset) >= 2:
        items_str = ', '.join(sorted(list(itemset)))
        print(f"   - {items_str} (support: {support})")

print("\n2. Strategi Cross-selling berdasarkan rules dengan lift tinggi:")
high_lift_rules = rules[rules['lift'] > 5].head(5)
for idx, rule in high_lift_rules.iterrows():
    antecedents = ', '.join(list(rule['antecedents']))
    consequents = ', '.join(list(rule['consequents']))
    print(f"   - Jika customer membeli {antecedents}, rekomendasikan {consequents}")
    print(f"     (Confidence: {rule['confidence']:.1%}, Lift: {rule['lift']:.2f})")
# Out:
# === ANALISIS KESIMPULAN ===
# Total transaksi: 153
# Total item unik: 19
# Total frequent itemsets: 1477
# Total association rules: 1838669
#
# Top 10 Association Rules (berdasarkan lift):
# eggs, oranges, cheese, butter → cereal, yogurt, bananas
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# cereal, yogurt, bananas → eggs, oranges, cheese, butter
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# coffee, oranges, eggs, butter → cereal, yogurt, bananas
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# yogurt, cereal, butter, bananas → coffee, oranges, eggs
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# coffee, oranges, eggs → yogurt, cereal, butter, bananas
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# cereal, yogurt, bananas → coffee, oranges, eggs, butter
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# yogurt, cheese, butter, bananas → coffee, oranges, eggs
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# coffee, oranges, eggs → yogurt, cheese, butter, bananas
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# coffee, oranges, cheese, butter → cereal, yogurt, bananas
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# oranges, yogurt, cheese, butter → coffee, cereal, bananas
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
# === STATISTIK RINGKASAN ===
# Rata-rata confidence: 0.895
# Rata-rata lift: 94.373
# Rata-rata support: 0.007
# Jumlah rules dengan lift > 2: 1838669
# Jumlah rules dengan confidence > 0.8: 1451417
#
# === REKOMENDASI BISNIS ===
# 1. Item yang sering dibeli bersama:
#    - bananas, eggs (support: 7)
#    - cereal, eggs (support: 7)
#    - bananas, cereal, eggs (support: 3)
#    - cereal, coffee, eggs (support: 2)
#    - coffee, eggs (support: 6)
#    - bananas, coffee, eggs (support: 2)
#    - cheese, eggs (support: 5)
#    - cereal, cheese, eggs (support: 3)
#    - cereal, cheese, coffee, eggs (support: 2)
#
# 2. Strategi Cross-selling berdasarkan rules dengan lift tinggi:
#    - Jika customer membeli tomatoes, cereal, bananas, rekomendasikan eggs
#      (Confidence: 100.0%, Lift: 5.67)
#    - Jika customer membeli eggs, tomatoes, coffee, rekomendasikan potatoes
#      (Confidence: 100.0%, Lift: 5.67)
#    - Jika customer membeli coffee, cereal, bananas, rekomendasikan eggs
#      (Confidence: 100.0%, Lift: 5.67)
#    - Jika customer membeli eggs, cereal, coffee, rekomendasikan cheese
#      (Confidence: 100.0%, Lift: 5.46)
#    - Jika customer membeli coffee, potatoes, cheese, bananas, rekomendasikan eggs
#      (Confidence: 100.0%, Lift: 5.67)

# %% [markdown]
# # Tabu Search for Related Products

# %% [markdown]
# #### Setelah algoritma FP-Growth menghasilkan aturan asosiasi, Tabu Search digunakan untuk memilih dan mengurutkan produk yang paling relevan untuk setiap item. Proses ini bertujuan memaksimalkan skor gabungan dari beberapa faktor penting seperti support, confidence, dan lift, sambil tetap menjaga variasi produk yang direkomendasikan. Pada setiap iterasi, Tabu Search mengevaluasi beberapa kemungkinan perubahan (menambah, menghapus, atau menukar produk), dan menyimpan langkah-langkah yang baru digunakan dalam tabu list agar pencarian tidak berulang atau terjebak pada solusi yang kurang optimal.
#
# #### Hasil akhirnya adalah daftar produk terkait yang sudah terurut untuk setiap item, yang kemudian digunakan untuk menyaring aturan asosiasi sehingga rekomendasi menjadi lebih spesifik dan relevan.

# %%
import random
from collections import defaultdict, Counter

def craft_symmetric_pairs(rules, cap_rules=200000, pick_metric='lift'):
    """
    Bangun peta kandidat simetris dari aturan asosiasi.
    Tiap pasangan item (a,b) nyimpen support, confidence, lift terkumpul.
    """
    R = rules.copy()
    if pick_metric in R.columns:
        R = R.nlargest(cap_rules, pick_metric)
    pairbank = defaultdict(lambda: defaultdict(lambda: {'support':0.0,'confidence':0.0,'lift':0.0,'tally':0}))
    for _, row in R.iterrows():
        lefties = list(row['antecedents'])
        righties = list(row['consequents'])
        supp = row.get('support', 0.0)
        conf = row.get('confidence', 0.0)
        lift = row.get('lift', 1.0)
        for l in lefties:
            for r in righties:
                if l == r:
                    continue
                slot = pairbank[l][r]
                slot['support'] += supp
                slot['confidence'] += conf
                slot['lift'] += lift
                slot['tally'] += 1
                mirror = pairbank[r][l]
                mirror['support'] += supp
                mirror['confidence'] += conf
                mirror['lift'] += lift
                mirror['tally'] += 1
    for anchor, mates in pairbank.items():
        for mate, m in mates.items():
            c = max(m['tally'], 1)
            m['support'] /= c
            m['confidence'] /= c
            m['lift'] /= c
    return pairbank


def _minmax_scales(anchor, pairbank):
    """
    Hitung faktor min-max tiap metrik (support, confidence, lift)
    di antara tetangga item dasar.
    """
    buckets = {'support':[], 'confidence':[], 'lift':[]}
    for _, m in pairbank.get(anchor, {}).items():
        buckets['support'].append(m['support'])
        buckets['confidence'].append(m['confidence'])
        buckets['lift'].append(m['lift'])
    scales = {}
    for k, arr in buckets.items():
        if not arr:
            scales[k] = (0.0, 1.0)
        else:
            lo, hi = min(arr), max(arr)
            scales[k] = (lo, hi if hi > lo else lo + 1e-9)
    return scales


def rate_bundle(anchor, mates, pairbank, weights=(0.2,0.4,0.4)):
    """
    Skor daftar tetangga item pakai metrik ternormalisasi berbobot.
    """
    ws, wc, wl = weights
    scales = _minmax_scales(anchor, pairbank)
    total = 0.0
    for m in mates:
        slot = pairbank.get(anchor, {}).get(m)
        if not slot:
            continue
        def rescale(k, v):
            lo, hi = scales[k]
            return (v - lo) / (hi - lo) if hi > lo else 0.0
        total += ws*rescale('support', slot['support']) + wc*rescale('confidence', slot['confidence']) + wl*rescale('lift', slot['lift'])
    return total


def greedy_seed(anchor, pairbank, k, weights=(0.2,0.4,0.4)):
    """
    Solusi awal rakus: ambil top-k tetangga berdasar hasil kali support*confidence*lift.
    """
    buddies = list(pairbank.get(anchor, {}).items())
    if not buddies:
        return []
    ranked = sorted(buddies, key=lambda kv: (kv[1]['support']*kv[1]['confidence']*kv[1]['lift']), reverse=True)
    return [n for n,_ in ranked[:k]]

def tabu_hunt(anchor, pairbank, k=5, max_iter=100, tabu_span=7, weights=(0.2,0.4,0.4), seed=42):
    """
    ALGORITMA PENCARIAN TABU – Langkah demi Langkah
    ------------------------------------
    Tujuan: temukan k tetangga terbaik untuk item dasar.

    Langkah 0: Inisialisasi
    - Set seed biar hasil tetap sama.
    - Bikin solusi awal (rakus top-k).
    - Set best = saat ini, best_score = skor(saat ini).
    - Buat daftar tabu kosong (dict: item -> iterasi saat tabu habis).

    Langkah 1: Bangkitkan Calon Gerakan (Tetangga)
    Tiap iterasi:
    - Susun daftar kemungkinan gerakan:
        * TAMBAH:   pilih item yang belum ada lalu tambahkan (kalau |saat ini| < k).
        * HAPUS:    pilih item yang ada lalu buang.
        * TUKAR:    pilih satu ada & satu belum, lalu tukar.

    Langkah 2: Evaluasi Gerakan
    - Tiap gerakan, bikin solusi percobaan.
    - Hitung skornya.
    - Cek status tabu:
        * Kalau gerakan pakai item yg masih tabu (tenure > iterasi sekarang), itu tabu.
        * Gerakan tabu cuma diterima kalau bikin best_score naik (aspirasi).

    Langkah 3: Pilih Gerakan Non-Tabu Terbaik
    - Dari gerakan yg boleh, ambil skor tertinggi.
    - Kalau tak ada, berhenti cepat.

    Langkah 4: Perbarui
    - Terapkan gerakan pilihan ke solusi saat ini.
    - Masukkan item tersentuh ke daftar tabu dg tenure = iterasi + tabu_span.
    - Kalau skor baru lebih tinggi, update best & best_score.

    Langkah 5: Ulang
    - Ulang Langkah 1-4 sampai max_iter atau tak ada gerakan valid.

    Langkah 6: Pasca-proses
    - Urutkan lagi daftar best berdasar skor per item biar rapi.
    - Kembalikan daftar terurut & skornya.
    """
    random.seed(seed)
    # Langkah 0
    now = greedy_seed(anchor, pairbank, k, weights)
    best = list(now)
    best_score = rate_bundle(anchor, best, pairbank, weights)
    tabu = {}
    universe = set(pairbank.get(anchor, {}).keys())

    for it in range(1, max_iter+1):
        # Langkah 1: bangkitkan calon gerakan
        moves = []
        inside = set(now)
        outside = list(universe - inside)
        inside_list = list(inside)
        if len(now) < k and outside:
            moves.append(('add', random.choice(outside), None))
        if inside_list:
            moves.append(('remove', random.choice(inside_list), None))
        if inside_list and outside:
            moves.append(('swap', random.choice(inside_list), random.choice(outside)))

        # Langkah 2 & 3: evaluasi & pilih gerakan terbaik yg boleh
        top_move = None
        top_move_score = -1e9
        top_move_sol = None
        for mv, a, b in moves:
            trial = list(now)
            if mv == 'add':
                trial.append(a)
            elif mv == 'remove':
                trial = [x for x in trial if x != a]
            elif mv == 'swap':
                trial = [x for x in trial if x != a]
                trial.append(b)
            trial = trial[:k]
            sc = rate_bundle(anchor, trial, pairbank, weights)
            # cek tabu
            is_tabu = (mv=='add' and a in tabu and tabu[a] > it) or (mv=='remove' and a in tabu and tabu[a] > it) or (mv=='swap' and ((a in tabu and tabu[a] > it) or (b in tabu and tabu[b] > it)))
            if is_tabu and sc <= best_score:
                continue  # lewati gerakan tabu kecuali bikin best_score naik
            if sc > top_move_score:
                top_move_score = sc
                top_move = (mv, a, b)
                top_move_sol = trial

        # Langkah 4: terapkan gerakan
        if top_move_sol is None:
            break  # tak ada gerakan valid
        mv, a, b = top_move
        now = top_move_sol
        touched = [a] if b is None else [a,b]
        for t in touched:
            tabu[t] = it + tabu_span
        if top_move_score > best_score:
            best = list(now)
            best_score = top_move_score

    # Langkah 6: urutkan lagi best berdasar skor individu
    solo_scores = [(n, rate_bundle(anchor, [n], pairbank, weights)) for n in best]
    solo_scores.sort(key=lambda x: x[1], reverse=True)
    return [n for n,_ in solo_scores], best_score

def optimize_all_items(pairbank, k=5, max_iter=100, tabu_span=7, weights=(0.2,0.4,0.4), cap_items=None):
    """
    Jalankan pencarian tabu tiap item dasar (atau daftar terbatas) & kumpulkan hasil.
    """
    outcome = {}
    anchors = list(pairbank.keys()) if cap_items is None else [b for b in pairbank.keys() if b in cap_items]
    for i, anchor in enumerate(anchors):
        best_list, best_score = tabu_hunt(anchor, pairbank, k=k, max_iter=max_iter, tabu_span=tabu_span, weights=weights, seed=42+i)
        outcome[anchor] = {'related': best_list, 'score': best_score}
    return outcome


def prune_via_tabu(rules, tabu_related):
    """
    Saring aturan asosiasi: tiap item anteseden,
    semua konsekuen harus ada di daftar tabu-terkaitnya (kalau daftar ada).
    """
    def keep(row):
        lefties = list(row['antecedents'])
        righties = list(row['consequents'])
        for l in lefties:
            rel = set(tabu_related.get(l, {}).get('related', []))
            if rel and not set(righties).issubset(rel):
                return False
        return True
    return rules[rules.apply(keep, axis=1)].copy()

# %%
# Build candidates from existing rules (use top by lift to keep runtime reasonable)
cand_map = build_pair_candidates(rules, limit_rules=200000, use_metric='lift')

# Choose target items to optimize (e.g., 10 most frequent items)
flat_items = [item for trx in transactions for item in trx]
top_items = [it for it,_ in Counter(flat_items).most_common(10)]

# %%
# show flat_items and top_items as horizontal table 
print("=== Flat Items ===")
print(tabulate([flat_items], tablefmt='grid'))

print("\n=== Top Items ===")
print(tabulate([top_items], tablefmt='grid'))
# Out:
# === Flat Items ===
# +--------+--------+------+----------+---------+------+--------+--------+----------+----------+--------+---------+----------+-------+--------+-------+---------+--------+-------+----------+---------+---------+---------+----------+---------+--------+---------+--------+-------+--------+--------+---------+---------+-------+------+--------+--------+--------+--------+--------+-------+--------+---------+-------+------+--------+---------+---------+----------+-----+---------+-------+------+--------+-------+--------+--------+----------+---------+-------+-------+-------+----------+--------+--------+---------+------+------+-------+-------+----------+--------+--------+--------+---------+--------+--------+-----+---------+--------+-------+-------+-----+-------+--------+--------+--------+-------+-------+--------+---------+-----+-------+----------+-------+--------+------+----------+--------+--------+------+-------+-------+--------+--------+--------+-----+-------+--------+------+----------+------+------+---------+---------+---------+--------+--------+-------+----------+-------+---------+----------+----------+--------+------+---------+------+--------+---------+--------+-------+-------+----------+------+----------+---------+------+--------+---------+--------+------+-------+--------+--------+---------+----------+--------+----------+-------+-------+---------+------+-----+--------+------+--------+---------+-------+----------+--------+-------+--------+----------+------+--------+---------+--------+-----+--------+--------+--------+-------+---------+--------+--------+--------+--------+---------+-------+---------+----------+----------+--------+-------+--------+-------+-----+--------+-------+--------+--------+-----+--------+---------+-----+--------+--------+-------+--------+-----+--------+--------+---------+--------+---------+-------+----------+---------+--------+----------+-----+------+---------+--------+----------+-------+----------+--------+---------+-----+--------+--------+---------+--------+--------+-------+----------+--------+-----+---------+-------+--------+--------+-----+--------+----------+--------+-------+--------+-------+--------+----------+--------+---------+--------+--------+----------+-----+-------+------+---------+--------+---------+--------+--------+--------+------+------+----------+--------+-------+---------+---------+-------+--------+-------+------+----------+--------+---------+--------+--------+-------+-----+------+----------+--------+---------+------+--------+---------+-------+------+----------+--------+----------+--------+---------+-------+--------+-------+--------+---------+--------+------+-------+--------+--------+--------+---------+--------+---------+------+--------+----------+--------+--------+-----+-------+-------+------+--------+--------+--------+--------+------+--------+--------+--------+--------+--------+--------+-----+-------+--------+-------+--------+-------+--------+------+---------+-------+-------+---------+--------+--------+----------+-------+--------+--------+----------+---------+------+----------+--------+--------+--------+--------+--------+------+-------+--------+-----+-------+--------+-------+--------+--------+---------+----------+--------+-------+-------+--------+-------+--------+--------+--------+--------+-------+---------+--------+--------+-----+---------+------+--------+--------+------+---------+-------+------+-------+--------+--------+-----+--------+---------+-------+-------+--------+--------+-------+-------+--------+-------+------+--------+--------+---------+---------+-------+--------+---------+--------+---------+------+--------+-------+-----+--------+----------+------+--------+-------+-------+--------+---------+----------+---------+----------+------+--------+------+----------+--------+--------+-------+--------+--------+--------+-------+----------+------+---------+------+----------+------+--------+-------+---------+---------+--------+--------+---------+----------+---------+--------+---------+-------+------+------ ...
# | apples | butter | eggs | potatoes | oranges | milk | onions | cereal | tomatoes | potatoes | cereal | bananas | tomatoes | pasta | onions | bread | bananas | coffee | sugar | potatoes | oranges | bananas | oranges | potatoes | chicken | cereal | bananas | cheese | pasta | cereal | onions | bananas | chicken | sugar | eggs | onions | cereal | cheese | cereal | coffee | bread | onions | chicken | pasta | eggs | butter | bananas | chicken | tomatoes | tea | bananas | pasta | eggs | cereal | sugar | coffee | apples | tomatoes | chicken | pasta | bread | sugar | potatoes | yogurt | butter | bananas | milk | eggs | sugar | juice | tomatoes | butter | onions | coffee | bananas | onions | coffee | tea | bananas | onions | juice | pasta | tea | juice | cereal | butter | yogurt | juice | pasta | onions | chicken | tea | juice | potatoes | sugar | coffee | milk | tomatoes | apples | yogurt | eggs | pasta | bread | apples | butter | apples | tea | juice | butter | eggs | tomatoes | milk | milk | bananas | oranges | bananas | apples | yogurt | sugar | tomatoes | bread | bananas | potatoes | tomatoes | onions | milk | oranges | milk | yogurt | oranges | coffee | bread | juice | tomatoes | eggs | potatoes | bananas | milk | butter | bananas | onions | eggs | juice | cheese | cheese | oranges | tomatoes | yogurt | potatoes | juice | sugar | bananas | eggs | tea | yogurt | eggs | butter | oranges | bread | potatoes | cheese | sugar | apples | tomatoes | milk | cheese | oranges | yogurt | tea | cereal | cheese | cereal | pasta | bananas | coffee | yogurt | cereal | butter | chicken | juice | oranges | potatoes | tomatoes | coffee | bread | cereal | juice | tea | coffee | pasta | onions | cheese | tea | apples | oranges | tea | cereal | onions | juice | cheese | tea | cereal | yogurt | bananas | yogurt | bananas | sugar | tomatoes | chicken | butter | potatoes | tea | milk | oranges | apples | tomatoes | sugar | tomatoes | cheese | oranges | tea | yogurt | yogurt | oranges | coffee | yogurt | juice | potatoes | coffee | tea | bananas | sugar | coffee | butter | tea | butter | tomatoes | apples | bread | cheese | sugar | onions | potatoes | cheese | bananas | butter | cereal | potatoes | tea | bread | milk | oranges | cereal | bananas | onions | cheese | apples | eggs | milk | potatoes | cereal | pasta | oranges | chicken | bread | cheese | sugar | milk | tomatoes | cereal | chicken | coffee | cheese | juice | tea | eggs | potatoes | butter | bananas | eggs | cheese | bananas | juice | eggs | tomatoes | apples | potatoes | cheese | bananas | sugar | coffee | bread | apples | bananas | apples | milk | sugar | coffee | cereal | cheese | oranges | cheese | oranges | milk | onions | potatoes | coffee | cereal | tea | bread | pasta | eggs | coffee | yogurt | coffee | butter | eggs | onions | cereal | cheese | butter | apples | cheese | tea | bread | cereal | pasta | coffee | sugar | yogurt | milk | chicken | juice | pasta | oranges | cheese | coffee | tomatoes | bread | cereal | cheese | tomatoes | oranges | milk | tomatoes | cereal | apples | butter | onions | yogurt | milk | pasta | onions | tea | sugar | cheese | juice | coffee | onions | chicken | potatoes | apples | sugar | bread | yogurt | juice | coffee | apples | coffee | butter | bread | oranges | cheese | butter | tea | bananas | milk | onions | coffee | eggs | bananas | juice | eggs | sugar | coffee | apples | tea | apples | chicken | pasta | sugar | yogurt | apples | sugar | pasta | coffee | bread | milk | yogurt | yogurt | chicken | oranges | bread | butter | oranges | apples | chicken | eggs | cereal | sugar | tea | coffee | potatoes | eggs | cereal | pasta | pasta | butter | chicken | potatoes | bananas | tomatoes | eggs | apples | milk | tomatoes | cheese | onions | sugar | coffee | cereal | yogurt | sugar | tomatoes | eggs | bananas | eggs | tomatoes | eggs | cereal | pasta | bananas | bananas | cereal | onions | chicken | potatoes | bananas | cereal | bananas | juice | milk | orang ...
# +--------+--------+------+----------+---------+------+--------+--------+----------+----------+--------+---------+----------+-------+--------+-------+---------+--------+-------+----------+---------+---------+---------+----------+---------+--------+---------+--------+-------+--------+--------+---------+---------+-------+------+--------+--------+--------+--------+--------+-------+--------+---------+-------+------+--------+---------+---------+----------+-----+---------+-------+------+--------+-------+--------+--------+----------+---------+-------+-------+-------+----------+--------+--------+---------+------+------+-------+-------+----------+--------+--------+--------+---------+--------+--------+-----+---------+--------+-------+-------+-----+-------+--------+--------+--------+-------+-------+--------+---------+-----+-------+----------+-------+--------+------+----------+--------+--------+------+-------+-------+--------+--------+--------+-----+-------+--------+------+----------+------+------+---------+---------+---------+--------+--------+-------+----------+-------+---------+----------+----------+--------+------+---------+------+--------+---------+--------+-------+-------+----------+------+----------+---------+------+--------+---------+--------+------+-------+--------+--------+---------+----------+--------+----------+-------+-------+---------+------+-----+--------+------+--------+---------+-------+----------+--------+-------+--------+----------+------+--------+---------+--------+-----+--------+--------+--------+-------+---------+--------+--------+--------+--------+---------+-------+---------+----------+----------+--------+-------+--------+-------+-----+--------+-------+--------+--------+-----+--------+---------+-----+--------+--------+-------+--------+-----+--------+--------+---------+--------+---------+-------+----------+---------+--------+----------+-----+------+---------+--------+----------+-------+----------+--------+---------+-----+--------+--------+---------+--------+--------+-------+----------+--------+-----+---------+-------+--------+--------+-----+--------+----------+--------+-------+--------+-------+--------+----------+--------+---------+--------+--------+----------+-----+-------+------+---------+--------+---------+--------+--------+--------+------+------+----------+--------+-------+---------+---------+-------+--------+-------+------+----------+--------+---------+--------+--------+-------+-----+------+----------+--------+---------+------+--------+---------+-------+------+----------+--------+----------+--------+---------+-------+--------+-------+--------+---------+--------+------+-------+--------+--------+--------+---------+--------+---------+------+--------+----------+--------+--------+-----+-------+-------+------+--------+--------+--------+--------+------+--------+--------+--------+--------+--------+--------+-----+-------+--------+-------+--------+-------+--------+------+---------+-------+-------+---------+--------+--------+----------+-------+--------+--------+----------+---------+------+----------+--------+--------+--------+--------+--------+------+-------+--------+-----+-------+--------+-------+--------+--------+---------+----------+--------+-------+-------+--------+-------+--------+--------+--------+--------+-------+---------+--------+--------+-----+---------+------+--------+--------+------+---------+-------+------+-------+--------+--------+-----+--------+---------+-------+-------+--------+--------+-------+-------+--------+-------+------+--------+--------+---------+---------+-------+--------+---------+--------+---------+------+--------+-------+-----+--------+----------+------+--------+-------+-------+--------+---------+----------+---------+----------+------+--------+------+----------+--------+--------+-------+--------+--------+--------+-------+----------+------+---------+------+----------+------+--------+-------+---------+---------+--------+--------+---------+----------+---------+--------+---------+-------+------+------ ...
#
# === Top Items ===
# +---------+--------+--------+---------+--------+------+----------+----------+-------+--------+
# | bananas | coffee | cereal | oranges | cheese | eggs | potatoes | tomatoes | sugar | yogurt |
# +---------+--------+--------+---------+--------+------+----------+----------+-------+--------+

# %%
tabu_related = optimize_related_products_all(
    cand_map,
    k=5,
    max_iter=120,
    tabu_tenure=8,
    weights=(0.2,0.4,0.4),
    limit_items=top_items
)

tabu_related
# Out:
# {'oranges': {'related': ['cheese', 'bread', 'eggs', 'cereal', 'bananas'],
#   'score': 0.9741898806139853},
#  'bananas': {'related': ['cheese', 'chicken', 'eggs', 'juice', 'bread'],
#   'score': 0.9724452035297467},
#  'yogurt': {'related': ['cheese', 'apples', 'milk', 'tomatoes', 'bread'],
#   'score': 0.9960509371870082},
#  'cereal': {'related': ['chicken', 'pasta', 'bread', 'butter', 'oranges'],
#   'score': 0.9716292134831462},
#  'cheese': {'related': ['pasta', 'eggs', 'yogurt', 'chicken', 'bananas'],
#   'score': 0.9950042099354477},
#  'eggs': {'related': ['cheese', 'onions', 'milk', 'sugar', 'tomatoes'],
#   'score': 0.9959660140376801},
#  'coffee': {'related': ['cheese', 'milk', 'onions', 'bread', 'apples'],
#   'score': 0.9969721243191285},
#  'sugar': {'related': ['milk', 'onions', 'pasta', 'juice', 'potatoes'],
#   'score': 0.9922346368715084},
#  'tomatoes': {'related': ['yogurt', 'onions', 'juice', 'eggs', 'potatoes'],
#   'score': 0.9945758799769188},
#  'potatoes': {'related': ['sugar', 'apples', 'onions', 'milk', 'tomatoes'],
#   'score': 0.988527397260274}}

# %%
# Filter association rules using Tabu-selected related items
rules_filtered = filter_rules_by_tabu(rules, tabu_related)

# Present results
print("=== Tabu Search: Related Products per Item ===")
for base in top_items:
    rel = tabu_related.get(base, {}).get('related', [])
    print(f"- {base}: {', '.join(rel) if rel else '(no candidates)'}")

print(f"\nOriginal rules: {len(rules)}; Filtered rules: {len(rules_filtered)}")

example_item = top_items[0] if top_items else None
if example_item:
    rel = tabu_related[example_item]['related']
    print(f"\nTop related for '{example_item}': {', '.join(rel)}")
# Out:
# === Tabu Search: Related Products per Item ===
# - bananas: cheese, chicken, eggs, juice, bread
# - coffee: cheese, milk, onions, bread, apples
# - cereal: chicken, pasta, bread, butter, oranges
# - oranges: cheese, bread, eggs, cereal, bananas
# - cheese: pasta, eggs, yogurt, chicken, bananas
# - eggs: cheese, onions, milk, sugar, tomatoes
# - potatoes: sugar, apples, onions, milk, tomatoes
# - tomatoes: yogurt, onions, juice, eggs, potatoes
# - sugar: milk, onions, pasta, juice, potatoes
# - yogurt: cheese, apples, milk, tomatoes, bread
#
# Original rules: 1838669; Filtered rules: 87141
#
# Top related for 'bananas': cheese, chicken, eggs, juice, bread

# %% [markdown]
# ## Kesimpulan Tabu Search
#
# - Tabu Search secara efektif merampingkan basis aturan: dari 1,838,669 aturan menjadi 87,141 , sehingga hasil rekomendasi lebih fokus, ringkas, dan mudah dieksekusi.
#
# - Algoritma menghasilkan daftar produk terkait terurut untuk item teratas
# (contoh bananas → cheese, chicken, eggs, juice, bread ), yang kemudian dipakai untuk memfilter aturan asosiasi agar relevansi tetap tinggi.
#
# - Rangkaian proses end-to-end (encoding transaksi → FP-Growth → pembentukan kandidat pasangan → optimisasi Tabu → penyaringan aturan) meningkatkan kualitas rekomendasi dengan menyeimbangkan kekuatan asosiasi ( support , confidence , lift ) dan keberagaman, sekaligus menghindari jebakan lokal optimum melalui mekanisme add/remove/swap dan tabu tenure.
