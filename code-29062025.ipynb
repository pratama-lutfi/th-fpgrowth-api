# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from mlxtend.preprocessing import TransactionEncoder
from tabulate import tabulate
import seaborn as sns

import collections
import warnings

import numpy as np
import pandas as pd

warnings.simplefilter("always", DeprecationWarning)

import random
import time

from itertools import groupby


import math

# %%
# local file path
df = pd.read_csv('./market_basket_dataset.csv', sep=';', dtype={'BillNo': str}, low_memory=False)

# drop column unnamed (for general purpose)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

df
# Out:
#     BillNo  Itemname  Quantity  Price  CustomerID
# 0     1000    Apples         5   8.30       52299
# 1     1000    Butter         4   6.06       11752
# 2     1000      Eggs         4   2.66       16415
# 3     1000  Potatoes         4   8.10       22889
# 4     1004   Oranges         2   7.26       52255
# ..     ...       ...       ...    ...         ...
# 495   1493     Juice         2   4.24       55321
# 496   1493     Bread         5   7.05       14479
# 497   1497    Coffee         3   2.01       25378
# 498   1497     Pasta         3   2.64       53334
# 499   1497      Eggs         4   7.37       34687
#
# [500 rows x 5 columns]

# %%
def drawLine(length=40):
    print("─" * length)

# %%
#pengecekan tipe data
drawLine()
print("📋 DATA TYPES")
drawLine()
print(df.dtypes.to_string())
drawLine()

# Menghitung jumlah itemname
jumlah_itemname = df['Itemname'].nunique()
print("\n📦  JUMLAH ITEMNAME")
drawLine()
print(f"Total unik: {jumlah_itemname:,}")
drawLine()

# Menghitung jumlah BillNo/transaksi
jumlah_billno = df['BillNo'].nunique()
print("\n🧾  JUMLAH BILLNO / TRANSAKSI")
drawLine()
print(f"Total unik: {jumlah_billno:,}")
drawLine()

# Menampilkan daftar BillNo/transaksi
billno_list = df['BillNo'].unique()
print("\n🧾  DAFTAR BILLNO")
drawLine()
cols = 20
rows = (len(billno_list) + cols - 1) // cols
for r in range(rows):
    line = []
    for c in range(cols):
        idx = r + c * rows
        if idx < len(billno_list):
            line.append(f"{idx + 1:>3}. {billno_list[idx]}")
        else:
            line.append(" " * 12)
    print("  ".join(line))
drawLine()
# Out:
# ────────────────────────────────────────
# 📋 DATA TYPES
# ────────────────────────────────────────
# BillNo         object
# Itemname       object
# Quantity        int64
# Price         float64
# CustomerID      int64
# ────────────────────────────────────────
#
# 📦  JUMLAH ITEMNAME
# ────────────────────────────────────────
# Total unik: 19
# ────────────────────────────────────────
#
# 🧾  JUMLAH BILLNO / TRANSAKSI
# ────────────────────────────────────────
# Total unik: 153
# ────────────────────────────────────────
#
# 🧾  DAFTAR BILLNO
# ────────────────────────────────────────
#   1. 1000    9. 1024   17. 1054   25. 1086   33. 1112   41. 1152   49. 1185   57. 1207   65. 1225   73. 1243   81. 1271   89. 1292   97. 1312  105. 1339  113. 1360  121. 1384  129. 1407  137. 1436  145. 1458  153. 1497
#   2. 1004   10. 1027   18. 1056   26. 1088   34. 1115   42. 1153   50. 1186   58. 1211   66. 1226   74. 1250   82. 1279   90. 1293   98. 1313  106. 1343  114. 1367  122. 1385  130. 1409  138. 1437  146. 1461
#   3. 1005   11. 1033   19. 1063   27. 1101   35. 1120   43. 1160   51. 1190   59. 1214   67. 1230   75. 1252   83. 1280   91. 1297   99. 1320  107. 1348  115. 1369  123. 1386  131. 1412  139. 1442  147. 1463
#   4. 1008   12. 1035   20. 1066   28. 1104   36. 1127   44. 1162   52. 1194   60. 1215   68. 1231   76. 1254   84. 1282   92. 1301  100. 1331  108. 1350  116. 1370  124. 1391  132. 1415  140. 1447  148. 1470
#   5. 1011   13. 1038   21. 1073   29. 1105   37. 1132   45. 1169   53. 1196   61. 1217   69. 1233   77. 1264   85. 1283   93. 1302  101. 1332  109. 1352  117. 1378  125. 1394  133. 1416  141. 1448  149. 1471
#   6. 1012   14. 1042   22. 1075   30. 1106   38. 1139   46. 1170   54. 1198   62. 1219   70. 1235   78. 1266   86. 1285   94. 1304  102. 1333  110. 1355  118. 1380  126. 1398  134. 1422  142. 1451  150. 1483
#   7. 1013   15. 1044   23. 1076   31. 1109   39. 1140   47. 1172   55. 1203   63. 1220   71. 1236   79. 1267   87. 1287   95. 1310  103. 1334  111. 1356  119. 1381  127. 1399  135. 1424  143. 1454  151. 1485
#   8. 1021   16. 1049   24. 1082   32. 1111   40. 1144   48. 1176   56. 1205   64. 1222   72. 1242   80. 1268   88. 1290   96. 1311  104. 1336  112. 1358  120. 1383  128. 1402  136. 1431  144. 1457  152. 1493
# ────────────────────────────────────────

# %%
# Pengecekan nilai kosong
drawLine()
print("🔍 Pengecekan Nilai Kosong (Missing Values)")
drawLine()
print(df.isnull().sum())

# Menampilkan Baris yang Mengandung Nilai Kosong (NaN)
print("\n")
drawLine()
print("⚠️  Baris yang Mengandung Nilai Kosong (NaN)")
drawLine()
print(df[df.isnull().any(axis=1)])
# Out:
# ────────────────────────────────────────
# 🔍 Pengecekan Nilai Kosong (Missing Values)
# ────────────────────────────────────────
# BillNo        0
# Itemname      0
# Quantity      0
# Price         0
# CustomerID    0
# dtype: int64
#
#
# ────────────────────────────────────────
# ⚠️  Baris yang Mengandung Nilai Kosong (NaN)
# ────────────────────────────────────────
# Empty DataFrame
# Columns: [BillNo, Itemname, Quantity, Price, CustomerID]
# Index: []

# %%
# Normalisasi nama barang ke huruf kecil
df['Itemname'] = df['Itemname'].str.lower()

# Mengelompokkan barang per transaksi (BillNo) 
transactions = df.groupby('BillNo')['Itemname'].apply(list).tolist()

# Tampilkan keranjang transaksi hasil pengelompokan
print("\n🛒  Keranjang Transaksi (setiap daftar = satu struk):\n")
# Build a clean table
table = [(f"T{idx:03d}", ", ".join(basket)) for idx, basket in enumerate(transactions, 1)]
print(tabulate(table, headers=["Transaksi", "Daftar Barang"], tablefmt="grid"))
# Out:
# 🛒  Keranjang Transaksi (setiap daftar = satu struk):
#
# +-------------+---------------------------------------------------------------------------------------------------+
# | Transaksi   | Daftar Barang                                                                                     |
# +=============+===================================================================================================+
# | T001        | apples, butter, eggs, potatoes                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T002        | oranges                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T003        | milk, onions, cereal                                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T004        | tomatoes, potatoes, cereal                                                                        |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T005        | bananas                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T006        | tomatoes                                                                                          |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T007        | pasta, onions, bread, bananas, coffee, sugar, potatoes, oranges                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T008        | bananas, oranges, potatoes                                                                        |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T009        | chicken, cereal, bananas                                                                          |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T010        | cheese, pasta, cereal, onions, bananas, chicken                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T011        | sugar, eggs                                                                                       |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T012        | onions, cereal, cheese                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T013        | cereal, coffee, bread, onions                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T014        | chicken, pasta                                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T015        | eggs, butter, bananas, chicken, tomatoes                                                          |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T016        | tea, bananas, pasta, eggs, cereal                                                                 |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T017        | sugar, coffee                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T018        | apples, tomatoes, chicken, pasta, bread, sugar, potatoes                                          |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T019        | yogurt, butter, bananas                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T020        | milk, eggs, sugar, juice, tomatoes, butter, onions                                                |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T021        | coffee, bananas                                                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T022        | onions                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T023        | coffee, tea, bananas, onions, juice, pasta                                                        |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T024        | tea, juice, cereal, butter                                                                        |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T025        | yogurt, juice                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T026        | pasta, onions, chicken, tea, juice, potatoes, sugar, coffee, milk, tomatoes, apples, yogurt, eggs |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T027        | pasta, bread, apples                                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T028        | butter                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T029        | apples                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T030        | tea, juice, butter                                                                                |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T031        | eggs, tomatoes                                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T032        | milk                                                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T033        | milk, bananas, oranges                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T034        | bananas, apples, yogurt, sugar, tomatoes                                                          |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T035        | bread, bananas, potatoes, tomatoes, onions, milk, oranges                                         |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T036        | milk, yogurt, oranges, coffee, bread                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T037        | juice, tomatoes, eggs, potatoes, bananas, milk, butter                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T038        | bananas                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T039        | onions, eggs, juice, cheese                                                                       |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T040        | cheese, oranges, tomatoes, yogurt, potatoes, juice, sugar, bananas                                |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T041        | eggs                                                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T042        | tea, yogurt, eggs, butter, oranges, bread, potatoes                                               |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T043        | cheese, sugar                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T044        | apples, tomatoes, milk, cheese, oranges, yogurt, tea                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T045        | cereal                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T046        | cheese, cereal                                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T047        | pasta, bananas, coffee, yogurt                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T048        | cereal, butter, chicken, juice, oranges, potatoes, tomatoes, coffee, bread                        |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T049        | cereal                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T050        | juice, tea, coffee, pasta                                                                         |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T051        | onions, cheese, tea, apples                                                                       |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T052        | oranges, tea                                                                                      |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T053        | cereal, onions                                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T054        | juice, cheese, tea, cereal, yogurt                                                                |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T055        | bananas, yogurt                                                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T056        | bananas, sugar                                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T057        | tomatoes, chicken, butter, potatoes                                                               |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T058        | tea, milk, oranges                                                                                |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T059        | apples                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T060        | tomatoes, sugar                                                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T061        | tomatoes, cheese                                                                                  |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T062        | oranges                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T063        | tea, yogurt                                                                                       |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T064        | yogurt, oranges, coffee                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T065        | yogurt                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T066        | juice, potatoes, coffee, tea                                                                      |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T067        | bananas                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T068        | sugar, coffee                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T069        | butter, tea                                                                                       |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T070        | butter                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T071        | tomatoes, apples, bread, cheese, sugar, onions                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T072        | potatoes                                                                                          |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T073        | cheese, bananas, butter, cereal, potatoes, tea, bread                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T074        | milk, oranges                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T075        | cereal, bananas                                                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T076        | onions, cheese, apples, eggs, milk, potatoes, cereal, pasta, oranges, chicken                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T077        | bread, cheese                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T078        | sugar                                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T079        | milk                                                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T080        | tomatoes, cereal, chicken                                                                         |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T081        | coffee, cheese, juice, tea, eggs, potatoes, butter, bananas                                       |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T082        | eggs                                                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T083        | cheese, bananas                                                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T084        | juice                                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T085        | eggs, tomatoes                                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T086        | apples, potatoes                                                                                  |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T087        | cheese, bananas, sugar                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T088        | coffee, bread                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T089        | apples                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T090        | bananas, apples, milk, sugar                                                                      |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T091        | coffee, cereal, cheese, oranges                                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T092        | cheese                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T093        | oranges, milk                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T094        | onions, potatoes, coffee, cereal, tea, bread                                                      |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T095        | pasta                                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T096        | eggs                                                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T097        | coffee                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T098        | yogurt, coffee, butter, eggs, onions, cereal, cheese                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T099        | butter, apples, cheese, tea, bread, cereal, pasta, coffee, sugar, yogurt, milk                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T100        | chicken                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T101        | juice                                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T102        | pasta                                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T103        | oranges, cheese                                                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T104        | coffee, tomatoes, bread                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T105        | cereal, cheese, tomatoes, oranges                                                                 |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T106        | milk, tomatoes, cereal, apples, butter                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T107        | onions, yogurt                                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T108        | milk, pasta                                                                                       |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T109        | onions, tea, sugar                                                                                |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T110        | cheese                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T111        | juice, coffee                                                                                     |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T112        | onions, chicken                                                                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T113        | potatoes, apples, sugar, bread, yogurt, juice, coffee                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T114        | apples, coffee                                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T115        | butter                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T116        | bread, oranges, cheese, butter, tea, bananas, milk, onions                                        |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T117        | coffee, eggs                                                                                      |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T118        | bananas                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T119        | juice, eggs                                                                                       |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T120        | sugar                                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T121        | coffee                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T122        | apples                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T123        | tea, apples, chicken, pasta, sugar                                                                |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T124        | yogurt, apples, sugar                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T125        | pasta, coffee, bread, milk                                                                        |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T126        | yogurt                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T127        | yogurt, chicken, oranges                                                                          |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T128        | bread, butter, oranges, apples, chicken                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T129        | eggs, cereal                                                                                      |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T130        | sugar, tea, coffee                                                                                |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T131        | potatoes, eggs, cereal                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T132        | pasta                                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T133        | pasta, butter, chicken, potatoes, bananas, tomatoes                                               |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T134        | eggs, apples                                                                                      |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T135        | milk, tomatoes, cheese, onions, sugar, coffee, cereal                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T136        | yogurt, sugar, tomatoes, eggs, bananas                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T137        | eggs                                                                                              |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T138        | tomatoes, eggs, cereal, pasta, bananas                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T139        | bananas, cereal, onions, chicken, potatoes                                                        |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T140        | bananas                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T141        | cereal, bananas, juice                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T142        | milk, oranges, butter                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T143        | apples, bread, yogurt                                                                             |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T144        | oranges                                                                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T145        | sugar, potatoes, pasta                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T146        | oranges, potatoes                                                                                 |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T147        | yogurt, oranges, cheese, apples, milk, potatoes, coffee                                           |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T148        | yogurt                                                                                            |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T149        | butter, bread, cereal, cheese, bananas, yogurt, pasta, chicken, juice, eggs, oranges, coffee      |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T150        | tomatoes, coffee                                                                                  |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T151        | bread, juice, bananas, chicken, butter, oranges, milk, potatoes                                   |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T152        | chicken, bananas, juice, bread                                                                    |
# +-------------+---------------------------------------------------------------------------------------------------+
# | T153        | coffee, pasta, eggs                                                                               |
# +-------------+---------------------------------------------------------------------------------------------------+

# %% [markdown]
# # Tabu Search Preprocessing

# %%
# ... existing code ...
# Fungsi Tabu Search (jalankan di sel baru sebelum FP-Growth)
def tabu_search(transactions, max_iter=15, tabu_size=5, k=5, threshold=0.5):
    """
    Tabu Search untuk memilih k item fokus dari transaksi dan mem-filter
    transaksi sebelum FP-Growth.

    Args:
        transactions (List[List[str]]): daftar transaksi (list item per struk)
        max_iter (int): jumlah iterasi maksimal
        tabu_size (int): ukuran tabu list (tenure)
        k (int): jumlah item fokus yang dipilih
        threshold (float): minimum support relatif (0..1) untuk kandidat item

    Returns:
        dict: {
          'selected_items': List[str],
          'filtered_transactions': List[List[str]],
          'score': float
        }
    """
    from collections import Counter, deque
    from itertools import combinations

    n = len(transactions)
    if n == 0:
        return {'selected_items': [], 'filtered_transactions': [], 'score': 0.0}

    # Gunakan set per transaksi untuk menghitung presence dengan benar
    trx_sets = [set(t) for t in transactions]

    # Support single items (presence-based)
    item_counts = Counter()
    for s in trx_sets:
        item_counts.update(s)
    item_support = {it: item_counts[it] / n for it in item_counts}

    # Support pasangan (co-occurrence presence-based)
    pair_counts = Counter()
    for s in trx_sets:
        for a, b in combinations(sorted(s), 2):
            pair_counts[(a, b)] += 1
    pair_support = {p: pair_counts[p] / n for p in pair_counts}

    # Kandidat awal berdasar threshold; fallback jika kosong
    universe = [it for it, sup in item_support.items() if sup >= threshold]
    if not universe:
        universe = [it for it, _ in item_counts.most_common()]

    # Inisialisasi solusi dengan top-k by support
    init = [it for it, _ in sorted(((it, item_support[it]) for it in universe),
                                   key=lambda x: (-x[1], x[0]))][:k]
    S = set(init)

    # Objective: gabungan support rata-rata dan ko-occurrence internal
    def score_set(Sset):
        if not Sset:
            return 0.0
        Slist = sorted(Sset)
        s1 = sum(item_support.get(it, 0.0) for it in Slist) / len(Slist)
        if len(Slist) >= 2:
            pairs = list(combinations(Slist, 2))
            s2 = sum(pair_support.get(tuple(sorted(p)), 0.0) for p in pairs)
            s2 = s2 / len(pairs)
        else:
            s2 = 0.0
        # Bobot (bisa di-tune)
        return 0.6 * s1 + 0.4 * s2

    best_S = set(S)
    best_score = score_set(best_S)

    tabu = deque(maxlen=tabu_size)

    for _ in range(max_iter):
        current_best_neighbor = None
        current_best_move = None
        current_best_score = -1.0

        # Generate neighbors: add/remove/swap
        # ADD
        if len(S) < k:
            for x in universe:
                if x in S:
                    continue
                move_token = ("add", x)
                cand = set(S)
                cand.add(x)
                sc = score_set(cand)
                if move_token in tabu and sc <= best_score:
                    continue  # tabu, tidak memenuhi aspiration
                if sc > current_best_score:
                    current_best_score = sc
                    current_best_neighbor = cand
                    current_best_move = move_token

        # REMOVE
        for i in list(S):
            move_token = ("remove", i)
            cand = set(S)
            cand.remove(i)
            sc = score_set(cand)
            if move_token in tabu and sc <= best_score:
                continue
            if sc > current_best_score:
                current_best_score = sc
                current_best_neighbor = cand
                current_best_move = move_token

        # SWAP
        for i in list(S):
            for x in universe:
                if x in S:
                    continue
                move_token = ("swap", i, x)
                cand = set(S)
                cand.remove(i)
                if len(cand) < k:
                    cand.add(x)
                sc = score_set(cand)
                if move_token in tabu and sc <= best_score:
                    continue
                if sc > current_best_score:
                    current_best_score = sc
                    current_best_neighbor = cand
                    current_best_move = move_token

        # Jika tak ada neighbor valid, berhenti
        if current_best_neighbor is None:
            break

        # Apply move
        S = current_best_neighbor
        tabu.append(current_best_move)

        # Update best (global)
        if current_best_score > best_score:
            best_S = set(S)
            best_score = current_best_score

    # Filter transaksi ke item terpilih
    selected_items = sorted(best_S)
    filtered = []
    for t in transactions:
        ft = [it for it in t if it in best_S]
        if ft:
            filtered.append(ft)

    return {
        'selected_items': selected_items,
        'filtered_transactions': filtered,
        'score': best_score
    }
# ... existing code ...

# %%
# ... existing code ...
# Normalisasi nama barang ke huruf kecil
df['Itemname'] = df['Itemname'].str.lower()

# Mengelompokkan barang per transaksi (BillNo) 
transactions = df.groupby('BillNo')['Itemname'].apply(list).tolist()

# Jalankan Tabu Search sebelum FP-Growth
tabu_out = tabu_search(transactions, max_iter=15, tabu_size=5, k=5, threshold=0.5)
transactions_tabu = tabu_out['filtered_transactions']
selected_items = tabu_out['selected_items']
print("\n🔧 Tabu Search: item terpilih →", ", ".join(selected_items))
print(f"Total transaksi setelah filter: {len(transactions_tabu)} dari {len(transactions)}")
# ... existing code ...
# Out:
# 🔧 Tabu Search: item terpilih → bananas, cereal
# Total transaksi setelah filter: 59 dari 153

# %%
# Encode transaksi ke format biner
te = TransactionEncoder()
te_ary = te.fit(transactions_tabu).transform(transactions_tabu)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# Tampilan hasil data encoding
drawLine()
print("TRANSACTION ENCODER RESULTS - BINARY FORMAT")
drawLine()
print(f"Dataset Shape: {df_encoded.shape[0]} transaksi × {df_encoded.shape[1]} item")
print("\n10 Data Pertama:")
drawLine()

print(tabulate(df_encoded.head(10), headers='keys', tablefmt='grid', showindex=True)) # 1 = True, 0 = False
# Out:
# ────────────────────────────────────────
# TRANSACTION ENCODER RESULTS - BINARY FORMAT
# ────────────────────────────────────────
# Dataset Shape: 59 transaksi × 2 item
#
# 10 Data Pertama:
# ────────────────────────────────────────
# +----+-----------+----------+
# |    |   bananas |   cereal |
# +====+===========+==========+
# |  0 |         0 |        1 |
# +----+-----------+----------+
# |  1 |         0 |        1 |
# +----+-----------+----------+
# |  2 |         1 |        0 |
# +----+-----------+----------+
# |  3 |         1 |        0 |
# +----+-----------+----------+
# |  4 |         1 |        0 |
# +----+-----------+----------+
# |  5 |         1 |        1 |
# +----+-----------+----------+
# |  6 |         1 |        1 |
# +----+-----------+----------+
# |  7 |         0 |        1 |
# +----+-----------+----------+
# |  8 |         0 |        1 |
# +----+-----------+----------+
# |  9 |         1 |        0 |
# +----+-----------+----------+

# %% [markdown]
# ## Manual Algorithm FP Growth

# %% [markdown]
# ### Configure FP Common Algorithm

# %%
def setup_fptree(df, min_support):
    """
    Membangun struktur FP-Tree dari DataFrame transaksi.
    
    Langkah-langkah:
    1. Hitung jumlah transaksi (baris).
    2. Deteksi apakah DataFrame dalam format sparse.
    3. Buat matriks 'disabled' untuk menandai nilai yang hilang (NaN) atau tidak valid.
    4. Hitung support relatif setiap item dengan mengabaikan baris yang disabled.
    5. Filter item yang memenuhi min_support.
    6. Urutkan item berdasarkan support (descending) untuk pembangunan tree.
    7. Bangun FP-Tree dengan memasukkan setiap transaksi yang sudah difilter dan diurutkan.
    
    Returns:
        tree: objek FPTree yang sudah terisi
        disabled: ndarray penanda baris/item yang tidak valid
        rank: dict pemetaan item ke urutan prioritas
    """
    num_itemsets = len(df.index)

    # Deteksi format sparse
    is_sparse = False
    if hasattr(df, "sparse"):
        if df.size == 0:
            itemsets = df.values
        else:
            itemsets = df.sparse.to_coo().tocsr()
            is_sparse = True
    else:
        itemsets = df.values

    # Buat masker untuk nilai yang hilang / tidak valid
    disabled = df.copy()
    disabled = np.where(pd.isna(disabled), 1, np.nan) + np.where(
        (disabled == 0) | (disabled == 1), np.nan, 0
    )

    # Hitung support tiap item dengan mengabaikan baris disabled
    item_support = np.array(
        np.nansum(df.values, axis=0)
        / (float(num_itemsets) - np.nansum(disabled, axis=0))
    )
    item_support = item_support.reshape(-1)
    items = np.nonzero(item_support >= min_support)[0]

    # Urutkan item berdasarkan support (descending)
    indices = item_support[items].argsort()
    rank = {item: i for i, item in enumerate(items[indices])}

    # Hapus nilai nol pada sparse matrix untuk efisiensi
    if is_sparse:
        itemsets.eliminate_zeros()

    # Bangun FP-Tree
    tree = FPTree(rank)
    for i in range(num_itemsets):
        if is_sparse:
            nonnull = itemsets.indices[itemsets.indptr[i] : itemsets.indptr[i + 1]]
        else:
            nonnull = np.where(itemsets[i, :])[0]
        # Filter item yang memenuhi min_support lalu urutkan sesuai rank
        itemset = [item for item in nonnull if item in rank]
        itemset.sort(key=rank.get, reverse=True)
        tree.insert_ordered_itemset(itemset)

    return tree, disabled, rank


def generate_itemsets_with_supports(generator, df, disabled, min_support, num_itemsets, colname_map):
    """
    Menghasilkan daftar itemset beserta nilai support-nya dari generator pola yang ditemukan.
    
    Langkah-langkah:
    1. Iterasi setiap (support, itemset) dari generator.
    2. Hitung support yang sudah dikoreksi dengan mengabaikan baris disabled.
       - Untuk itemset tunggal: langsung kurangi jumlah disabled.
       - Untuk itemset >1: periksa tiap baris, hitung penyebut (baris yang valid) dan pembilang (itemset yang valid).
    3. Filter hasil akhir yang memenuhi min_support.
    4. (Opsional) ubah nama kolom sesuai pemetaan yang diberikan.
    
    Returns:
        DataFrame dengan kolom 'support' dan 'itemsets'
    """
    itemsets = []
    supports = []
    for sup, iset in generator:
        itemsets.append(frozenset(iset))
        dec = disabled[:, iset]
        _dec = df.values[:, iset]

        if len(iset) == 1:
            supports.append((sup - np.nansum(dec)) / (num_itemsets - np.nansum(dec)))

        elif len(iset) > 1:
            denom = 0
            num = 0
            for i in range(dec.shape[0]):
                item_dsbl = list(dec[i, :])
                item_orig = list(_dec[i, :])

                if 1 in set(item_dsbl):
                    denom += 1

                    if (0 not in set(item_orig)) or (
                        all(np.isnan(x) for x in item_orig)
                    ):
                        num -= 1

            if num_itemsets - denom == 0:
                supports.append(0)
            else:
                supports.append((sup + num) / (num_itemsets - denom))

    res_df = pd.DataFrame({"support": supports, "itemsets": itemsets})
    res_df = res_df[res_df["support"] >= min_support]

    if colname_map is not None:
        res_df["itemsets"] = res_df["itemsets"].apply(
            lambda x: frozenset([colname_map[i] for i in x])
        )

    return res_df


def check_valid_input(df, null_values=False):
    """
    Validasi keabsahan DataFrame input.
    
    Langkah-langkah:
    1. Lewati jika df None.
    2. Tolak SparseDataFrame yang sudah deprecated.
    3. Untuk sparse matrix, pastikan nama kolom string atau dimulai 0.
    4. Periksa tipe data: semua kolom harus boolean (atau boleh NaN bila null_values=True).
    5. Beri peringatan jika ada tipe non-bool.
    6. Pastikan nilai hanya 0, 1, True, False, (dan NaN bila null_values=True).
    
    Raises:
        TypeError, ValueError bila input tidak valid.
    """
    if df is None:
        return

    # Blokir SparseDataFrame deprecated
    if f"{type(df)}" == "<class 'pandas.core.frame.SparseDataFrame'>":
        msg = (
            "SparseDataFrame sudah kedaluwarsa. Gunakan DataFrame biasa dengan kolom sparse."
        )
        raise TypeError(msg)

    if df.size == 0:
        return
    if hasattr(df, "sparse"):
        if not isinstance(df.columns[0], str) and df.columns[0] != 0:
            raise ValueError(
                "Pembatasan Pandas: nama kolom bertipe int harus diawali 0 atau ubah jadi string: "
                "`df.columns = [str(i) for i in df.columns]`."
            )

    # Cek tipe data: semua boolean (ataboleh NaN bila null_values=True)
    if null_values:
        all_bools = (
            df.apply(lambda col: col.apply(lambda x: pd.isna(x) or isinstance(x, bool)))
            .all()
            .all()
        )
    else:
        all_bools = df.dtypes.apply(pd.api.types.is_bool_dtype).all()

    if not all_bools:
        warnings.warn(
            "Tipe data non-bool memperlambat komputasi. "
            "Gunakan DataFrame bertipe bool.",
            DeprecationWarning,
        )

        has_nans = pd.isna(df).any().any()
        if null_values and not has_nans:
            warnings.warn(
                "null_values=True lambat bila tak ada NaN. Gunakan False."
            )
        if not null_values and has_nans:
            raise ValueError(
                "NaN values are not permitted"
            )

        # Ambil nilai aktual untuk dicek
        if hasattr(df, "sparse"):
            if df.size == 0:
                values = df.values
            else:
                values = df.sparse.to_coo().tocoo().data
        else:
            values = df.values

        if null_values:
            idxs = np.where((values != 1) & (values != 0) & (~np.isnan(values)))
        else:
            idxs = np.where((values != 1) & (values != 0))

        if len(idxs[0]) > 0:
            val = values[tuple(loc[0] for loc in idxs)]
            s = (
                "The allowed values for a DataFrame"
                " are True, False, 0, 1. Found value %s" % (val)
            )

            if null_values:
                s = (
                    "The allowed values for a DataFrame"
                    " are True, False, 0, 1, NaN. Found value %s" % (val)
                )
            raise ValueError(s)


class FPTree(object):
    """
    Struktur data FP-Tree untuk menyimpan transaksi dalam bentuk pohon.
    Setiap node merepresentasikan item dengan count tertentu.
    """
    def __init__(self, rank=None):
        # Root node virtual (item=None)
        self.root = FPNode(None)
        # Dictionary menampung daftar node per item
        self.nodes = collections.defaultdict(list)
        # Item kondisi untuk conditional tree
        self.cond_items = []
        # Urutan prioritas item (support descending)
        self.rank = rank

    def conditional_tree(self, cond_item, minsup):
        """
        Bangun conditional FP-Tree untuk item tertentu.
        
        Langkah-langkah:
        1. Kumpulkan semua path dari root ke node cond_item.
        2. Hitung count tiap item pada path-path tersebut.
        3. Filter item yang memenuhi minsup.
        4. Bangun conditional tree baru dengan item yang sudah difilter & diurutkan.
        
        Returns:
            FPTree baru yang dikondisikan pada cond_item
        """
        branches = []
        count = collections.defaultdict(int)
        for node in self.nodes[cond_item]:
            branch = node.get_item_path_from_root()
            branches.append(branch)
            for item in branch:
                count[item] += node.count

        # Item yang memenuhi minsup, diurutkan ascending (untuk kemudahan)
        items = [item for item in count if count[item] >= minsup]
        items.sort(key=count.get)
        rank = {item: i for i, item in enumerate(items)}

        # Bangun conditional tree
        cond_tree = FPTree(rank)
        for idx, branch in enumerate(branches):
            branch = sorted(
                [i for i in branch if i in rank], key=rank.get, reverse=True
            )
            cond_tree.insert_ordered_itemset(branch, self.nodes[cond_item][idx].count)
        cond_tree.cond_items = self.cond_items + [cond_item]

        return cond_tree

    def insert_ordered_itemset(self, itemset, count=1):
        """
        Masukkan itemset (urutan menurun support) ke dalam tree.
        
        Langkah-langkah:
        1. Naikkan count root.
        2. Untuk setiap item, jika child sudah ada naikkan count, jika tidak buat node baru.
        3. Simpan node pada dictionary nodes untuk akses cepat.
        """
        self.root.count += count

        if len(itemset) == 0:
            return

        index = 0
        node = self.root
        for item in itemset:
            if item in node.children:
                child = node.children[item]
                child.count += count
                node = child
                index += 1
            else:
                break

        # Sisanya buat cabang baru
        for item in itemset[index:]:
            child_node = FPNode(item, count, node)
            self.nodes[item].append(child_node)
            node = child_node

    def is_single_path(self):
        """
        Cek apakah tree hanya berisi satu path lurus (untuk optimasi mining).
        
        Returns:
            bool: True bila tree hanya satu jalur dari root ke leaf
        """
        if len(self.root.children) > 1:
            return False
        for i in self.nodes:
            if len(self.nodes[i]) > 1 or len(self.nodes[i][0].children) > 1:
                return False
        return True

    def print_status(self, count, colnames):
        """
        Cetak status proses mining untuk debugging.
        
        Args:
            count: jumlah itemset yang sudah ditemukan
            colnames: dict pemetaan index ke nama kolom
        """
        cond_items = [str(i) for i in self.cond_items]
        if colnames:
            cond_items = [str(colnames[i]) for i in self.cond_items]
        cond_items = ", ".join(cond_items)
        print(
            "\r%d itemset dari tree yang dikondisikan pada item (%s)" % (count, cond_items),
            end="\n",
        )


class FPNode(object):
    """
    Node individual di dalam FP-Tree.
    """
    def __init__(self, item, count=0, parent=None):
        self.item = item          # Nama item (None untuk root)
        self.count = count        # Jumlah transaksi yang melewati node ini
        self.parent = parent      # Node induk
        self.children = collections.defaultdict(FPNode)  # Child nodes

        if parent is not None:
            parent.children[item] = self

    def get_item_path_from_root(self):
        """
        Ambil path item dari root (tidak termasuk node ini) dalam urutan root -> ... -> parent.
        
        Returns:
            list: item-item pada jalur, sudah diurutkan dari root
        """
        path = []
        if self.item is None:
            return path

        node = self.parent
        while node.item is not None:
            path.append(node.item)
            node = node.parent

        path.reverse()
        return path

# %% [markdown]
# ### Configure FP Growth Algorithm

# %%
def fpgrowth(
    df, min_support=0.5, null_values=False, use_colnames=False, max_len=None, verbose=0
):
    # Langkah 1: Validasi DataFrame masukan dan flag penanganan nilai null
    check_valid_input(df, null_values)

    # Langkah 2: Pastikan min_support berada dalam rentang yang valid (0, 1]
    if min_support <= 0.0:
        raise ValueError(
            "`min_support` harus angka positif "
            "dalam interval `(0, 1]`. "
            "Didapat %s." % min_support
        )

    # Langkah 3: Bangun pemetaan nama kolom jika pengguna ingin menyimpan nama kolom asli
    colname_map = None
    if use_colnames:
        colname_map = {idx: item for idx, item in enumerate(df.columns)}

    # Langkah 4: Bangun FP-tree dan identifikasi item yang dinonaktifkan (di bawah min_support)
    tree, disabled, _ = setup_fptree(df, min_support)

    # Langkah 5: Ubah min_support relatif menjadi hitungan absolut
    minsup = math.ceil(min_support * len(df.index))

    # Langkah 6: Buat generator yang secara malas menghasilkan itemset yang sering
    generator = fpg_step(tree, minsup, colname_map, max_len, verbose)

    # Langkah 7: Pasca-proses generator untuk melampirkan nilai support dan kembalikan hasil akhir
    return generate_itemsets_with_supports(
        generator, df, disabled, min_support, len(df.index), colname_map
    )


def fpg_step(tree, minsup, colnames, max_len, verbose):
    # Langkah 1: Inisialisasi penghitung untuk itemset yang dihasilkan dan ambil item tree saat ini
    count = 0
    items = tree.nodes.keys()

    # Langkah 2: Tangani kasus khusus ketika FP-tree berupa jalur tunggal
    if tree.is_single_path():
        # Tentukan ukuran kombinasi maksimal dengan memperhatikan batasan max_len
        size_remain = len(items) + 1
        if max_len:
            size_remain = max_len - len(tree.cond_items) + 1
        # Hasilkan semua kombinasi non-kosong dari item pada jalur
        for i in range(1, size_remain):
            for itemset in itertools.combinations(items, i):
                count += 1
                # Kombinasi adalah hitungan minimum dari item-itemnya
                support = min([tree.nodes[i][0].count for i in itemset])
                yield support, tree.cond_items + list(itemset)

    # Langkah 3: Jika tree bukan jalur tunggal, hasilkan setiap perluasan item
    elif not max_len or max_len > len(tree.cond_items):
        for item in items:
            count += 1
            # Agregasikan support untuk item di semua nodenya
            support = sum([node.count for node in tree.nodes[item]])
            yield support, tree.cond_items + [item]

    # Langkah 4: print
    if verbose:
        tree.print_status(count, colnames)

    # Langkah 5: Secara rekursif jalankan FP-tree bersyarat untuk setiap item
    if not tree.is_single_path() and (not max_len or max_len > len(tree.cond_items)):
        for item in items:
            # Bangun FP-tree bersyarat untuk item saat ini
            cond_tree = tree.conditional_tree(item, minsup)
            # Secara rekursif hasilkan itemset yang sering dari tree bersyarat
            for sup, iset in fpg_step(cond_tree, minsup, colnames, max_len, verbose):
                yield sup, iset

# %% [markdown]
# ### Implementation FP Growth

# %%
# Hitung frequent itemsets dengan nilai support
frequent_itemsets = fpgrowth(df_encoded, min_support=0.001, use_colnames=True)
print("\nHasil Frequent Itemset dengan nilai support: \n\n", frequent_itemsets)

frequent_itemsets_sorted = frequent_itemsets.sort_values(by='support', ascending=False).head(20)
# Grafik Horizontal
plt.figure(figsize=(10, 8))
sns.barplot(x='support', y='itemsets', data=frequent_itemsets_sorted, palette='viridis')
plt.title('20 Itemset Frekuen Teratas Berdasarkan Support', fontsize=16, fontweight='bold')
plt.xlabel('Support', fontsize=12)
plt.ylabel('Itemsets', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Hitung frequent itemsets dengan nilai support
# ----> 2 frequent_itemsets = fpgrowth(df_encoded, min_support=0.001, use_colnames=True)
#       3 print("\nHasil Frequent Itemset dengan nilai support: \n\n", frequent_itemsets)
#       5 frequent_itemsets_sorted = frequent_itemsets.sort_values(by='support', ascending=False).head(20)
#
# Cell In[13], line 30, in fpgrowth(df, min_support, null_values, use_colnames, max_len, verbose)
#      27 generator = fpg_step(tree, minsup, colname_map, max_len, verbose)
#      29 # Langkah 7: Pasca-proses generator untuk melampirkan nilai support dan kembalikan hasil akhir
# ---> 30 return generate_itemsets_with_supports(
#      31     generator, df, disabled, min_support, len(df.index), colname_map
#      32 )
#
# Cell In[12], line 86, in generate_itemsets_with_supports(generator, df, disabled, min_support, num_itemsets, colname_map)
#      84 itemsets = []
#      85 supports = []
# ---> 86 for sup, iset in generator:
#      87     itemsets.append(frozenset(iset))
#      88     dec = disabled[:, iset]
#
# Cell In[13], line 72, in fpg_step(tree, minsup, colnames, max_len, verbose)
#      70 cond_tree = tree.conditional_tree(item, minsup)
#      71 # Secara rekursif hasilkan itemset yang sering dari tree bersyarat
# ---> 72 for sup, iset in fpg_step(cond_tree, minsup, colnames, max_len, verbose):
#      73     yield sup, iset
#
# Cell In[13], line 48, in fpg_step(tree, minsup, colnames, max_len, verbose)
#      46 # Hasilkan semua kombinasi non-kosong dari item pada jalur
#      47 for i in range(1, size_remain):
# ---> 48     for itemset in itertools.combinations(items, i):
#      49         count += 1
#      50         # Kombinasi adalah hitungan minimum dari item-itemnya
#
# NameError: name 'itertools' is not defined

# %%
# mengurutkan berdasarkan prioritas 1-itemset
single_items = frequent_itemsets[frequent_itemsets['itemsets'].apply(lambda x: len(x) == 1)]

single_items_sorted = single_items.sort_values(by='support', ascending=False)

# Menampilkan grafik batang dengan keterangan
import matplotlib.pyplot as plt

labels = [list(item)[0] for item in single_items_sorted['itemsets']]
supports = single_items_sorted['support'].values

plt.figure(figsize=(10, 6))
bars = plt.bar(labels, supports, color='skyblue')

# Keterangan
plt.xlabel('Item')
plt.ylabel('Support')
plt.title('Support untuk 1-Itemset')
plt.xticks(rotation=45, ha='right')

for bar, sup in zip(bars, supports):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.001,
             f'{sup:.3f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## CBP

# %%
# Tujuan: Membangun Conditional Pattern Base (CPB) untuk setiap 1-itemset
#          – himpunan jalur prefiks yang muncul bersama item tertentu.
#          CPB ini menjadi masukan untuk menambang pola frekuensi dengan FP-Growth.
from collections import defaultdict

# 1: Hitung frekuensi global setiap item
item_counts = defaultdict(int)
for transaction in transactions:
    for item in transaction:
        item_counts[item] += 1

# 2: Hapus item di bawah ambang minimum support
min_support = 0.01 * len(transactions)
item_counts = {item: count for item, count in item_counts.items() if count >= min_support}

# 3: Urutkan item yang tersisa secara menurun berdasarkan frekuensi
def sort_items(transaction):
    return sorted([item for item in transaction if item in item_counts],
                  key=lambda item: (-item_counts[item], item))

sorted_transactions = [sort_items(t) for t in transactions]

# 4: Bangun FP-Tree
class FPNode:
    def __init__(self, item, count=1):
        self.item = item
        self.count = count
        self.children = {}
        self.parent = None

class FPTree:
    def __init__(self):
        self.root = FPNode(None)
        self.headers = defaultdict(list)

    def insert(self, transaction):
        current = self.root
        for item in transaction:
            if item in current.children:
                current.children[item].count += 1
            else:
                new_node = FPNode(item)
                new_node.parent = current
                current.children[item] = new_node
                self.headers[item].append(new_node)
            current = current.children[item]

    def conditional_pattern_base(self, item):
        patterns = []
        for node in self.headers[item]:
            path = []
            current = node.parent
            while current and current.item is not None:
                path.append(current.item)
                current = current.parent
            if path:
                patterns.append((list(reversed(path)), node.count))
        return patterns

# 5: Isi FP-Tree dengan transaksi yang sudah diurutkan
tree = FPTree()
for transaction in sorted_transactions:
    tree.insert(transaction)

# 6: Tampilkan Conditional Pattern Base untuk setiap 1-itemset yang frekuen
print("\nConditional Pattern Base untuk semua item:")
for item in item_counts.keys():
    cpb = tree.conditional_pattern_base(item)
    print(f"\nItem: {item}")
    if cpb:
        for pattern, count in cpb:
            print(f"  Jalur: {pattern}, Hitungan: {count}")
    else:
        print("  (Tidak ada pola)")
# Out:
# Conditional Pattern Base untuk semua item:
#
# Item: apples
#   Jalur: ['eggs', 'potatoes'], Hitungan: 1
#   Jalur: ['potatoes', 'tomatoes', 'sugar'], Hitungan: 1
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes', 'sugar', 'yogurt'], Hitungan: 1
#   Jalur: ['bananas', 'tomatoes', 'sugar', 'yogurt'], Hitungan: 1
#   Jalur: ['oranges', 'cheese', 'tomatoes', 'yogurt'], Hitungan: 1
#   Jalur: ['cheese'], Hitungan: 1
#   Jalur: ['cheese', 'tomatoes', 'sugar'], Hitungan: 1
#   Jalur: ['cereal', 'oranges', 'cheese', 'eggs', 'potatoes'], Hitungan: 1
#   Jalur: ['potatoes'], Hitungan: 1
#   Jalur: ['bananas', 'sugar'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'sugar', 'yogurt'], Hitungan: 1
#   Jalur: ['cereal', 'tomatoes'], Hitungan: 1
#   Jalur: ['coffee', 'potatoes', 'sugar', 'yogurt'], Hitungan: 1
#   Jalur: ['coffee'], Hitungan: 1
#   Jalur: ['sugar'], Hitungan: 1
#   Jalur: ['sugar', 'yogurt'], Hitungan: 1
#   Jalur: ['oranges'], Hitungan: 1
#   Jalur: ['eggs'], Hitungan: 1
#   Jalur: ['yogurt'], Hitungan: 1
#   Jalur: ['coffee', 'oranges', 'cheese', 'potatoes', 'yogurt'], Hitungan: 1
#
# Item: butter
#   Jalur: ['eggs', 'potatoes', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'eggs', 'tomatoes'], Hitungan: 1
#   Jalur: ['bananas', 'yogurt'], Hitungan: 1
#   Jalur: ['eggs', 'tomatoes', 'sugar'], Hitungan: 1
#   Jalur: ['cereal'], Hitungan: 1
#   Jalur: ['bananas', 'eggs', 'potatoes', 'tomatoes'], Hitungan: 1
#   Jalur: ['oranges', 'eggs', 'potatoes', 'yogurt'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'oranges', 'potatoes', 'tomatoes'], Hitungan: 1
#   Jalur: ['potatoes', 'tomatoes'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'cheese', 'potatoes'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cheese', 'eggs', 'potatoes'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'eggs', 'yogurt'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'sugar', 'yogurt', 'apples'], Hitungan: 1
#   Jalur: ['cereal', 'tomatoes', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese'], Hitungan: 1
#   Jalur: ['oranges', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'potatoes', 'tomatoes'], Hitungan: 1
#   Jalur: ['oranges'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cereal', 'oranges', 'cheese', 'eggs', 'yogurt'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes'], Hitungan: 1
#
# Item: eggs
#   Jalur: ['bananas'], Hitungan: 3
#   Jalur: ['bananas', 'cereal'], Hitungan: 2
#   Jalur: ['coffee'], Hitungan: 3
#   Jalur: ['cheese'], Hitungan: 1
#   Jalur: ['oranges'], Hitungan: 1
#   Jalur: ['cereal', 'oranges', 'cheese'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cheese'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese'], Hitungan: 1
#   Jalur: ['cereal'], Hitungan: 2
#   Jalur: ['bananas', 'coffee', 'cereal', 'oranges', 'cheese'], Hitungan: 1
#
# Item: potatoes
#   Jalur: ['eggs'], Hitungan: 1
#   Jalur: ['cereal'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'oranges'], Hitungan: 1
#   Jalur: ['bananas', 'oranges'], Hitungan: 3
#   Jalur: ['coffee', 'eggs'], Hitungan: 1
#   Jalur: ['bananas', 'eggs'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese'], Hitungan: 1
#   Jalur: ['oranges', 'eggs'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'oranges'], Hitungan: 1
#   Jalur: ['coffee'], Hitungan: 2
#   Jalur: ['bananas', 'cereal', 'cheese'], Hitungan: 1
#   Jalur: ['cereal', 'oranges', 'cheese', 'eggs'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cheese', 'eggs'], Hitungan: 1
#   Jalur: ['coffee', 'cereal'], Hitungan: 1
#   Jalur: ['cereal', 'eggs'], Hitungan: 1
#   Jalur: ['bananas'], Hitungan: 1
#   Jalur: ['bananas', 'cereal'], Hitungan: 1
#   Jalur: ['oranges'], Hitungan: 1
#   Jalur: ['coffee', 'oranges', 'cheese'], Hitungan: 1
#
# Item: oranges
#   Jalur: ['bananas', 'coffee'], Hitungan: 1
#   Jalur: ['bananas'], Hitungan: 6
#   Jalur: ['coffee'], Hitungan: 3
#   Jalur: ['coffee', 'cereal'], Hitungan: 2
#   Jalur: ['cereal'], Hitungan: 2
#   Jalur: ['bananas', 'coffee', 'cereal'], Hitungan: 1
#
# Item: milk
#   Jalur: ['cereal'], Hitungan: 1
#   Jalur: ['eggs', 'tomatoes', 'sugar', 'butter'], Hitungan: 1
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes', 'sugar', 'yogurt', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'oranges'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes', 'tomatoes'], Hitungan: 1
#   Jalur: ['coffee', 'oranges', 'yogurt'], Hitungan: 1
#   Jalur: ['bananas', 'eggs', 'potatoes', 'tomatoes', 'butter'], Hitungan: 1
#   Jalur: ['oranges', 'cheese', 'tomatoes', 'yogurt', 'apples'], Hitungan: 1
#   Jalur: ['oranges'], Hitungan: 3
#   Jalur: ['cereal', 'oranges', 'cheese', 'eggs', 'potatoes', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'sugar', 'apples'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'sugar', 'yogurt', 'apples', 'butter'], Hitungan: 1
#   Jalur: ['cereal', 'tomatoes', 'apples', 'butter'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese', 'butter'], Hitungan: 1
#   Jalur: ['coffee'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'tomatoes', 'sugar'], Hitungan: 1
#   Jalur: ['oranges', 'butter'], Hitungan: 1
#   Jalur: ['coffee', 'oranges', 'cheese', 'potatoes', 'yogurt', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes', 'butter'], Hitungan: 1
#
# Item: onions
#   Jalur: ['cereal', 'milk'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'oranges', 'potatoes', 'sugar', 'bread'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'cheese'], Hitungan: 1
#   Jalur: ['cereal', 'cheese'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'bread'], Hitungan: 1
#   Jalur: ['eggs', 'tomatoes', 'sugar', 'butter', 'milk', 'juice'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'juice'], Hitungan: 1
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes', 'sugar', 'yogurt', 'apples', 'milk', 'juice'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes', 'tomatoes', 'milk', 'bread'], Hitungan: 1
#   Jalur: ['cheese', 'eggs', 'juice'], Hitungan: 1
#   Jalur: ['cheese', 'apples'], Hitungan: 1
#   Jalur: ['cereal'], Hitungan: 1
#   Jalur: ['cheese', 'tomatoes', 'sugar', 'apples', 'bread'], Hitungan: 1
#   Jalur: ['cereal', 'oranges', 'cheese', 'eggs', 'potatoes', 'apples', 'milk'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'potatoes', 'bread'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'eggs', 'yogurt', 'butter'], Hitungan: 1
#   Jalur: ['yogurt'], Hitungan: 1
#   Jalur: ['sugar'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese', 'butter', 'milk', 'bread'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'tomatoes', 'sugar', 'milk'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'potatoes'], Hitungan: 1
#
# Item: cereal
#   Jalur: ['bananas'], Hitungan: 8
#   Jalur: ['coffee'], Hitungan: 7
#   Jalur: ['bananas', 'coffee'], Hitungan: 1
#
# Item: tomatoes
#   Jalur: ['cereal', 'potatoes'], Hitungan: 1
#   Jalur: ['bananas', 'eggs'], Hitungan: 2
#   Jalur: ['potatoes'], Hitungan: 2
#   Jalur: ['eggs'], Hitungan: 3
#   Jalur: ['coffee', 'eggs', 'potatoes'], Hitungan: 1
#   Jalur: ['bananas'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes'], Hitungan: 1
#   Jalur: ['bananas', 'eggs', 'potatoes'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese', 'potatoes'], Hitungan: 1
#   Jalur: ['oranges', 'cheese'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'oranges', 'potatoes'], Hitungan: 1
#   Jalur: ['cheese'], Hitungan: 2
#   Jalur: ['cereal'], Hitungan: 2
#   Jalur: ['coffee'], Hitungan: 2
#   Jalur: ['cereal', 'oranges', 'cheese'], Hitungan: 1
#   Jalur: ['bananas', 'potatoes'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'eggs'], Hitungan: 1
#
# Item: bananas
#   (Tidak ada pola)
#
# Item: pasta
#   Jalur: ['bananas', 'coffee', 'oranges', 'potatoes', 'sugar', 'bread', 'onions'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'cheese', 'onions'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'eggs'], Hitungan: 1
#   Jalur: ['potatoes', 'tomatoes', 'sugar', 'apples', 'bread'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'juice', 'onions'], Hitungan: 1
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes', 'sugar', 'yogurt', 'apples', 'milk', 'juice', 'onions'], Hitungan: 1
#   Jalur: ['apples', 'bread'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'yogurt'], Hitungan: 1
#   Jalur: ['coffee', 'juice'], Hitungan: 1
#   Jalur: ['cereal', 'oranges', 'cheese', 'eggs', 'potatoes', 'apples', 'milk', 'onions'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'sugar', 'yogurt', 'apples', 'butter', 'milk', 'bread'], Hitungan: 1
#   Jalur: ['milk'], Hitungan: 1
#   Jalur: ['sugar', 'apples'], Hitungan: 1
#   Jalur: ['coffee', 'milk', 'bread'], Hitungan: 1
#   Jalur: ['bananas', 'potatoes', 'tomatoes', 'butter'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'eggs', 'tomatoes'], Hitungan: 1
#   Jalur: ['potatoes', 'sugar'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cereal', 'oranges', 'cheese', 'eggs', 'yogurt', 'butter', 'bread', 'juice'], Hitungan: 1
#   Jalur: ['coffee', 'eggs'], Hitungan: 1
#
# Item: bread
#   Jalur: ['bananas', 'coffee', 'oranges', 'potatoes', 'sugar'], Hitungan: 1
#   Jalur: ['coffee', 'cereal'], Hitungan: 1
#   Jalur: ['potatoes', 'tomatoes', 'sugar', 'apples'], Hitungan: 1
#   Jalur: ['apples'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes', 'tomatoes', 'milk'], Hitungan: 1
#   Jalur: ['coffee', 'oranges', 'yogurt', 'milk'], Hitungan: 1
#   Jalur: ['oranges', 'eggs', 'potatoes', 'yogurt', 'butter'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'oranges', 'potatoes', 'tomatoes', 'butter'], Hitungan: 1
#   Jalur: ['cheese', 'tomatoes', 'sugar', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'cheese', 'potatoes', 'butter'], Hitungan: 1
#   Jalur: ['cheese'], Hitungan: 1
#   Jalur: ['coffee'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'potatoes'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'sugar', 'yogurt', 'apples', 'butter', 'milk'], Hitungan: 1
#   Jalur: ['coffee', 'tomatoes'], Hitungan: 1
#   Jalur: ['coffee', 'potatoes', 'sugar', 'yogurt', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese', 'butter', 'milk'], Hitungan: 1
#   Jalur: ['coffee', 'milk'], Hitungan: 1
#   Jalur: ['oranges', 'apples', 'butter'], Hitungan: 1
#   Jalur: ['yogurt', 'apples'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cereal', 'oranges', 'cheese', 'eggs', 'yogurt', 'butter'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes', 'butter', 'milk'], Hitungan: 1
#   Jalur: ['bananas'], Hitungan: 1
#
# Item: coffee
#   Jalur: ['bananas'], Hitungan: 6
#
# Item: sugar
#   Jalur: ['bananas', 'coffee', 'oranges', 'potatoes'], Hitungan: 1
#   Jalur: ['eggs'], Hitungan: 1
#   Jalur: ['coffee'], Hitungan: 3
#   Jalur: ['potatoes', 'tomatoes'], Hitungan: 1
#   Jalur: ['eggs', 'tomatoes'], Hitungan: 1
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes'], Hitungan: 1
#   Jalur: ['bananas', 'tomatoes'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese', 'potatoes', 'tomatoes'], Hitungan: 1
#   Jalur: ['cheese'], Hitungan: 1
#   Jalur: ['bananas'], Hitungan: 2
#   Jalur: ['tomatoes'], Hitungan: 1
#   Jalur: ['cheese', 'tomatoes'], Hitungan: 1
#   Jalur: ['bananas', 'cheese'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese'], Hitungan: 1
#   Jalur: ['coffee', 'potatoes'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'tomatoes'], Hitungan: 1
#   Jalur: ['bananas', 'eggs', 'tomatoes'], Hitungan: 1
#   Jalur: ['potatoes'], Hitungan: 1
#
# Item: chicken
#   Jalur: ['bananas', 'cereal'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'cheese', 'onions', 'pasta'], Hitungan: 1
#   Jalur: ['pasta'], Hitungan: 1
#   Jalur: ['bananas', 'eggs', 'tomatoes', 'butter'], Hitungan: 1
#   Jalur: ['potatoes', 'tomatoes', 'sugar', 'apples', 'bread', 'pasta'], Hitungan: 1
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes', 'sugar', 'yogurt', 'apples', 'milk', 'juice', 'onions', 'pasta', 'tea'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'oranges', 'potatoes', 'tomatoes', 'butter', 'bread', 'juice'], Hitungan: 1
#   Jalur: ['potatoes', 'tomatoes', 'butter'], Hitungan: 1
#   Jalur: ['cereal', 'oranges', 'cheese', 'eggs', 'potatoes', 'apples', 'milk', 'onions', 'pasta'], Hitungan: 1
#   Jalur: ['cereal', 'tomatoes'], Hitungan: 1
#   Jalur: ['onions'], Hitungan: 1
#   Jalur: ['sugar', 'apples', 'pasta', 'tea'], Hitungan: 1
#   Jalur: ['oranges', 'yogurt'], Hitungan: 1
#   Jalur: ['oranges', 'apples', 'butter', 'bread'], Hitungan: 1
#   Jalur: ['bananas', 'potatoes', 'tomatoes', 'butter', 'pasta'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'potatoes', 'onions'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cereal', 'oranges', 'cheese', 'eggs', 'yogurt', 'butter', 'bread', 'juice', 'pasta'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes', 'butter', 'milk', 'bread', 'juice'], Hitungan: 1
#   Jalur: ['bananas', 'bread', 'juice'], Hitungan: 1
#
# Item: cheese
#   Jalur: ['bananas', 'cereal'], Hitungan: 2
#   Jalur: ['cereal'], Hitungan: 3
#   Jalur: ['bananas', 'oranges'], Hitungan: 2
#   Jalur: ['oranges'], Hitungan: 2
#   Jalur: ['cereal', 'oranges'], Hitungan: 2
#   Jalur: ['bananas', 'coffee'], Hitungan: 1
#   Jalur: ['bananas'], Hitungan: 2
#   Jalur: ['coffee', 'cereal', 'oranges'], Hitungan: 1
#   Jalur: ['coffee', 'cereal'], Hitungan: 3
#   Jalur: ['coffee', 'oranges'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cereal', 'oranges'], Hitungan: 1
#
# Item: tea
#   Jalur: ['bananas', 'cereal', 'eggs', 'pasta'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'juice', 'onions', 'pasta'], Hitungan: 1
#   Jalur: ['cereal', 'butter', 'juice'], Hitungan: 1
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes', 'sugar', 'yogurt', 'apples', 'milk', 'juice', 'onions', 'pasta'], Hitungan: 1
#   Jalur: ['butter', 'juice'], Hitungan: 1
#   Jalur: ['oranges', 'eggs', 'potatoes', 'yogurt', 'butter', 'bread'], Hitungan: 1
#   Jalur: ['oranges', 'cheese', 'tomatoes', 'yogurt', 'apples', 'milk'], Hitungan: 1
#   Jalur: ['coffee', 'juice', 'pasta'], Hitungan: 1
#   Jalur: ['cheese', 'apples', 'onions'], Hitungan: 1
#   Jalur: ['oranges'], Hitungan: 1
#   Jalur: ['cereal', 'cheese', 'yogurt', 'juice'], Hitungan: 1
#   Jalur: ['oranges', 'milk'], Hitungan: 1
#   Jalur: ['yogurt'], Hitungan: 1
#   Jalur: ['coffee', 'potatoes', 'juice'], Hitungan: 1
#   Jalur: ['butter'], Hitungan: 1
#   Jalur: ['bananas', 'cereal', 'cheese', 'potatoes', 'butter', 'bread'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cheese', 'eggs', 'potatoes', 'butter', 'juice'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'potatoes', 'bread', 'onions'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'sugar', 'yogurt', 'apples', 'butter', 'milk', 'bread', 'pasta'], Hitungan: 1
#   Jalur: ['sugar', 'onions'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese', 'butter', 'milk', 'bread', 'onions'], Hitungan: 1
#   Jalur: ['sugar', 'apples', 'pasta'], Hitungan: 1
#   Jalur: ['coffee', 'sugar'], Hitungan: 1
#
# Item: yogurt
#   Jalur: ['bananas'], Hitungan: 2
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes', 'sugar'], Hitungan: 1
#   Jalur: ['bananas', 'tomatoes', 'sugar'], Hitungan: 1
#   Jalur: ['coffee', 'oranges'], Hitungan: 2
#   Jalur: ['bananas', 'oranges', 'cheese', 'potatoes', 'tomatoes', 'sugar'], Hitungan: 1
#   Jalur: ['oranges', 'eggs', 'potatoes'], Hitungan: 1
#   Jalur: ['oranges', 'cheese', 'tomatoes'], Hitungan: 1
#   Jalur: ['bananas', 'coffee'], Hitungan: 1
#   Jalur: ['cereal', 'cheese'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'eggs'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'cheese', 'sugar'], Hitungan: 1
#   Jalur: ['coffee', 'potatoes', 'sugar'], Hitungan: 1
#   Jalur: ['sugar'], Hitungan: 1
#   Jalur: ['oranges'], Hitungan: 1
#   Jalur: ['bananas', 'eggs', 'tomatoes', 'sugar'], Hitungan: 1
#   Jalur: ['coffee', 'oranges', 'cheese', 'potatoes'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cereal', 'oranges', 'cheese', 'eggs'], Hitungan: 1
#
# Item: juice
#   Jalur: ['eggs', 'tomatoes', 'sugar', 'butter', 'milk'], Hitungan: 1
#   Jalur: ['bananas', 'coffee'], Hitungan: 1
#   Jalur: ['cereal', 'butter'], Hitungan: 1
#   Jalur: ['yogurt'], Hitungan: 1
#   Jalur: ['coffee', 'eggs', 'potatoes', 'tomatoes', 'sugar', 'yogurt', 'apples', 'milk'], Hitungan: 1
#   Jalur: ['butter'], Hitungan: 1
#   Jalur: ['bananas', 'eggs', 'potatoes', 'tomatoes', 'butter', 'milk'], Hitungan: 1
#   Jalur: ['cheese', 'eggs'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'cheese', 'potatoes', 'tomatoes', 'sugar', 'yogurt'], Hitungan: 1
#   Jalur: ['coffee', 'cereal', 'oranges', 'potatoes', 'tomatoes', 'butter', 'bread'], Hitungan: 1
#   Jalur: ['coffee'], Hitungan: 2
#   Jalur: ['cereal', 'cheese', 'yogurt'], Hitungan: 1
#   Jalur: ['coffee', 'potatoes'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cheese', 'eggs', 'potatoes', 'butter'], Hitungan: 1
#   Jalur: ['coffee', 'potatoes', 'sugar', 'yogurt', 'apples', 'bread'], Hitungan: 1
#   Jalur: ['eggs'], Hitungan: 1
#   Jalur: ['bananas', 'cereal'], Hitungan: 1
#   Jalur: ['bananas', 'coffee', 'cereal', 'oranges', 'cheese', 'eggs', 'yogurt', 'butter', 'bread'], Hitungan: 1
#   Jalur: ['bananas', 'oranges', 'potatoes', 'butter', 'milk', 'bread'], Hitungan: 1
#   Jalur: ['bananas', 'bread'], Hitungan: 1

# %% [markdown]
# ## Conditional FP TREE

# %%
# pembentukan conditional FP-TREE
# Tujuan: membangun sub-pohon (conditional FP-Tree) untuk setiap item yang sering muncul
#         sehingga kita bisa menemukan semua pola (frequent itemset) yang mengandung item tersebut
#         tanpa harus memindai seluruh database lagi.

from collections import defaultdict

# 1: Hitung frekuensi tiap item dan simpan semua transaksi
item_counts = defaultdict(int)
for transaction in transactions:
    for item in transaction:
        item_counts[item] += 1

# 2: Hapus item yang tidak memenuhi min_support
min_support = 0.01 * len(transactions)  # min_support absolut, bukan proporsi
item_counts = {item: count for item, count in item_counts.items() if count >= min_support}

# Step 3: Sort item dalam transaksi berdasarkan frekuensi
def sort_items(transaction):
    return sorted(
        [item for item in transaction if item in item_counts],
        key=lambda item: (-item_counts[item], item)
    )

sorted_transactions = [sort_items(t) for t in transactions]

# 4: Bangun FP-Tree
class FPNode:
    def __init__(self, item, count=1):
        self.item = item
        self.count = count
        self.children = {}
        self.parent = None

class FPTree:
    def __init__(self):
        self.root = FPNode(None)
        self.headers = defaultdict(list)

    def insert(self, transaction):
        current = self.root
        for item in transaction:
            if item in current.children:
                current.children[item].count += 1
            else:
                new_node = FPNode(item)
                new_node.parent = current
                current.children[item] = new_node
                self.headers[item].append(new_node)
            current = current.children[item]

    def conditional_pattern_base(self, item):
        patterns = []
        for node in self.headers[item]:
            path = []
            current = node.parent
            while current and current.item is not None:
                path.append(current.item)
                current = current.parent
            if path:
                patterns.append((list(reversed(path)), node.count))
        return patterns

# 5: Masukkan transaksi ke dalam FP-Tree
tree = FPTree()
for transaction in sorted_transactions:
    tree.insert(transaction)

# 6: Conditional FP-Tree untuk setiap item
def build_conditional_fptree(cpb, min_support):
    # Step 1: Hitung frekuensi item dari CPB
    item_freq = defaultdict(int)
    for pattern, count in cpb:
        for item in pattern:
            item_freq[item] += count

    # Step 2: Filter berdasarkan min_support
    frequent_items = {item: freq for item, freq in item_freq.items() if freq >= min_support}

    # Step 3: Urutkan item dalam setiap pattern berdasarkan frekuensi (descending)
    def sort_pattern(pattern):
        return sorted([item for item in pattern if item in frequent_items],
                      key=lambda x: (-frequent_items[x], x))

    sorted_patterns = [(sort_pattern(pattern), count) for pattern, count in cpb]

    # Step 4: Bangun Conditional FP-Tree
    root = FPNode(None)
    for pattern, count in sorted_patterns:
        current_node = root
        for item in pattern:
            current_node = current_node.children.get(item, FPNode(item))
            current_node.count += count
            current_node.parent = root
            root.children[item] = current_node

    return root

# 7: Loop untuk membangun Conditional FP-Tree untuk semua item
print("\nConditional FP-Tree untuk setiap item:")
for item in item_counts.keys():
    cpb = tree.conditional_pattern_base(item)
    if cpb:
        print(f"\nItem: {item}")
        root = build_conditional_fptree(cpb, min_support)

        # Fungsi untuk mencetak tree
        def print_tree(node, indent=0):
            for child in node.children.values():
                print('  ' * indent + f"{child.item} ({child.count})")
                print_tree(child, indent + 1)

        # Tampilkan hasil
        print_tree(root)
    else:
        print(f"  Tidak ada Conditional Pattern Base untuk item '{item}'")
# Out:
# Conditional FP-Tree untuk setiap item:
#
# Item: apples
# potatoes (2)
# eggs (3)
# sugar (10)
# tomatoes (3)
# yogurt (4)
# coffee (2)
# bananas (2)
# cheese (2)
# oranges (2)
# cereal (2)
#
# Item: butter
# potatoes (2)
# eggs (2)
# apples (2)
# bananas (10)
# tomatoes (2)
# yogurt (2)
# sugar (2)
# cereal (2)
# oranges (2)
# coffee (2)
# cheese (2)
#
# Item: eggs
# bananas (8)
# cereal (2)
# coffee (2)
# cheese (2)
# oranges (2)
#
# Item: potatoes
# eggs (2)
# cereal (2)
# bananas (11)
# oranges (7)
# coffee (2)
# cheese (2)
#
# Item: oranges
# bananas (9)
# coffee (2)
# cereal (2)
#
# Item: milk
# cereal (2)
# butter (2)
# tomatoes (3)
# sugar (2)
# eggs (2)
# apples (2)
# coffee (2)
# potatoes (2)
# yogurt (2)
# oranges (13)
# bananas (2)
# cheese (2)
#
# Item: onions
# cereal (11)
# milk (2)
# coffee (2)
# bananas (2)
# bread (2)
# potatoes (2)
# sugar (2)
# oranges (2)
# cheese (2)
# eggs (2)
# tomatoes (2)
# juice (2)
# butter (2)
# apples (2)
# yogurt (3)
#
# Item: cereal
# bananas (10)
# coffee (2)
#
# Item: tomatoes
# potatoes (10)
# cereal (2)
# bananas (3)
# eggs (2)
# coffee (2)
# oranges (2)
# cheese (2)
#   Tidak ada Conditional Pattern Base untuk item 'bananas'
#
# Item: pasta
# coffee (10)
# bananas (2)
# bread (2)
# potatoes (3)
# sugar (2)
# onions (2)
# oranges (2)
# cereal (2)
# cheese (2)
# eggs (2)
# apples (3)
# tomatoes (2)
# juice (2)
# milk (2)
# yogurt (2)
# butter (2)
#
# Item: bread
# coffee (12)
# oranges (3)
# potatoes (2)
# bananas (3)
# sugar (2)
# cereal (2)
# apples (3)
# tomatoes (2)
# milk (2)
# yogurt (2)
# butter (2)
# eggs (2)
# cheese (2)
#
# Item: coffee
# bananas (7)
#
# Item: sugar
# coffee (2)
# bananas (2)
# potatoes (3)
# oranges (2)
# eggs (2)
# tomatoes (10)
# cheese (2)
# cereal (2)
#
# Item: chicken
# bananas (9)
# cereal (2)
# pasta (2)
# onions (2)
# cheese (2)
# butter (2)
# tomatoes (2)
# eggs (2)
# potatoes (2)
# bread (2)
# apples (2)
# sugar (2)
# juice (2)
# coffee (2)
# milk (2)
# yogurt (2)
# tea (2)
# oranges (2)
#
# Item: cheese
# cereal (13)
# bananas (2)
# oranges (2)
# coffee (2)
#
# Item: tea
# cereal (2)
# pasta (3)
# bananas (2)
# eggs (2)
# coffee (3)
# juice (2)
# onions (2)
# butter (9)
# potatoes (2)
# yogurt (2)
# apples (2)
# milk (2)
# sugar (2)
# tomatoes (2)
# bread (2)
# oranges (2)
# cheese (2)
#
# Item: yogurt
# bananas (2)
# coffee (10)
# sugar (2)
# eggs (2)
# potatoes (2)
# tomatoes (2)
# oranges (2)
# cheese (2)
# cereal (2)
#
# Item: juice
# butter (2)
# eggs (2)
# tomatoes (2)
# milk (2)
# sugar (2)
# coffee (10)
# bananas (4)
# cereal (2)
# yogurt (2)
# potatoes (2)
# apples (2)
# cheese (2)
# oranges (2)
# bread (2)

# %%
# mencari conditional frequent itemset
# Fungsi untuk menambang frequent itemsets dari FP-Tree secara rekursif
def mine_tree(tree, suffix, min_support, frequent_patterns):
    for item in tree.headers:
        new_suffix = suffix.copy()
        new_suffix.add(item)

        # Hitung total support item dari header
        support = sum(node.count for node in tree.headers[item])

        if support >= min_support:
            frequent_patterns[frozenset(new_suffix)] = support

            # Bangun CPB dari node
            cpb = tree.conditional_pattern_base(item)

            # Bangun conditional FP-Tree
            conditional_tree = FPTree()
            for path, count in cpb:
                sorted_path = sorted(
                    [i for i in path],
                    key=lambda i: (-item_counts.get(i, 0), i)
                )
                for _ in range(count):  # Tambahkan sesuai count
                    conditional_tree.insert(sorted_path)

            # Rekursif ke bawah pohon
            mine_tree(conditional_tree, new_suffix, min_support, frequent_patterns)

# Menambang frequent itemsets dari pohon utama
frequent_patterns = {}
mine_tree(tree, set(), min_support, frequent_patterns)

# Tampilkan hasil
print("\nFrequent itemsets yang ditemukan (FP-Growth):")
for itemset, support in frequent_patterns.items():
    print(f"{set(itemset)}: {support}")
# Out:
# Frequent itemsets yang ditemukan (FP-Growth):
# {'eggs'}: 27
# {'eggs', 'bananas'}: 7
# {'eggs', 'cereal'}: 7
# {'eggs', 'cereal', 'bananas'}: 3
# {'eggs', 'cereal', 'coffee'}: 2
# {'eggs', 'coffee'}: 6
# {'eggs', 'coffee', 'bananas'}: 2
# {'eggs', 'cheese'}: 5
# {'eggs', 'cereal', 'cheese'}: 3
# {'eggs', 'cereal', 'cheese', 'coffee'}: 2
# {'eggs', 'oranges', 'cheese'}: 2
# {'eggs', 'oranges', 'cereal', 'cheese'}: 2
# {'eggs', 'cheese', 'bananas'}: 2
# {'eggs', 'cheese', 'coffee'}: 3
# {'eggs', 'cheese', 'coffee', 'bananas'}: 2
# {'eggs', 'oranges'}: 3
# {'eggs', 'oranges', 'cereal'}: 2
# {'potatoes'}: 27
# {'eggs', 'potatoes'}: 7
# {'eggs', 'potatoes', 'coffee'}: 2
# {'eggs', 'potatoes', 'bananas'}: 2
# {'eggs', 'oranges', 'potatoes'}: 2
# {'eggs', 'cereal', 'potatoes'}: 2
# {'eggs', 'cheese', 'potatoes'}: 2
# {'cereal', 'potatoes'}: 7
# {'coffee', 'cereal', 'potatoes'}: 2
# {'cereal', 'potatoes', 'bananas'}: 2
# {'potatoes', 'bananas'}: 10
# {'coffee', 'potatoes'}: 8
# {'coffee', 'potatoes', 'bananas'}: 2
# {'oranges', 'potatoes'}: 10
# {'oranges', 'potatoes', 'bananas'}: 5
# {'coffee', 'oranges', 'potatoes'}: 3
# {'oranges', 'cereal', 'potatoes'}: 2
# {'cheese', 'potatoes'}: 5
# {'cheese', 'potatoes', 'bananas'}: 3
# {'oranges', 'cheese', 'potatoes'}: 3
# {'cereal', 'cheese', 'potatoes'}: 2
# {'coffee', 'cheese', 'potatoes'}: 2
# {'apples'}: 25
# {'eggs', 'apples'}: 4
# {'apples', 'potatoes'}: 7
# {'eggs', 'apples', 'potatoes'}: 3
# {'coffee', 'apples', 'potatoes'}: 3
# {'oranges', 'apples', 'potatoes'}: 2
# {'cheese', 'apples', 'potatoes'}: 2
# {'oranges', 'cheese', 'apples', 'potatoes'}: 2
# {'tomatoes', 'apples'}: 6
# {'tomatoes', 'apples', 'potatoes'}: 2
# {'tomatoes', 'apples', 'cheese'}: 2
# {'apples', 'sugar'}: 9
# {'apples', 'potatoes', 'sugar'}: 3
# {'coffee', 'apples', 'potatoes', 'sugar'}: 2
# {'tomatoes', 'apples', 'sugar'}: 4
# {'tomatoes', 'apples', 'potatoes', 'sugar'}: 2
# {'coffee', 'apples', 'sugar'}: 3
# {'apples', 'bananas', 'sugar'}: 2
# {'apples', 'cheese', 'sugar'}: 2
# {'coffee', 'apples'}: 5
# {'yogurt', 'apples'}: 8
# {'coffee', 'yogurt', 'apples'}: 4
# {'yogurt', 'apples', 'potatoes'}: 3
# {'coffee', 'yogurt', 'apples', 'potatoes'}: 3
# {'tomatoes', 'yogurt', 'apples'}: 3
# {'yogurt', 'apples', 'sugar'}: 5
# {'coffee', 'yogurt', 'apples', 'sugar'}: 3
# {'yogurt', 'apples', 'potatoes', 'sugar'}: 2
# {'coffee', 'yogurt', 'sugar', 'apples', 'potatoes'}: 2
# {'tomatoes', 'yogurt', 'apples', 'sugar'}: 2
# {'oranges', 'yogurt', 'apples'}: 2
# {'yogurt', 'apples', 'cheese'}: 3
# {'oranges', 'yogurt', 'apples', 'cheese'}: 2
# {'coffee', 'yogurt', 'apples', 'cheese'}: 2
# {'apples', 'bananas'}: 2
# {'oranges', 'apples'}: 4
# {'apples', 'cheese'}: 6
# {'oranges', 'apples', 'cheese'}: 3
# {'cereal', 'apples', 'cheese'}: 2
# {'coffee', 'apples', 'cheese'}: 2
# {'cereal', 'apples'}: 3
# {'butter'}: 25
# {'eggs', 'butter'}: 8
# {'eggs', 'butter', 'bananas'}: 4
# {'eggs', 'oranges', 'butter'}: 2
# {'eggs', 'coffee', 'butter'}: 3
# {'eggs', 'coffee', 'butter', 'bananas'}: 2
# {'eggs', 'cheese', 'butter'}: 3
# {'eggs', 'cheese', 'butter', 'bananas'}: 2
# {'eggs', 'coffee', 'cheese', 'butter'}: 3
# {'coffee', 'eggs', 'cheese', 'bananas', 'butter'}: 2
# {'eggs', 'cereal', 'cheese', 'butter'}: 2
# {'coffee', 'eggs', 'cheese', 'cereal', 'butter'}: 2
# {'eggs', 'cereal', 'butter'}: 2
# {'eggs', 'cereal', 'coffee', 'butter'}: 2
# {'potatoes', 'butter'}: 9
# {'eggs', 'potatoes', 'butter'}: 4
# {'eggs', 'potatoes', 'butter', 'bananas'}: 2
# {'potatoes', 'butter', 'bananas'}: 5
# {'oranges', 'potatoes', 'butter'}: 3
# {'coffee', 'potatoes', 'butter'}: 2
# {'cereal', 'potatoes', 'butter'}: 2
# {'cheese', 'potatoes', 'butter'}: 2
# {'cheese', 'potatoes', 'butter', 'bananas'}: 2
# {'apples', 'butter'}: 4
# {'cereal', 'apples', 'butter'}: 2
# {'butter', 'bananas'}: 9
# {'tomatoes', 'butter'}: 7
# {'tomatoes', 'butter', 'bananas'}: 3
# {'eggs', 'tomatoes', 'butter'}: 3
# {'eggs', 'tomatoes', 'butter', 'bananas'}: 2
# {'tomatoes', 'potatoes', 'butter'}: 4
# {'tomatoes', 'potatoes', 'butter', 'bananas'}: 2
# {'tomatoes', 'cereal', 'butter'}: 2
# {'yogurt', 'butter'}: 5
# {'yogurt', 'butter', 'bananas'}: 2
# {'oranges', 'yogurt', 'butter'}: 2
# {'eggs', 'yogurt', 'butter'}: 3
# {'eggs', 'oranges', 'yogurt', 'butter'}: 2
# {'eggs', 'yogurt', 'coffee', 'butter'}: 2
# {'eggs', 'cereal', 'yogurt', 'butter'}: 2
# {'coffee', 'eggs', 'yogurt', 'cereal', 'butter'}: 2
# {'eggs', 'yogurt', 'cheese', 'butter'}: 2
# {'coffee', 'eggs', 'yogurt', 'cheese', 'butter'}: 2
# {'eggs', 'yogurt', 'cheese', 'cereal', 'butter'}: 2
# {'eggs', 'coffee', 'yogurt', 'cheese', 'cereal', 'butter'}: 2
# {'coffee', 'yogurt', 'butter'}: 3
# {'cereal', 'yogurt', 'butter'}: 3
# {'coffee', 'cereal', 'yogurt', 'butter'}: 3
# {'yogurt', 'cheese', 'butter'}: 3
# {'coffee', 'yogurt', 'cheese', 'butter'}: 3
# {'cereal', 'yogurt', 'cheese', 'butter'}: 3
# {'coffee', 'yogurt', 'cheese', 'cereal', 'butter'}: 3
# {'butter', 'sugar'}: 2
# {'cereal', 'butter'}: 7
# {'coffee', 'cereal', 'butter'}: 4
# {'cereal', 'butter', 'bananas'}: 2
# {'oranges', 'butter'}: 7
# {'coffee', 'oranges', 'butter'}: 2
# {'oranges', 'cereal', 'butter'}: 2
# {'coffee', 'oranges', 'cereal', 'butter'}: 2
# {'oranges', 'butter', 'bananas'}: 3
# {'coffee', 'butter'}: 5
# {'coffee', 'butter', 'bananas'}: 2
# {'cheese', 'butter'}: 6
# {'cheese', 'butter', 'bananas'}: 4
# {'cereal', 'cheese', 'butter'}: 4
# {'cereal', 'cheese', 'butter', 'bananas'}: 2
# {'coffee', 'cereal', 'cheese', 'butter'}: 3
# {'coffee', 'cheese', 'butter'}: 4
# {'coffee', 'cheese', 'butter', 'bananas'}: 2
# {'oranges', 'cheese', 'butter'}: 2
# {'oranges', 'cheese', 'butter', 'bananas'}: 2
# {'oranges'}: 29
# {'oranges', 'bananas'}: 8
# {'coffee', 'oranges'}: 7
# {'coffee', 'oranges', 'bananas'}: 2
# {'oranges', 'cereal'}: 5
# {'coffee', 'oranges', 'cereal'}: 3
# {'cereal'}: 31
# {'cereal', 'bananas'}: 9
# {'coffee', 'cereal'}: 8
# {'milk'}: 24
# {'milk', 'cereal'}: 5
# {'milk', 'cereal', 'coffee'}: 2
# {'milk', 'eggs'}: 4
# {'milk', 'tomatoes'}: 7
# {'milk', 'tomatoes', 'eggs'}: 3
# {'milk', 'tomatoes', 'coffee'}: 2
# {'milk', 'tomatoes', 'potatoes'}: 3
# {'milk', 'tomatoes', 'eggs', 'potatoes'}: 2
# {'milk', 'tomatoes', 'potatoes', 'bananas'}: 2
# {'milk', 'tomatoes', 'bananas'}: 2
# {'milk', 'tomatoes', 'oranges'}: 2
# {'milk', 'tomatoes', 'cheese'}: 2
# {'milk', 'tomatoes', 'cereal'}: 2
# {'milk', 'sugar'}: 5
# {'milk', 'eggs', 'sugar'}: 2
# {'milk', 'tomatoes', 'sugar'}: 3
# {'milk', 'tomatoes', 'eggs', 'sugar'}: 2
# {'milk', 'tomatoes', 'coffee', 'sugar'}: 2
# {'milk', 'coffee', 'sugar'}: 3
# {'milk', 'cereal', 'sugar'}: 2
# {'milk', 'cereal', 'coffee', 'sugar'}: 2
# {'milk', 'cheese', 'sugar'}: 2
# {'milk', 'cheese', 'coffee', 'sugar'}: 2
# {'milk', 'cereal', 'cheese', 'sugar'}: 2
# {'milk', 'coffee', 'cheese', 'sugar', 'cereal'}: 2
# {'milk', 'butter'}: 7
# {'milk', 'eggs', 'butter'}: 2
# {'milk', 'tomatoes', 'butter'}: 3
# {'milk', 'tomatoes', 'eggs', 'butter'}: 2
# {'milk', 'butter', 'sugar'}: 2
# {'milk', 'butter', 'bananas'}: 3
# {'milk', 'potatoes', 'butter'}: 2
# {'milk', 'potatoes', 'butter', 'bananas'}: 2
# {'milk', 'cereal', 'butter'}: 2
# {'milk', 'cheese', 'butter'}: 2
# {'milk', 'apples', 'butter'}: 2
# {'milk', 'cereal', 'apples', 'butter'}: 2
# {'milk', 'oranges', 'butter'}: 3
# {'milk', 'oranges', 'butter', 'bananas'}: 2
# {'milk', 'coffee'}: 6
# {'milk', 'potatoes'}: 6
# {'milk', 'potatoes', 'coffee'}: 2
# {'milk', 'eggs', 'potatoes'}: 3
# {'milk', 'potatoes', 'bananas'}: 3
# {'milk', 'oranges', 'potatoes'}: 4
# {'milk', 'oranges', 'potatoes', 'bananas'}: 2
# {'milk', 'cheese', 'potatoes'}: 2
# {'milk', 'oranges', 'cheese', 'potatoes'}: 2
# {'milk', 'yogurt'}: 5
# {'milk', 'yogurt', 'coffee'}: 4
# {'milk', 'yogurt', 'potatoes'}: 2
# {'milk', 'yogurt', 'potatoes', 'coffee'}: 2
# {'milk', 'tomatoes', 'yogurt'}: 2
# {'milk', 'yogurt', 'sugar'}: 2
# {'milk', 'yogurt', 'coffee', 'sugar'}: 2
# {'milk', 'oranges', 'yogurt'}: 3
# {'milk', 'oranges', 'yogurt', 'coffee'}: 2
# {'milk', 'yogurt', 'cheese'}: 3
# {'milk', 'oranges', 'yogurt', 'cheese'}: 2
# {'milk', 'yogurt', 'cheese', 'coffee'}: 2
# {'milk', 'apples'}: 7
# {'milk', 'apples', 'coffee'}: 3
# {'milk', 'eggs', 'apples'}: 2
# {'milk', 'apples', 'potatoes'}: 3
# {'milk', 'apples', 'potatoes', 'coffee'}: 2
# {'milk', 'eggs', 'apples', 'potatoes'}: 2
# {'milk', 'oranges', 'apples', 'potatoes'}: 2
# {'milk', 'cheese', 'apples', 'potatoes'}: 2
# {'milk', 'oranges', 'cheese', 'apples', 'potatoes'}: 2
# {'milk', 'tomatoes', 'apples'}: 3
# {'milk', 'apples', 'sugar'}: 3
# {'milk', 'apples', 'coffee', 'sugar'}: 2
# {'milk', 'yogurt', 'apples'}: 4
# {'milk', 'yogurt', 'apples', 'coffee'}: 3
# {'milk', 'yogurt', 'apples', 'potatoes'}: 2
# {'milk', 'coffee', 'yogurt', 'apples', 'potatoes'}: 2
# {'milk', 'tomatoes', 'yogurt', 'apples'}: 2
# {'milk', 'yogurt', 'apples', 'sugar'}: 2
# {'milk', 'coffee', 'yogurt', 'sugar', 'apples'}: 2
# {'milk', 'oranges', 'yogurt', 'apples'}: 2
# {'milk', 'yogurt', 'apples', 'cheese'}: 3
# {'milk', 'oranges', 'yogurt', 'cheese', 'apples'}: 2
# {'milk', 'coffee', 'yogurt', 'cheese', 'apples'}: 2
# {'milk', 'oranges', 'apples'}: 3
# {'milk', 'apples', 'cheese'}: 4
# {'milk', 'oranges', 'apples', 'cheese'}: 3
# {'milk', 'cereal', 'apples', 'cheese'}: 2
# {'milk', 'apples', 'cheese', 'coffee'}: 2
# {'milk', 'cereal', 'apples'}: 3
# {'milk', 'bananas'}: 6
# {'milk', 'oranges'}: 12
# {'milk', 'oranges', 'bananas'}: 4
# {'milk', 'oranges', 'coffee'}: 2
# {'milk', 'cheese'}: 6
# {'milk', 'oranges', 'cheese'}: 4
# {'milk', 'cereal', 'cheese'}: 3
# {'milk', 'cereal', 'cheese', 'coffee'}: 2
# {'milk', 'cheese', 'coffee'}: 3
# {'onions'}: 23
# {'cereal', 'onions'}: 10
# {'cereal', 'onions', 'bananas'}: 2
# {'coffee', 'cereal', 'onions'}: 4
# {'milk', 'onions'}: 7
# {'milk', 'cereal', 'onions'}: 3
# {'milk', 'eggs', 'onions'}: 3
# {'milk', 'tomatoes', 'onions'}: 4
# {'milk', 'tomatoes', 'eggs', 'onions'}: 2
# {'milk', 'tomatoes', 'onions', 'coffee'}: 2
# {'milk', 'tomatoes', 'onions', 'potatoes'}: 2
# {'milk', 'onions', 'sugar'}: 3
# {'milk', 'eggs', 'onions', 'sugar'}: 2
# {'milk', 'tomatoes', 'onions', 'sugar'}: 3
# {'milk', 'eggs', 'sugar', 'tomatoes', 'onions'}: 2
# {'milk', 'coffee', 'sugar', 'tomatoes', 'onions'}: 2
# {'milk', 'onions', 'coffee', 'sugar'}: 2
# {'milk', 'onions', 'butter'}: 2
# {'milk', 'onions', 'coffee'}: 2
# {'milk', 'onions', 'potatoes'}: 3
# {'milk', 'eggs', 'onions', 'potatoes'}: 2
# {'milk', 'oranges', 'onions', 'potatoes'}: 2
# {'milk', 'onions', 'apples'}: 2
# {'milk', 'eggs', 'onions', 'apples'}: 2
# {'milk', 'onions', 'potatoes', 'apples'}: 2
# {'milk', 'eggs', 'apples', 'potatoes', 'onions'}: 2
# {'milk', 'onions', 'bananas'}: 2
# {'milk', 'oranges', 'onions'}: 3
# {'milk', 'oranges', 'onions', 'bananas'}: 2
# {'milk', 'onions', 'cheese'}: 3
# {'milk', 'cereal', 'onions', 'cheese'}: 2
# {'milk', 'oranges', 'onions', 'cheese'}: 2
# {'onions', 'bananas'}: 6
# {'coffee', 'onions'}: 7
# {'coffee', 'onions', 'bananas'}: 2
# {'oranges', 'onions'}: 4
# {'oranges', 'onions', 'bananas'}: 3
# {'onions', 'potatoes'}: 6
# {'onions', 'potatoes', 'bananas'}: 3
# {'coffee', 'onions', 'potatoes'}: 3
# {'oranges', 'onions', 'potatoes'}: 3
# {'oranges', 'onions', 'potatoes', 'bananas'}: 2
# {'eggs', 'onions', 'potatoes'}: 2
# {'cereal', 'onions', 'potatoes'}: 3
# {'onions', 'sugar'}: 6
# {'coffee', 'onions', 'sugar'}: 3
# {'onions', 'potatoes', 'sugar'}: 2
# {'coffee', 'onions', 'potatoes', 'sugar'}: 2
# {'eggs', 'onions', 'sugar'}: 2
# {'tomatoes', 'onions', 'sugar'}: 4
# {'eggs', 'tomatoes', 'onions', 'sugar'}: 2
# {'coffee', 'tomatoes', 'onions', 'sugar'}: 2
# {'tomatoes', 'onions', 'cheese', 'sugar'}: 2
# {'onions', 'cheese', 'sugar'}: 2
# {'onions', 'bread'}: 6
# {'onions', 'bread', 'bananas'}: 3
# {'coffee', 'onions', 'bread'}: 3
# {'oranges', 'onions', 'bread'}: 3
# {'oranges', 'onions', 'bread', 'bananas'}: 3
# {'potatoes', 'onions', 'bread'}: 3
# {'potatoes', 'onions', 'bread', 'bananas'}: 2
# {'potatoes', 'onions', 'bread', 'coffee'}: 2
# {'potatoes', 'oranges', 'onions', 'bread'}: 2
# {'oranges', 'bread', 'bananas', 'onions', 'potatoes'}: 2
# {'onions', 'bread', 'sugar'}: 2
# {'cereal', 'onions', 'bread'}: 2
# {'coffee', 'cereal', 'onions', 'bread'}: 2
# {'tomatoes', 'onions', 'bread'}: 2
# {'milk', 'onions', 'bread'}: 2
# {'milk', 'onions', 'bread', 'bananas'}: 2
# {'milk', 'oranges', 'onions', 'bread'}: 2
# {'milk', 'oranges', 'bread', 'bananas', 'onions'}: 2
# {'cheese', 'onions', 'bread'}: 2
# {'onions', 'cheese'}: 9
# {'onions', 'cheese', 'bananas'}: 2
# {'cereal', 'onions', 'cheese'}: 5
# {'coffee', 'cereal', 'onions', 'cheese'}: 2
# {'oranges', 'onions', 'cheese'}: 2
# {'coffee', 'onions', 'cheese'}: 2
# {'eggs', 'onions'}: 5
# {'eggs', 'onions', 'coffee'}: 2
# {'eggs', 'onions', 'cheese'}: 3
# {'eggs', 'cereal', 'onions', 'cheese'}: 2
# {'eggs', 'cereal', 'onions'}: 2
# {'tomatoes', 'onions'}: 5
# {'eggs', 'tomatoes', 'onions'}: 2
# {'coffee', 'tomatoes', 'onions'}: 2
# {'tomatoes', 'onions', 'potatoes'}: 2
# {'tomatoes', 'onions', 'cheese'}: 2
# {'onions', 'butter'}: 3
# {'eggs', 'onions', 'butter'}: 2
# {'onions', 'cheese', 'butter'}: 2
# {'juice', 'onions'}: 4
# {'juice', 'eggs', 'onions'}: 3
# {'juice', 'tomatoes', 'onions'}: 2
# {'juice', 'tomatoes', 'eggs', 'onions'}: 2
# {'juice', 'onions', 'sugar'}: 2
# {'juice', 'eggs', 'onions', 'sugar'}: 2
# {'juice', 'tomatoes', 'onions', 'sugar'}: 2
# {'juice', 'eggs', 'sugar', 'tomatoes', 'onions'}: 2
# {'juice', 'milk', 'onions'}: 2
# {'juice', 'milk', 'eggs', 'onions'}: 2
# {'juice', 'milk', 'onions', 'tomatoes'}: 2
# {'juice', 'milk', 'eggs', 'tomatoes', 'onions'}: 2
# {'juice', 'milk', 'onions', 'sugar'}: 2
# {'juice', 'milk', 'eggs', 'sugar', 'onions'}: 2
# {'juice', 'milk', 'sugar', 'tomatoes', 'onions'}: 2
# {'juice', 'milk', 'eggs', 'sugar', 'tomatoes', 'onions'}: 2
# {'juice', 'onions', 'coffee'}: 2
# {'yogurt', 'onions'}: 3
# {'coffee', 'yogurt', 'onions'}: 2
# {'eggs', 'yogurt', 'onions'}: 2
# {'eggs', 'yogurt', 'onions', 'coffee'}: 2
# {'onions', 'apples'}: 4
# {'eggs', 'onions', 'apples'}: 2
# {'onions', 'potatoes', 'apples'}: 2
# {'eggs', 'onions', 'potatoes', 'apples'}: 2
# {'tomatoes', 'onions', 'apples'}: 2
# {'sugar', 'onions', 'apples'}: 2
# {'tomatoes', 'sugar', 'onions', 'apples'}: 2
# {'onions', 'cheese', 'apples'}: 3
# {'tomatoes'}: 27
# {'tomatoes', 'cereal'}: 7
# {'coffee', 'tomatoes', 'cereal'}: 2
# {'tomatoes', 'potatoes'}: 9
# {'tomatoes', 'cereal', 'potatoes'}: 2
# {'coffee', 'tomatoes', 'potatoes'}: 2
# {'eggs', 'tomatoes', 'potatoes'}: 2
# {'tomatoes', 'potatoes', 'bananas'}: 4
# {'tomatoes', 'oranges', 'potatoes'}: 3
# {'tomatoes', 'oranges', 'potatoes', 'bananas'}: 2
# {'tomatoes', 'bananas'}: 8
# {'eggs', 'tomatoes'}: 8
# {'eggs', 'tomatoes', 'bananas'}: 4
# {'coffee', 'tomatoes'}: 5
# {'tomatoes', 'oranges'}: 5
# {'tomatoes', 'oranges', 'bananas'}: 2
# {'tomatoes', 'oranges', 'cereal'}: 2
# {'tomatoes', 'cheese'}: 6
# {'tomatoes', 'oranges', 'cheese'}: 3
# {'tomatoes', 'cereal', 'cheese'}: 2
# {'bananas'}: 37
# {'coffee'}: 33
# {'coffee', 'bananas'}: 6
# {'sugar'}: 26
# {'bananas', 'sugar'}: 7
# {'coffee', 'sugar'}: 8
# {'oranges', 'sugar'}: 2
# {'oranges', 'bananas', 'sugar'}: 2
# {'potatoes', 'sugar'}: 6
# {'potatoes', 'bananas', 'sugar'}: 2
# {'coffee', 'potatoes', 'sugar'}: 3
# {'oranges', 'potatoes', 'sugar'}: 2
# {'oranges', 'potatoes', 'bananas', 'sugar'}: 2
# {'eggs', 'sugar'}: 4
# {'tomatoes', 'sugar'}: 9
# {'tomatoes', 'potatoes', 'sugar'}: 3
# {'eggs', 'tomatoes', 'sugar'}: 3
# {'coffee', 'tomatoes', 'sugar'}: 2
# {'tomatoes', 'bananas', 'sugar'}: 3
# {'tomatoes', 'cheese', 'sugar'}: 3
# {'cheese', 'sugar'}: 6
# {'cheese', 'bananas', 'sugar'}: 2
# {'coffee', 'cheese', 'sugar'}: 2
# {'cereal', 'cheese', 'sugar'}: 2
# {'coffee', 'cereal', 'cheese', 'sugar'}: 2
# {'cereal', 'sugar'}: 2
# {'coffee', 'cereal', 'sugar'}: 2
# {'bread'}: 23
# {'bread', 'bananas'}: 7
# {'coffee', 'bread'}: 11
# {'coffee', 'bread', 'bananas'}: 2
# {'oranges', 'bread'}: 9
# {'oranges', 'bread', 'bananas'}: 5
# {'coffee', 'oranges', 'bread'}: 4
# {'coffee', 'oranges', 'bread', 'bananas'}: 2
# {'oranges', 'cereal', 'bread'}: 2
# {'coffee', 'oranges', 'cereal', 'bread'}: 2
# {'potatoes', 'bread'}: 9
# {'potatoes', 'bread', 'bananas'}: 4
# {'potatoes', 'bread', 'coffee'}: 4
# {'potatoes', 'oranges', 'bread'}: 5
# {'potatoes', 'oranges', 'bread', 'bananas'}: 3
# {'potatoes', 'oranges', 'bread', 'coffee'}: 2
# {'potatoes', 'cereal', 'bread'}: 3
# {'potatoes', 'cereal', 'bread', 'coffee'}: 2
# {'bread', 'sugar'}: 5
# {'coffee', 'bread', 'sugar'}: 3
# {'potatoes', 'bread', 'sugar'}: 3
# {'potatoes', 'bread', 'coffee', 'sugar'}: 2
# {'tomatoes', 'bread', 'sugar'}: 2
# {'cheese', 'bread', 'sugar'}: 2
# {'cereal', 'bread'}: 6
# {'coffee', 'cereal', 'bread'}: 5
# {'cereal', 'bread', 'bananas'}: 2
# {'tomatoes', 'bread'}: 5
# {'potatoes', 'tomatoes', 'bread'}: 3
# {'potatoes', 'tomatoes', 'oranges', 'bread'}: 2
# {'tomatoes', 'oranges', 'bread'}: 2
# {'coffee', 'tomatoes', 'bread'}: 2
# {'apples', 'bread'}: 7
# {'potatoes', 'apples', 'bread'}: 2
# {'tomatoes', 'apples', 'bread'}: 2
# {'apples', 'bread', 'sugar'}: 4
# {'potatoes', 'apples', 'bread', 'sugar'}: 2
# {'tomatoes', 'apples', 'bread', 'sugar'}: 2
# {'cheese', 'apples', 'bread', 'sugar'}: 2
# {'coffee', 'apples', 'bread', 'sugar'}: 2
# {'cheese', 'apples', 'bread'}: 2
# {'coffee', 'apples', 'bread'}: 2
# {'yogurt', 'apples', 'bread'}: 3
# {'coffee', 'yogurt', 'apples', 'bread'}: 2
# {'yogurt', 'apples', 'bread', 'sugar'}: 2
# {'coffee', 'yogurt', 'bread', 'sugar', 'apples'}: 2
# {'milk', 'bread'}: 6
# {'milk', 'bread', 'bananas'}: 3
# {'milk', 'oranges', 'bread'}: 4
# {'milk', 'oranges', 'bread', 'bananas'}: 3
# {'milk', 'potatoes', 'bread'}: 2
# {'milk', 'potatoes', 'bread', 'bananas'}: 2
# {'milk', 'potatoes', 'oranges', 'bread'}: 2
# {'milk', 'oranges', 'bread', 'bananas', 'potatoes'}: 2
# {'milk', 'bread', 'coffee'}: 3
# {'milk', 'yogurt', 'bread'}: 2
# {'milk', 'yogurt', 'bread', 'coffee'}: 2
# {'milk', 'cheese', 'bread'}: 2
# {'milk', 'bread', 'butter'}: 3
# {'milk', 'cheese', 'bread', 'butter'}: 2
# {'milk', 'bread', 'butter', 'bananas'}: 2
# {'milk', 'oranges', 'bread', 'butter'}: 2
# {'milk', 'oranges', 'bread', 'bananas', 'butter'}: 2
# {'yogurt', 'bread'}: 6
# {'coffee', 'yogurt', 'bread'}: 4
# {'oranges', 'yogurt', 'bread'}: 3
# {'coffee', 'oranges', 'yogurt', 'bread'}: 2
# {'eggs', 'yogurt', 'bread'}: 2
# {'eggs', 'oranges', 'yogurt', 'bread'}: 2
# {'potatoes', 'yogurt', 'bread'}: 2
# {'cereal', 'yogurt', 'bread'}: 2
# {'coffee', 'cereal', 'yogurt', 'bread'}: 2
# {'yogurt', 'bread', 'cheese'}: 2
# {'coffee', 'yogurt', 'bread', 'cheese'}: 2
# {'cereal', 'yogurt', 'bread', 'cheese'}: 2
# {'coffee', 'yogurt', 'cheese', 'bread', 'cereal'}: 2
# {'yogurt', 'bread', 'sugar'}: 2
# {'coffee', 'yogurt', 'bread', 'sugar'}: 2
# {'eggs', 'bread'}: 2
# {'eggs', 'oranges', 'bread'}: 2
# {'bread', 'butter'}: 8
# {'oranges', 'bread', 'butter'}: 6
# {'coffee', 'oranges', 'bread', 'butter'}: 2
# {'oranges', 'cereal', 'bread', 'butter'}: 2
# {'coffee', 'oranges', 'bread', 'cereal', 'butter'}: 2
# {'oranges', 'bread', 'butter', 'bananas'}: 3
# {'eggs', 'bread', 'butter'}: 2
# {'eggs', 'oranges', 'bread', 'butter'}: 2
# {'potatoes', 'bread', 'butter'}: 4
# {'potatoes', 'oranges', 'bread', 'butter'}: 3
# {'potatoes', 'cereal', 'bread', 'butter'}: 2
# {'potatoes', 'bread', 'butter', 'bananas'}: 2
# {'yogurt', 'bread', 'butter'}: 3
# {'oranges', 'yogurt', 'bread', 'butter'}: 2
# {'eggs', 'yogurt', 'bread', 'butter'}: 2
# {'eggs', 'oranges', 'yogurt', 'bread', 'butter'}: 2
# {'coffee', 'yogurt', 'bread', 'butter'}: 2
# {'cereal', 'yogurt', 'bread', 'butter'}: 2
# {'coffee', 'yogurt', 'bread', 'cereal', 'butter'}: 2
# {'yogurt', 'cheese', 'bread', 'butter'}: 2
# {'coffee', 'yogurt', 'cheese', 'bread', 'butter'}: 2
# {'yogurt', 'cheese', 'bread', 'cereal', 'butter'}: 2
# {'coffee', 'yogurt', 'cheese', 'bread', 'cereal', 'butter'}: 2
# {'coffee', 'bread', 'butter'}: 3
# {'cereal', 'bread', 'butter'}: 4
# {'coffee', 'cereal', 'bread', 'butter'}: 3
# {'cereal', 'bread', 'butter', 'bananas'}: 2
# {'bread', 'butter', 'bananas'}: 4
# {'cheese', 'bread', 'butter'}: 4
# {'cheese', 'bread', 'butter', 'bananas'}: 3
# {'cereal', 'cheese', 'bread', 'butter'}: 3
# {'cheese', 'bread', 'bananas', 'cereal', 'butter'}: 2
# {'coffee', 'cheese', 'bread', 'cereal', 'butter'}: 2
# {'coffee', 'cheese', 'bread', 'butter'}: 2
# {'oranges', 'cheese', 'bread', 'butter'}: 2
# {'oranges', 'cheese', 'bread', 'bananas', 'butter'}: 2
# {'apples', 'bread', 'butter'}: 2
# {'cheese', 'bread'}: 6
# {'cheese', 'bread', 'bananas'}: 3
# {'cereal', 'cheese', 'bread'}: 3
# {'cereal', 'cheese', 'bread', 'bananas'}: 2
# {'coffee', 'cereal', 'cheese', 'bread'}: 2
# {'coffee', 'cheese', 'bread'}: 2
# {'oranges', 'cheese', 'bread'}: 2
# {'oranges', 'cheese', 'bread', 'bananas'}: 2
# {'pasta'}: 23
# {'pasta', 'bananas'}: 8
# {'coffee', 'pasta'}: 9
# {'coffee', 'pasta', 'bananas'}: 4
# {'oranges', 'pasta'}: 3
# {'oranges', 'pasta', 'bananas'}: 2
# {'coffee', 'oranges', 'pasta'}: 2
# {'coffee', 'oranges', 'pasta', 'bananas'}: 2
# {'oranges', 'cereal', 'pasta'}: 2
# {'pasta', 'potatoes'}: 6
# {'pasta', 'potatoes', 'bananas'}: 2
# {'coffee', 'pasta', 'potatoes'}: 2
# {'oranges', 'pasta', 'potatoes'}: 2
# {'eggs', 'pasta', 'potatoes'}: 2
# {'pasta', 'sugar'}: 6
# {'coffee', 'pasta', 'sugar'}: 3
# {'pasta', 'potatoes', 'sugar'}: 4
# {'coffee', 'pasta', 'potatoes', 'sugar'}: 2
# {'tomatoes', 'pasta', 'sugar'}: 2
# {'tomatoes', 'pasta', 'potatoes', 'sugar'}: 2
# {'pasta', 'bread'}: 6
# {'pasta', 'bread', 'bananas'}: 2
# {'coffee', 'pasta', 'bread'}: 4
# {'coffee', 'pasta', 'bread', 'bananas'}: 2
# {'oranges', 'pasta', 'bread'}: 2
# {'oranges', 'pasta', 'bread', 'bananas'}: 2
# {'coffee', 'oranges', 'pasta', 'bread'}: 2
# {'coffee', 'oranges', 'bread', 'bananas', 'pasta'}: 2
# {'potatoes', 'pasta', 'bread'}: 2
# {'pasta', 'bread', 'sugar'}: 3
# {'coffee', 'pasta', 'bread', 'sugar'}: 2
# {'potatoes', 'pasta', 'bread', 'sugar'}: 2
# {'pasta', 'bread', 'apples'}: 3
# {'sugar', 'pasta', 'bread', 'apples'}: 2
# {'cereal', 'pasta', 'bread'}: 2
# {'coffee', 'cereal', 'pasta', 'bread'}: 2
# {'cheese', 'pasta', 'bread'}: 2
# {'coffee', 'cheese', 'pasta', 'bread'}: 2
# {'cereal', 'cheese', 'pasta', 'bread'}: 2
# {'coffee', 'cheese', 'bread', 'cereal', 'pasta'}: 2
# {'yogurt', 'pasta', 'bread'}: 2
# {'coffee', 'yogurt', 'pasta', 'bread'}: 2
# {'cereal', 'yogurt', 'pasta', 'bread'}: 2
# {'coffee', 'yogurt', 'bread', 'cereal', 'pasta'}: 2
# {'yogurt', 'pasta', 'bread', 'cheese'}: 2
# {'coffee', 'yogurt', 'cheese', 'bread', 'pasta'}: 2
# {'yogurt', 'cheese', 'bread', 'cereal', 'pasta'}: 2
# {'coffee', 'yogurt', 'cheese', 'bread', 'cereal', 'pasta'}: 2
# {'pasta', 'bread', 'butter'}: 2
# {'coffee', 'pasta', 'bread', 'butter'}: 2
# {'cereal', 'pasta', 'bread', 'butter'}: 2
# {'coffee', 'bread', 'cereal', 'pasta', 'butter'}: 2
# {'cheese', 'pasta', 'bread', 'butter'}: 2
# {'coffee', 'cheese', 'bread', 'pasta', 'butter'}: 2
# {'cheese', 'bread', 'cereal', 'pasta', 'butter'}: 2
# {'coffee', 'cheese', 'bread', 'cereal', 'pasta', 'butter'}: 2
# {'yogurt', 'pasta', 'bread', 'butter'}: 2
# {'coffee', 'yogurt', 'bread', 'pasta', 'butter'}: 2
# {'yogurt', 'bread', 'cereal', 'pasta', 'butter'}: 2
# {'coffee', 'yogurt', 'bread', 'cereal', 'pasta', 'butter'}: 2
# {'yogurt', 'cheese', 'bread', 'pasta', 'butter'}: 2
# {'coffee', 'yogurt', 'cheese', 'bread', 'pasta', 'butter'}: 2
# {'yogurt', 'cheese', 'bread', 'cereal', 'pasta', 'butter'}: 2
# {'coffee', 'yogurt', 'cheese', 'bread', 'cereal', 'pasta', 'butter'}: 2
# {'milk', 'pasta', 'bread'}: 2
# {'milk', 'pasta', 'bread', 'coffee'}: 2
# {'pasta', 'onions'}: 5
# {'pasta', 'onions', 'bananas'}: 3
# {'coffee', 'pasta', 'onions'}: 3
# {'coffee', 'pasta', 'onions', 'bananas'}: 2
# {'oranges', 'pasta', 'onions'}: 2
# {'potatoes', 'pasta', 'onions'}: 3
# {'potatoes', 'pasta', 'onions', 'coffee'}: 2
# {'potatoes', 'oranges', 'pasta', 'onions'}: 2
# {'potatoes', 'eggs', 'pasta', 'onions'}: 2
# {'pasta', 'onions', 'sugar'}: 2
# {'coffee', 'pasta', 'onions', 'sugar'}: 2
# {'potatoes', 'pasta', 'onions', 'sugar'}: 2
# {'coffee', 'sugar', 'pasta', 'onions', 'potatoes'}: 2
# {'cereal', 'pasta', 'onions'}: 2
# {'cheese', 'pasta', 'onions'}: 2
# {'cereal', 'cheese', 'pasta', 'onions'}: 2
# {'juice', 'pasta', 'onions'}: 2
# {'juice', 'pasta', 'onions', 'coffee'}: 2
# {'eggs', 'pasta', 'onions'}: 2
# {'pasta', 'onions', 'apples'}: 2
# {'eggs', 'pasta', 'onions', 'apples'}: 2
# {'potatoes', 'pasta', 'onions', 'apples'}: 2
# {'eggs', 'pasta', 'apples', 'potatoes', 'onions'}: 2
# {'milk', 'pasta', 'onions'}: 2
# {'milk', 'eggs', 'pasta', 'onions'}: 2
# {'milk', 'potatoes', 'pasta', 'onions'}: 2
# {'milk', 'eggs', 'pasta', 'onions', 'potatoes'}: 2
# {'milk', 'pasta', 'onions', 'apples'}: 2
# {'milk', 'eggs', 'pasta', 'apples', 'onions'}: 2
# {'milk', 'pasta', 'apples', 'potatoes', 'onions'}: 2
# {'milk', 'eggs', 'pasta', 'apples', 'potatoes', 'onions'}: 2
# {'cereal', 'pasta'}: 6
# {'cereal', 'pasta', 'bananas'}: 4
# {'coffee', 'cereal', 'pasta'}: 2
# {'pasta', 'cheese'}: 4
# {'pasta', 'cheese', 'bananas'}: 2
# {'cereal', 'pasta', 'cheese'}: 4
# {'cereal', 'pasta', 'cheese', 'bananas'}: 2
# {'coffee', 'cereal', 'pasta', 'cheese'}: 2
# {'oranges', 'pasta', 'cheese'}: 2
# {'oranges', 'cereal', 'pasta', 'cheese'}: 2
# {'coffee', 'pasta', 'cheese'}: 2
# {'eggs', 'pasta'}: 6
# {'eggs', 'pasta', 'bananas'}: 3
# {'eggs', 'cereal', 'pasta'}: 4
# {'eggs', 'cereal', 'pasta', 'bananas'}: 3
# {'eggs', 'pasta', 'coffee'}: 3
# {'eggs', 'oranges', 'pasta'}: 2
# {'eggs', 'oranges', 'cereal', 'pasta'}: 2
# {'eggs', 'pasta', 'cheese'}: 2
# {'eggs', 'cereal', 'pasta', 'cheese'}: 2
# {'eggs', 'oranges', 'pasta', 'cheese'}: 2
# {'eggs', 'oranges', 'cheese', 'cereal', 'pasta'}: 2
# {'tomatoes', 'pasta'}: 4
# {'tomatoes', 'pasta', 'potatoes'}: 3
# {'eggs', 'tomatoes', 'pasta'}: 2
# {'tomatoes', 'pasta', 'bananas'}: 2
# {'pasta', 'apples'}: 6
# {'pasta', 'potatoes', 'apples'}: 3
# {'eggs', 'pasta', 'potatoes', 'apples'}: 2
# {'tomatoes', 'pasta', 'apples'}: 2
# {'tomatoes', 'pasta', 'potatoes', 'apples'}: 2
# {'sugar', 'pasta', 'apples'}: 4
# {'sugar', 'pasta', 'potatoes', 'apples'}: 2
# {'tomatoes', 'sugar', 'pasta', 'apples'}: 2
# {'sugar', 'pasta', 'tomatoes', 'apples', 'potatoes'}: 2
# {'coffee', 'sugar', 'pasta', 'apples'}: 2
# {'coffee', 'pasta', 'apples'}: 2
# {'eggs', 'pasta', 'apples'}: 2
# {'yogurt', 'pasta', 'apples'}: 2
# {'coffee', 'yogurt', 'pasta', 'apples'}: 2
# {'yogurt', 'sugar', 'pasta', 'apples'}: 2
# {'coffee', 'yogurt', 'sugar', 'pasta', 'apples'}: 2
# {'cereal', 'pasta', 'apples'}: 2
# {'pasta', 'cheese', 'apples'}: 2
# {'cereal', 'pasta', 'cheese', 'apples'}: 2
# {'juice', 'pasta'}: 4
# {'juice', 'pasta', 'bananas'}: 2
# {'juice', 'pasta', 'coffee'}: 4
# {'juice', 'pasta', 'coffee', 'bananas'}: 2
# {'juice', 'eggs', 'pasta'}: 2
# {'juice', 'eggs', 'pasta', 'coffee'}: 2
# {'juice', 'yogurt', 'pasta'}: 2
# {'juice', 'yogurt', 'pasta', 'coffee'}: 2
# {'juice', 'yogurt', 'eggs', 'pasta'}: 2
# {'juice', 'coffee', 'eggs', 'yogurt', 'pasta'}: 2
# {'yogurt', 'pasta'}: 4
# {'coffee', 'yogurt', 'pasta'}: 4
# {'coffee', 'yogurt', 'pasta', 'bananas'}: 2
# {'eggs', 'yogurt', 'pasta'}: 2
# {'eggs', 'yogurt', 'pasta', 'coffee'}: 2
# {'yogurt', 'pasta', 'sugar'}: 2
# {'coffee', 'yogurt', 'pasta', 'sugar'}: 2
# {'yogurt', 'pasta', 'bananas'}: 2
# {'cereal', 'yogurt', 'pasta'}: 2
# {'coffee', 'cereal', 'yogurt', 'pasta'}: 2
# {'yogurt', 'pasta', 'cheese'}: 2
# {'coffee', 'yogurt', 'pasta', 'cheese'}: 2
# {'cereal', 'yogurt', 'pasta', 'cheese'}: 2
# {'coffee', 'yogurt', 'cheese', 'cereal', 'pasta'}: 2
# {'milk', 'pasta'}: 5
# {'milk', 'pasta', 'coffee'}: 3
# {'milk', 'eggs', 'pasta'}: 2
# {'milk', 'pasta', 'potatoes'}: 2
# {'milk', 'eggs', 'pasta', 'potatoes'}: 2
# {'milk', 'pasta', 'sugar'}: 2
# {'milk', 'pasta', 'coffee', 'sugar'}: 2
# {'milk', 'yogurt', 'pasta'}: 2
# {'milk', 'yogurt', 'pasta', 'coffee'}: 2
# {'milk', 'yogurt', 'pasta', 'sugar'}: 2
# {'milk', 'coffee', 'yogurt', 'sugar', 'pasta'}: 2
# {'milk', 'pasta', 'apples'}: 3
# {'milk', 'pasta', 'coffee', 'apples'}: 2
# {'milk', 'eggs', 'pasta', 'apples'}: 2
# {'milk', 'pasta', 'potatoes', 'apples'}: 2
# {'milk', 'eggs', 'pasta', 'apples', 'potatoes'}: 2
# {'milk', 'sugar', 'pasta', 'apples'}: 2
# {'milk', 'coffee', 'sugar', 'pasta', 'apples'}: 2
# {'milk', 'yogurt', 'pasta', 'apples'}: 2
# {'milk', 'coffee', 'yogurt', 'pasta', 'apples'}: 2
# {'milk', 'yogurt', 'sugar', 'pasta', 'apples'}: 2
# {'milk', 'coffee', 'yogurt', 'sugar', 'pasta', 'apples'}: 2
# {'milk', 'cereal', 'pasta', 'apples'}: 2
# {'milk', 'pasta', 'cheese', 'apples'}: 2
# {'milk', 'cheese', 'pasta', 'cereal', 'apples'}: 2
# {'milk', 'cereal', 'pasta'}: 2
# {'milk', 'pasta', 'cheese'}: 2
# {'milk', 'cereal', 'pasta', 'cheese'}: 2
# {'pasta', 'butter'}: 3
# {'coffee', 'pasta', 'butter'}: 2
# {'cereal', 'pasta', 'butter'}: 2
# {'coffee', 'cereal', 'pasta', 'butter'}: 2
# {'pasta', 'cheese', 'butter'}: 2
# {'coffee', 'pasta', 'cheese', 'butter'}: 2
# {'cereal', 'pasta', 'cheese', 'butter'}: 2
# {'coffee', 'cheese', 'cereal', 'pasta', 'butter'}: 2
# {'yogurt', 'pasta', 'butter'}: 2
# {'coffee', 'yogurt', 'pasta', 'butter'}: 2
# {'cereal', 'yogurt', 'pasta', 'butter'}: 2
# {'coffee', 'yogurt', 'cereal', 'pasta', 'butter'}: 2
# {'yogurt', 'pasta', 'cheese', 'butter'}: 2
# {'coffee', 'yogurt', 'cheese', 'pasta', 'butter'}: 2
# {'yogurt', 'cheese', 'cereal', 'pasta', 'butter'}: 2
# {'coffee', 'yogurt', 'cheese', 'cereal', 'pasta', 'butter'}: 2
# {'pasta', 'butter', 'bananas'}: 2
# {'chicken'}: 20
# {'chicken', 'bananas'}: 8
# {'chicken', 'cereal'}: 7
# {'chicken', 'cereal', 'bananas'}: 4
# {'coffee', 'chicken', 'cereal'}: 2
# {'chicken', 'cheese'}: 3
# {'chicken', 'cheese', 'bananas'}: 2
# {'chicken', 'cereal', 'cheese'}: 3
# {'chicken', 'cereal', 'cheese', 'bananas'}: 2
# {'chicken', 'oranges', 'cheese'}: 2
# {'chicken', 'oranges', 'cereal', 'cheese'}: 2
# {'chicken', 'onions'}: 5
# {'chicken', 'onions', 'bananas'}: 2
# {'chicken', 'cereal', 'onions'}: 3
# {'chicken', 'cereal', 'onions', 'bananas'}: 2
# {'chicken', 'onions', 'cheese'}: 2
# {'chicken', 'cereal', 'onions', 'cheese'}: 2
# {'eggs', 'chicken', 'onions'}: 2
# {'chicken', 'onions', 'potatoes'}: 3
# {'eggs', 'chicken', 'onions', 'potatoes'}: 2
# {'chicken', 'cereal', 'onions', 'potatoes'}: 2
# {'chicken', 'onions', 'apples'}: 2
# {'eggs', 'chicken', 'onions', 'apples'}: 2
# {'chicken', 'onions', 'potatoes', 'apples'}: 2
# {'eggs', 'chicken', 'apples', 'potatoes', 'onions'}: 2
# {'milk', 'chicken', 'onions'}: 2
# {'milk', 'chicken', 'eggs', 'onions'}: 2
# {'milk', 'chicken', 'onions', 'potatoes'}: 2
# {'milk', 'chicken', 'eggs', 'onions', 'potatoes'}: 2
# {'milk', 'chicken', 'onions', 'apples'}: 2
# {'milk', 'chicken', 'eggs', 'apples', 'onions'}: 2
# {'milk', 'chicken', 'apples', 'potatoes', 'onions'}: 2
# {'milk', 'chicken', 'eggs', 'apples', 'potatoes', 'onions'}: 2
# {'chicken', 'pasta'}: 8
# {'chicken', 'pasta', 'bananas'}: 3
# {'chicken', 'cereal', 'pasta'}: 3
# {'chicken', 'cereal', 'pasta', 'bananas'}: 2
# {'chicken', 'pasta', 'cheese'}: 3
# {'chicken', 'pasta', 'cheese', 'bananas'}: 2
# {'chicken', 'cereal', 'pasta', 'cheese'}: 3
# {'chicken', 'cheese', 'bananas', 'cereal', 'pasta'}: 2
# {'chicken', 'oranges', 'pasta', 'cheese'}: 2
# {'chicken', 'oranges', 'cheese', 'cereal', 'pasta'}: 2
# {'chicken', 'pasta', 'onions'}: 3
# {'chicken', 'cereal', 'pasta', 'onions'}: 2
# {'chicken', 'cheese', 'pasta', 'onions'}: 2
# {'chicken', 'cheese', 'pasta', 'cereal', 'onions'}: 2
# {'eggs', 'chicken', 'pasta', 'onions'}: 2
# {'potatoes', 'chicken', 'pasta', 'onions'}: 2
# {'eggs', 'chicken', 'pasta', 'onions', 'potatoes'}: 2
# {'chicken', 'pasta', 'onions', 'apples'}: 2
# {'eggs', 'chicken', 'pasta', 'apples', 'onions'}: 2
# {'chicken', 'pasta', 'apples', 'potatoes', 'onions'}: 2
# {'eggs', 'chicken', 'pasta', 'apples', 'potatoes', 'onions'}: 2
# {'milk', 'chicken', 'pasta', 'onions'}: 2
# {'milk', 'chicken', 'eggs', 'pasta', 'onions'}: 2
# {'milk', 'chicken', 'pasta', 'onions', 'potatoes'}: 2
# {'milk', 'chicken', 'eggs', 'pasta', 'onions', 'potatoes'}: 2
# {'milk', 'chicken', 'pasta', 'apples', 'onions'}: 2
# {'milk', 'chicken', 'eggs', 'pasta', 'apples', 'onions'}: 2
# {'milk', 'chicken', 'potatoes', 'pasta', 'apples', 'onions'}: 2
# {'milk', 'chicken', 'potatoes', 'eggs', 'pasta', 'apples', 'onions'}: 2
# {'chicken', 'pasta', 'potatoes'}: 4
# {'eggs', 'chicken', 'pasta', 'potatoes'}: 2
# {'chicken', 'pasta', 'tomatoes'}: 3
# {'potatoes', 'chicken', 'pasta', 'tomatoes'}: 3
# {'chicken', 'pasta', 'sugar'}: 3
# {'chicken', 'pasta', 'potatoes', 'sugar'}: 2
# {'chicken', 'pasta', 'tomatoes', 'sugar'}: 2
# {'chicken', 'sugar', 'tomatoes', 'pasta', 'potatoes'}: 2
# {'chicken', 'pasta', 'apples'}: 4
# {'chicken', 'pasta', 'potatoes', 'apples'}: 3
# {'eggs', 'chicken', 'pasta', 'apples', 'potatoes'}: 2
# {'chicken', 'pasta', 'tomatoes', 'apples'}: 2
# {'chicken', 'pasta', 'tomatoes', 'apples', 'potatoes'}: 2
# {'chicken', 'sugar', 'pasta', 'apples'}: 3
# {'chicken', 'sugar', 'pasta', 'apples', 'potatoes'}: 2
# {'chicken', 'sugar', 'pasta', 'tomatoes', 'apples'}: 2
# {'chicken', 'sugar', 'pasta', 'tomatoes', 'apples', 'potatoes'}: 2
# {'eggs', 'chicken', 'pasta', 'apples'}: 2
# {'chicken', 'pasta', 'bread'}: 2
# {'coffee', 'chicken', 'pasta'}: 2
# {'eggs', 'chicken', 'pasta'}: 3
# {'eggs', 'chicken', 'pasta', 'coffee'}: 2
# {'eggs', 'chicken', 'cereal', 'pasta'}: 2
# {'eggs', 'chicken', 'oranges', 'pasta'}: 2
# {'eggs', 'chicken', 'oranges', 'cereal', 'pasta'}: 2
# {'eggs', 'chicken', 'pasta', 'cheese'}: 2
# {'eggs', 'chicken', 'cheese', 'cereal', 'pasta'}: 2
# {'eggs', 'chicken', 'oranges', 'cheese', 'pasta'}: 2
# {'eggs', 'chicken', 'oranges', 'cheese', 'cereal', 'pasta'}: 2
# {'chicken', 'yogurt', 'pasta'}: 2
# {'coffee', 'chicken', 'yogurt', 'pasta'}: 2
# {'eggs', 'chicken', 'yogurt', 'pasta'}: 2
# {'coffee', 'chicken', 'eggs', 'yogurt', 'pasta'}: 2
# {'milk', 'chicken', 'pasta'}: 2
# {'milk', 'chicken', 'eggs', 'pasta'}: 2
# {'milk', 'chicken', 'pasta', 'potatoes'}: 2
# {'milk', 'chicken', 'eggs', 'pasta', 'potatoes'}: 2
# {'milk', 'chicken', 'pasta', 'apples'}: 2
# {'milk', 'chicken', 'eggs', 'pasta', 'apples'}: 2
# {'milk', 'chicken', 'pasta', 'apples', 'potatoes'}: 2
# {'milk', 'chicken', 'eggs', 'pasta', 'apples', 'potatoes'}: 2
# {'juice', 'chicken', 'pasta'}: 2
# {'juice', 'chicken', 'pasta', 'coffee'}: 2
# {'juice', 'chicken', 'eggs', 'pasta'}: 2
# {'juice', 'chicken', 'coffee', 'eggs', 'pasta'}: 2
# {'juice', 'chicken', 'yogurt', 'pasta'}: 2
# {'juice', 'chicken', 'coffee', 'yogurt', 'pasta'}: 2
# {'juice', 'chicken', 'eggs', 'yogurt', 'pasta'}: 2
# {'juice', 'chicken', 'eggs', 'yogurt', 'coffee', 'pasta'}: 2
# {'chicken', 'oranges', 'pasta'}: 2
# {'chicken', 'oranges', 'cereal', 'pasta'}: 2
# {'chicken', 'pasta', 'butter'}: 2
# {'chicken', 'pasta', 'butter', 'bananas'}: 2
# {'eggs', 'chicken'}: 4
# {'eggs', 'chicken', 'bananas'}: 2
# {'eggs', 'chicken', 'coffee'}: 2
# {'eggs', 'chicken', 'cereal'}: 2
# {'eggs', 'chicken', 'oranges'}: 2
# {'eggs', 'chicken', 'oranges', 'cereal'}: 2
# {'eggs', 'chicken', 'cheese'}: 2
# {'eggs', 'chicken', 'cereal', 'cheese'}: 2
# {'eggs', 'chicken', 'oranges', 'cheese'}: 2
# {'eggs', 'chicken', 'oranges', 'cheese', 'cereal'}: 2
# {'chicken', 'tomatoes'}: 7
# {'chicken', 'tomatoes', 'bananas'}: 2
# {'eggs', 'chicken', 'tomatoes'}: 2
# {'potatoes', 'chicken', 'tomatoes'}: 5
# {'potatoes', 'chicken', 'tomatoes', 'coffee'}: 2
# {'coffee', 'chicken', 'tomatoes'}: 2
# {'chicken', 'cereal', 'tomatoes'}: 2
# {'chicken', 'butter'}: 7
# {'chicken', 'butter', 'bananas'}: 4
# {'eggs', 'chicken', 'butter'}: 2
# {'eggs', 'chicken', 'butter', 'bananas'}: 2
# {'chicken', 'tomatoes', 'butter'}: 4
# {'chicken', 'tomatoes', 'butter', 'bananas'}: 2
# {'potatoes', 'chicken', 'tomatoes', 'butter'}: 3
# {'coffee', 'chicken', 'butter'}: 2
# {'chicken', 'cereal', 'butter'}: 2
# {'coffee', 'chicken', 'cereal', 'butter'}: 2
# {'chicken', 'oranges', 'butter'}: 4
# {'coffee', 'chicken', 'oranges', 'butter'}: 2
# {'chicken', 'oranges', 'cereal', 'butter'}: 2
# {'coffee', 'chicken', 'oranges', 'cereal', 'butter'}: 2
# {'chicken', 'oranges', 'butter', 'bananas'}: 2
# {'chicken', 'potatoes', 'butter'}: 4
# {'chicken', 'oranges', 'potatoes', 'butter'}: 2
# {'chicken', 'potatoes', 'butter', 'bananas'}: 2
# {'chicken', 'potatoes'}: 8
# {'coffee', 'chicken', 'potatoes'}: 2
# {'eggs', 'chicken', 'potatoes'}: 2
# {'chicken', 'cereal', 'potatoes'}: 3
# {'chicken', 'oranges', 'potatoes'}: 3
# {'chicken', 'oranges', 'cereal', 'potatoes'}: 2
# {'chicken', 'potatoes', 'bananas'}: 3
# {'chicken', 'sugar'}: 3
# {'chicken', 'potatoes', 'sugar'}: 2
# {'chicken', 'tomatoes', 'sugar'}: 2
# {'potatoes', 'chicken', 'tomatoes', 'sugar'}: 2
# {'chicken', 'apples'}: 5
# {'chicken', 'apples', 'potatoes'}: 3
# {'eggs', 'chicken', 'apples', 'potatoes'}: 2
# {'chicken', 'apples', 'tomatoes'}: 2
# {'potatoes', 'chicken', 'apples', 'tomatoes'}: 2
# {'chicken', 'apples', 'sugar'}: 3
# {'chicken', 'apples', 'potatoes', 'sugar'}: 2
# {'chicken', 'apples', 'tomatoes', 'sugar'}: 2
# {'chicken', 'sugar', 'tomatoes', 'apples', 'potatoes'}: 2
# {'eggs', 'chicken', 'apples'}: 2
# {'chicken', 'oranges', 'apples'}: 2
# {'chicken', 'bread'}: 6
# {'potatoes', 'chicken', 'bread'}: 3
# {'potatoes', 'chicken', 'oranges', 'bread'}: 2
# {'chicken', 'tomatoes', 'bread'}: 2
# {'potatoes', 'chicken', 'tomatoes', 'bread'}: 2
# {'chicken', 'apples', 'bread'}: 2
# {'coffee', 'chicken', 'bread'}: 2
# {'chicken', 'cereal', 'bread'}: 2
# {'coffee', 'chicken', 'cereal', 'bread'}: 2
# {'chicken', 'oranges', 'bread'}: 4
# {'coffee', 'chicken', 'oranges', 'bread'}: 2
# {'chicken', 'oranges', 'cereal', 'bread'}: 2
# {'coffee', 'chicken', 'oranges', 'bread', 'cereal'}: 2
# {'chicken', 'oranges', 'bread', 'bananas'}: 2
# {'chicken', 'bread', 'butter'}: 4
# {'coffee', 'chicken', 'bread', 'butter'}: 2
# {'chicken', 'cereal', 'bread', 'butter'}: 2
# {'coffee', 'chicken', 'bread', 'cereal', 'butter'}: 2
# {'chicken', 'oranges', 'bread', 'butter'}: 4
# {'coffee', 'chicken', 'oranges', 'bread', 'butter'}: 2
# {'chicken', 'oranges', 'bread', 'cereal', 'butter'}: 2
# {'coffee', 'chicken', 'oranges', 'bread', 'cereal', 'butter'}: 2
# {'chicken', 'oranges', 'bread', 'bananas', 'butter'}: 2
# {'potatoes', 'chicken', 'bread', 'butter'}: 2
# {'chicken', 'oranges', 'bread', 'potatoes', 'butter'}: 2
# {'chicken', 'bread', 'butter', 'bananas'}: 2
# {'chicken', 'bread', 'bananas'}: 3
# {'coffee', 'chicken'}: 3
# {'chicken', 'yogurt'}: 3
# {'coffee', 'chicken', 'yogurt'}: 2
# {'eggs', 'chicken', 'yogurt'}: 2
# {'eggs', 'chicken', 'yogurt', 'coffee'}: 2
# {'chicken', 'yogurt', 'oranges'}: 2
# {'milk', 'chicken'}: 3
# {'milk', 'chicken', 'eggs'}: 2
# {'milk', 'chicken', 'potatoes'}: 3
# {'milk', 'chicken', 'eggs', 'potatoes'}: 2
# {'milk', 'chicken', 'oranges', 'potatoes'}: 2
# {'milk', 'chicken', 'apples'}: 2
# {'milk', 'chicken', 'eggs', 'apples'}: 2
# {'milk', 'chicken', 'apples', 'potatoes'}: 2
# {'milk', 'chicken', 'eggs', 'apples', 'potatoes'}: 2
# {'milk', 'chicken', 'oranges'}: 2
# {'juice', 'chicken'}: 5
# {'juice', 'chicken', 'coffee'}: 3
# {'juice', 'chicken', 'eggs'}: 2
# {'juice', 'chicken', 'eggs', 'coffee'}: 2
# {'juice', 'chicken', 'potatoes'}: 3
# {'juice', 'chicken', 'potatoes', 'coffee'}: 2
# {'juice', 'chicken', 'oranges', 'potatoes'}: 2
# {'juice', 'chicken', 'tomatoes'}: 2
# {'juice', 'chicken', 'tomatoes', 'coffee'}: 2
# {'juice', 'chicken', 'potatoes', 'tomatoes'}: 2
# {'juice', 'chicken', 'coffee', 'tomatoes', 'potatoes'}: 2
# {'juice', 'chicken', 'yogurt'}: 2
# {'juice', 'chicken', 'yogurt', 'coffee'}: 2
# {'juice', 'chicken', 'yogurt', 'eggs'}: 2
# {'juice', 'chicken', 'coffee', 'eggs', 'yogurt'}: 2
# {'juice', 'chicken', 'milk'}: 2
# {'juice', 'chicken', 'milk', 'potatoes'}: 2
# {'juice', 'chicken', 'cereal'}: 2
# {'juice', 'chicken', 'cereal', 'coffee'}: 2
# {'juice', 'chicken', 'oranges'}: 3
# {'juice', 'chicken', 'oranges', 'coffee'}: 2
# {'juice', 'chicken', 'oranges', 'cereal'}: 2
# {'juice', 'chicken', 'coffee', 'oranges', 'cereal'}: 2
# {'juice', 'chicken', 'oranges', 'bananas'}: 2
# {'juice', 'chicken', 'butter'}: 3
# {'juice', 'chicken', 'coffee', 'butter'}: 2
# {'juice', 'chicken', 'cereal', 'butter'}: 2
# {'juice', 'chicken', 'coffee', 'cereal', 'butter'}: 2
# {'juice', 'chicken', 'oranges', 'butter'}: 3
# {'juice', 'chicken', 'coffee', 'oranges', 'butter'}: 2
# {'juice', 'chicken', 'oranges', 'cereal', 'butter'}: 2
# {'juice', 'chicken', 'oranges', 'coffee', 'cereal', 'butter'}: 2
# {'juice', 'chicken', 'oranges', 'bananas', 'butter'}: 2
# {'juice', 'chicken', 'potatoes', 'butter'}: 2
# {'juice', 'chicken', 'oranges', 'potatoes', 'butter'}: 2
# {'juice', 'chicken', 'butter', 'bananas'}: 2
# {'juice', 'chicken', 'bread'}: 4
# {'juice', 'chicken', 'bread', 'coffee'}: 2
# {'juice', 'chicken', 'cereal', 'bread'}: 2
# {'juice', 'chicken', 'coffee', 'bread', 'cereal'}: 2
# {'juice', 'chicken', 'oranges', 'bread'}: 3
# {'juice', 'chicken', 'coffee', 'oranges', 'bread'}: 2
# {'juice', 'chicken', 'oranges', 'bread', 'cereal'}: 2
# {'juice', 'chicken', 'oranges', 'coffee', 'bread', 'cereal'}: 2
# {'juice', 'chicken', 'oranges', 'bread', 'bananas'}: 2
# {'juice', 'chicken', 'potatoes', 'bread'}: 2
# {'juice', 'chicken', 'oranges', 'bread', 'potatoes'}: 2
# {'juice', 'chicken', 'bread', 'butter'}: 3
# {'juice', 'chicken', 'coffee', 'bread', 'butter'}: 2
# {'juice', 'chicken', 'bread', 'cereal', 'butter'}: 2
# {'juice', 'chicken', 'coffee', 'bread', 'cereal', 'butter'}: 2
# {'juice', 'chicken', 'oranges', 'bread', 'butter'}: 3
# {'juice', 'chicken', 'oranges', 'coffee', 'bread', 'butter'}: 2
# {'juice', 'chicken', 'oranges', 'bread', 'cereal', 'butter'}: 2
# {'juice', 'chicken', 'oranges', 'coffee', 'bread', 'cereal', 'butter'}: 2
# {'juice', 'chicken', 'oranges', 'bread', 'bananas', 'butter'}: 2
# {'juice', 'chicken', 'bread', 'potatoes', 'butter'}: 2
# {'juice', 'chicken', 'oranges', 'bread', 'potatoes', 'butter'}: 2
# {'juice', 'chicken', 'bread', 'bananas', 'butter'}: 2
# {'juice', 'chicken', 'bread', 'bananas'}: 3
# {'juice', 'chicken', 'bananas'}: 3
# {'chicken', 'tea'}: 2
# {'chicken', 'tea', 'sugar'}: 2
# {'chicken', 'apples', 'tea'}: 2
# {'chicken', 'apples', 'tea', 'sugar'}: 2
# {'chicken', 'pasta', 'tea'}: 2
# {'chicken', 'pasta', 'tea', 'sugar'}: 2
# {'chicken', 'pasta', 'tea', 'apples'}: 2
# {'chicken', 'sugar', 'pasta', 'apples', 'tea'}: 2
# {'chicken', 'oranges'}: 6
# {'coffee', 'chicken', 'oranges'}: 2
# {'chicken', 'oranges', 'cereal'}: 3
# {'coffee', 'chicken', 'oranges', 'cereal'}: 2
# {'chicken', 'oranges', 'bananas'}: 2
# {'cheese'}: 28
# {'cheese', 'bananas'}: 8
# {'cereal', 'cheese'}: 12
# {'cereal', 'cheese', 'bananas'}: 3
# {'coffee', 'cereal', 'cheese'}: 5
# {'oranges', 'cheese'}: 9
# {'oranges', 'cheese', 'bananas'}: 3
# {'oranges', 'cereal', 'cheese'}: 4
# {'coffee', 'oranges', 'cereal', 'cheese'}: 2
# {'coffee', 'oranges', 'cheese'}: 3
# {'coffee', 'cheese'}: 7
# {'coffee', 'cheese', 'bananas'}: 2
# {'tea'}: 23
# {'tea', 'bananas'}: 5
# {'cereal', 'tea'}: 6
# {'cereal', 'tea', 'bananas'}: 2
# {'coffee', 'cereal', 'tea'}: 2
# {'eggs', 'tea'}: 4
# {'eggs', 'tea', 'bananas'}: 2
# {'eggs', 'coffee', 'tea'}: 2
# {'pasta', 'tea'}: 6
# {'pasta', 'tea', 'bananas'}: 2
# {'cereal', 'pasta', 'tea'}: 2
# {'eggs', 'pasta', 'tea'}: 2
# {'coffee', 'pasta', 'tea'}: 4
# {'juice', 'pasta', 'tea'}: 3
# {'juice', 'pasta', 'coffee', 'tea'}: 3
# {'pasta', 'onions', 'tea'}: 2
# {'coffee', 'pasta', 'onions', 'tea'}: 2
# {'juice', 'pasta', 'onions', 'tea'}: 2
# {'juice', 'coffee', 'pasta', 'onions', 'tea'}: 2
# {'pasta', 'tea', 'sugar'}: 3
# {'coffee', 'pasta', 'tea', 'sugar'}: 2
# {'yogurt', 'pasta', 'tea'}: 2
# {'coffee', 'yogurt', 'pasta', 'tea'}: 2
# {'yogurt', 'pasta', 'tea', 'sugar'}: 2
# {'coffee', 'yogurt', 'sugar', 'pasta', 'tea'}: 2
# {'pasta', 'tea', 'apples'}: 3
# {'coffee', 'pasta', 'tea', 'apples'}: 2
# {'sugar', 'pasta', 'tea', 'apples'}: 3
# {'coffee', 'sugar', 'pasta', 'apples', 'tea'}: 2
# {'yogurt', 'pasta', 'tea', 'apples'}: 2
# {'coffee', 'yogurt', 'pasta', 'apples', 'tea'}: 2
# {'yogurt', 'sugar', 'pasta', 'apples', 'tea'}: 2
# {'coffee', 'yogurt', 'sugar', 'pasta', 'apples', 'tea'}: 2
# {'milk', 'pasta', 'tea'}: 2
# {'milk', 'pasta', 'coffee', 'tea'}: 2
# {'milk', 'pasta', 'tea', 'sugar'}: 2
# {'milk', 'coffee', 'sugar', 'pasta', 'tea'}: 2
# {'milk', 'yogurt', 'pasta', 'tea'}: 2
# {'milk', 'coffee', 'yogurt', 'pasta', 'tea'}: 2
# {'milk', 'yogurt', 'sugar', 'pasta', 'tea'}: 2
# {'milk', 'coffee', 'yogurt', 'sugar', 'pasta', 'tea'}: 2
# {'milk', 'pasta', 'tea', 'apples'}: 2
# {'milk', 'coffee', 'pasta', 'apples', 'tea'}: 2
# {'milk', 'sugar', 'pasta', 'apples', 'tea'}: 2
# {'milk', 'coffee', 'sugar', 'pasta', 'apples', 'tea'}: 2
# {'milk', 'yogurt', 'pasta', 'apples', 'tea'}: 2
# {'milk', 'coffee', 'yogurt', 'pasta', 'apples', 'tea'}: 2
# {'milk', 'yogurt', 'sugar', 'pasta', 'apples', 'tea'}: 2
# {'milk', 'coffee', 'yogurt', 'sugar', 'pasta', 'apples', 'tea'}: 2
# {'coffee', 'tea'}: 8
# {'coffee', 'tea', 'bananas'}: 2
# {'juice', 'tea'}: 8
# {'juice', 'tea', 'bananas'}: 2
# {'juice', 'coffee', 'tea'}: 5
# {'juice', 'coffee', 'tea', 'bananas'}: 2
# {'juice', 'cereal', 'tea'}: 2
# {'juice', 'butter', 'tea'}: 3
# {'juice', 'eggs', 'tea'}: 2
# {'juice', 'eggs', 'coffee', 'tea'}: 2
# {'juice', 'potatoes', 'tea'}: 3
# {'juice', 'coffee', 'potatoes', 'tea'}: 3
# {'juice', 'eggs', 'potatoes', 'tea'}: 2
# {'juice', 'coffee', 'eggs', 'potatoes', 'tea'}: 2
# {'juice', 'yogurt', 'tea'}: 2
# {'juice', 'cheese', 'tea'}: 2
# {'onions', 'tea'}: 6
# {'onions', 'tea', 'bananas'}: 2
# {'coffee', 'onions', 'tea'}: 3
# {'juice', 'onions', 'tea'}: 2
# {'juice', 'onions', 'coffee', 'tea'}: 2
# {'onions', 'potatoes', 'tea'}: 2
# {'coffee', 'onions', 'potatoes', 'tea'}: 2
# {'onions', 'tea', 'sugar'}: 2
# {'onions', 'tea', 'apples'}: 2
# {'milk', 'onions', 'tea'}: 2
# {'onions', 'cheese', 'tea'}: 2
# {'onions', 'bread', 'tea'}: 2
# {'butter', 'tea'}: 8
# {'cereal', 'butter', 'tea'}: 3
# {'oranges', 'butter', 'tea'}: 2
# {'eggs', 'butter', 'tea'}: 2
# {'butter', 'potatoes', 'tea'}: 3
# {'eggs', 'butter', 'potatoes', 'tea'}: 2
# {'butter', 'potatoes', 'tea', 'bananas'}: 2
# {'cheese', 'butter', 'potatoes', 'tea'}: 2
# {'tea', 'cheese', 'bananas', 'potatoes', 'butter'}: 2
# {'yogurt', 'butter', 'tea'}: 2
# {'butter', 'tea', 'bananas'}: 3
# {'butter', 'cheese', 'tea'}: 4
# {'butter', 'cheese', 'tea', 'bananas'}: 3
# {'cereal', 'butter', 'cheese', 'tea'}: 2
# {'coffee', 'butter', 'cheese', 'tea'}: 2
# {'coffee', 'butter', 'tea'}: 2
# {'potatoes', 'tea'}: 6
# {'coffee', 'potatoes', 'tea'}: 4
# {'eggs', 'potatoes', 'tea'}: 3
# {'eggs', 'coffee', 'potatoes', 'tea'}: 2
# {'potatoes', 'tea', 'bananas'}: 2
# {'cereal', 'potatoes', 'tea'}: 2
# {'cheese', 'potatoes', 'tea'}: 2
# {'cheese', 'potatoes', 'tea', 'bananas'}: 2
# {'tomatoes', 'tea'}: 2
# {'tea', 'sugar'}: 5
# {'coffee', 'tea', 'sugar'}: 3
# {'yogurt', 'tea'}: 6
# {'coffee', 'yogurt', 'tea'}: 2
# {'eggs', 'yogurt', 'tea'}: 2
# {'yogurt', 'potatoes', 'tea'}: 2
# {'eggs', 'yogurt', 'potatoes', 'tea'}: 2
# {'tomatoes', 'yogurt', 'tea'}: 2
# {'yogurt', 'tea', 'sugar'}: 2
# {'coffee', 'yogurt', 'tea', 'sugar'}: 2
# {'oranges', 'yogurt', 'tea'}: 2
# {'yogurt', 'cheese', 'tea'}: 3
# {'cereal', 'yogurt', 'cheese', 'tea'}: 2
# {'cereal', 'yogurt', 'tea'}: 2
# {'apples', 'tea'}: 5
# {'coffee', 'apples', 'tea'}: 2
# {'tomatoes', 'apples', 'tea'}: 2
# {'apples', 'tea', 'sugar'}: 3
# {'coffee', 'apples', 'tea', 'sugar'}: 2
# {'yogurt', 'apples', 'tea'}: 3
# {'coffee', 'yogurt', 'apples', 'tea'}: 2
# {'tomatoes', 'yogurt', 'apples', 'tea'}: 2
# {'yogurt', 'apples', 'tea', 'sugar'}: 2
# {'coffee', 'yogurt', 'sugar', 'apples', 'tea'}: 2
# {'yogurt', 'apples', 'cheese', 'tea'}: 2
# {'apples', 'cheese', 'tea'}: 3
# {'milk', 'tea'}: 5
# {'milk', 'coffee', 'tea'}: 2
# {'milk', 'tomatoes', 'tea'}: 2
# {'milk', 'tea', 'sugar'}: 2
# {'milk', 'coffee', 'tea', 'sugar'}: 2
# {'milk', 'yogurt', 'tea'}: 3
# {'milk', 'yogurt', 'coffee', 'tea'}: 2
# {'milk', 'tomatoes', 'yogurt', 'tea'}: 2
# {'milk', 'yogurt', 'tea', 'sugar'}: 2
# {'milk', 'coffee', 'yogurt', 'sugar', 'tea'}: 2
# {'milk', 'yogurt', 'cheese', 'tea'}: 2
# {'milk', 'apples', 'tea'}: 3
# {'milk', 'apples', 'coffee', 'tea'}: 2
# {'milk', 'tomatoes', 'apples', 'tea'}: 2
# {'milk', 'apples', 'tea', 'sugar'}: 2
# {'milk', 'coffee', 'sugar', 'apples', 'tea'}: 2
# {'milk', 'yogurt', 'apples', 'tea'}: 3
# {'milk', 'coffee', 'yogurt', 'apples', 'tea'}: 2
# {'milk', 'yogurt', 'tomatoes', 'apples', 'tea'}: 2
# {'milk', 'yogurt', 'sugar', 'apples', 'tea'}: 2
# {'milk', 'coffee', 'yogurt', 'sugar', 'apples', 'tea'}: 2
# {'milk', 'yogurt', 'cheese', 'apples', 'tea'}: 2
# {'milk', 'apples', 'cheese', 'tea'}: 2
# {'milk', 'oranges', 'tea'}: 3
# {'milk', 'cheese', 'tea'}: 3
# {'milk', 'oranges', 'cheese', 'tea'}: 2
# {'milk', 'butter', 'tea'}: 2
# {'milk', 'butter', 'cheese', 'tea'}: 2
# {'oranges', 'tea'}: 5
# {'bread', 'tea'}: 5
# {'oranges', 'bread', 'tea'}: 2
# {'potatoes', 'bread', 'tea'}: 3
# {'potatoes', 'cereal', 'bread', 'tea'}: 2
# {'yogurt', 'bread', 'tea'}: 2
# {'butter', 'bread', 'tea'}: 4
# {'oranges', 'butter', 'bread', 'tea'}: 2
# {'potatoes', 'butter', 'bread', 'tea'}: 2
# {'yogurt', 'butter', 'bread', 'tea'}: 2
# {'butter', 'bread', 'tea', 'bananas'}: 2
# {'cereal', 'butter', 'bread', 'tea'}: 2
# {'cheese', 'butter', 'bread', 'tea'}: 3
# {'tea', 'cheese', 'bread', 'bananas', 'butter'}: 2
# {'tea', 'cheese', 'bread', 'cereal', 'butter'}: 2
# {'bread', 'tea', 'bananas'}: 2
# {'cereal', 'bread', 'tea'}: 3
# {'coffee', 'cereal', 'bread', 'tea'}: 2
# {'cheese', 'bread', 'tea'}: 3
# {'cheese', 'bread', 'tea', 'bananas'}: 2
# {'cereal', 'cheese', 'bread', 'tea'}: 2
# {'coffee', 'bread', 'tea'}: 2
# {'milk', 'bread', 'tea'}: 2
# {'milk', 'cheese', 'bread', 'tea'}: 2
# {'milk', 'butter', 'bread', 'tea'}: 2
# {'milk', 'tea', 'cheese', 'bread', 'butter'}: 2
# {'cheese', 'tea'}: 7
# {'oranges', 'cheese', 'tea'}: 2
# {'cereal', 'cheese', 'tea'}: 3
# {'cheese', 'tea', 'bananas'}: 3
# {'coffee', 'cheese', 'tea'}: 2
# {'yogurt'}: 26
# {'yogurt', 'bananas'}: 7
# {'coffee', 'yogurt'}: 9
# {'coffee', 'yogurt', 'bananas'}: 2
# {'eggs', 'yogurt'}: 5
# {'eggs', 'yogurt', 'coffee'}: 3
# {'eggs', 'oranges', 'yogurt'}: 2
# {'eggs', 'cereal', 'yogurt'}: 2
# {'eggs', 'cereal', 'yogurt', 'coffee'}: 2
# {'eggs', 'yogurt', 'cheese'}: 2
# {'eggs', 'yogurt', 'cheese', 'coffee'}: 2
# {'eggs', 'cereal', 'yogurt', 'cheese'}: 2
# {'coffee', 'eggs', 'yogurt', 'cheese', 'cereal'}: 2
# {'eggs', 'yogurt', 'bananas'}: 2
# {'yogurt', 'potatoes'}: 5
# {'coffee', 'yogurt', 'potatoes'}: 3
# {'eggs', 'yogurt', 'potatoes'}: 2
# {'oranges', 'yogurt', 'potatoes'}: 3
# {'yogurt', 'potatoes', 'cheese'}: 2
# {'oranges', 'yogurt', 'potatoes', 'cheese'}: 2
# {'tomatoes', 'yogurt'}: 5
# {'eggs', 'tomatoes', 'yogurt'}: 2
# {'tomatoes', 'yogurt', 'potatoes'}: 2
# {'tomatoes', 'yogurt', 'bananas'}: 3
# {'tomatoes', 'yogurt', 'oranges'}: 2
# {'tomatoes', 'yogurt', 'cheese'}: 2
# {'tomatoes', 'yogurt', 'oranges', 'cheese'}: 2
# {'yogurt', 'sugar'}: 7
# {'coffee', 'yogurt', 'sugar'}: 3
# {'eggs', 'yogurt', 'sugar'}: 2
# {'yogurt', 'potatoes', 'sugar'}: 3
# {'coffee', 'yogurt', 'potatoes', 'sugar'}: 2
# {'tomatoes', 'yogurt', 'sugar'}: 4
# {'eggs', 'tomatoes', 'yogurt', 'sugar'}: 2
# {'tomatoes', 'yogurt', 'potatoes', 'sugar'}: 2
# {'tomatoes', 'yogurt', 'bananas', 'sugar'}: 3
# {'yogurt', 'bananas', 'sugar'}: 3
# {'yogurt', 'cheese', 'sugar'}: 2
# {'oranges', 'yogurt'}: 8
# {'coffee', 'oranges', 'yogurt'}: 4
# {'oranges', 'yogurt', 'bananas'}: 2
# {'yogurt', 'cheese'}: 7
# {'yogurt', 'cheese', 'bananas'}: 2
# {'oranges', 'yogurt', 'cheese'}: 4
# {'oranges', 'yogurt', 'cheese', 'bananas'}: 2
# {'coffee', 'oranges', 'yogurt', 'cheese'}: 2
# {'cereal', 'yogurt', 'cheese'}: 4
# {'coffee', 'cereal', 'yogurt', 'cheese'}: 3
# {'coffee', 'yogurt', 'cheese'}: 4
# {'cereal', 'yogurt'}: 4
# {'coffee', 'cereal', 'yogurt'}: 3
# {'juice'}: 23
# {'juice', 'eggs'}: 7
# {'juice', 'eggs', 'coffee'}: 3
# {'juice', 'eggs', 'coffee', 'bananas'}: 2
# {'juice', 'eggs', 'bananas'}: 3
# {'juice', 'eggs', 'cheese'}: 3
# {'juice', 'eggs', 'cheese', 'bananas'}: 2
# {'juice', 'eggs', 'cheese', 'coffee'}: 2
# {'juice', 'coffee', 'eggs', 'cheese', 'bananas'}: 2
# {'juice', 'tomatoes'}: 5
# {'juice', 'tomatoes', 'eggs'}: 3
# {'juice', 'tomatoes', 'coffee'}: 2
# {'juice', 'tomatoes', 'potatoes'}: 4
# {'juice', 'tomatoes', 'potatoes', 'coffee'}: 2
# {'juice', 'tomatoes', 'eggs', 'potatoes'}: 2
# {'juice', 'tomatoes', 'potatoes', 'bananas'}: 2
# {'juice', 'tomatoes', 'oranges', 'potatoes'}: 2
# {'juice', 'tomatoes', 'bananas'}: 2
# {'juice', 'tomatoes', 'oranges'}: 2
# {'juice', 'sugar'}: 4
# {'juice', 'eggs', 'sugar'}: 2
# {'juice', 'tomatoes', 'sugar'}: 3
# {'juice', 'tomatoes', 'eggs', 'sugar'}: 2
# {'juice', 'tomatoes', 'potatoes', 'sugar'}: 2
# {'juice', 'coffee', 'sugar'}: 2
# {'juice', 'potatoes', 'sugar'}: 3
# {'juice', 'potatoes', 'coffee', 'sugar'}: 2
# {'juice', 'butter'}: 8
# {'juice', 'eggs', 'butter'}: 4
# {'juice', 'eggs', 'butter', 'bananas'}: 3
# {'juice', 'eggs', 'coffee', 'butter'}: 2
# {'juice', 'coffee', 'eggs', 'bananas', 'butter'}: 2
# {'juice', 'eggs', 'cheese', 'butter'}: 2
# {'juice', 'eggs', 'cheese', 'bananas', 'butter'}: 2
# {'juice', 'coffee', 'eggs', 'cheese', 'butter'}: 2
# {'juice', 'coffee', 'eggs', 'cheese', 'bananas', 'butter'}: 2
# {'juice', 'tomatoes', 'butter'}: 3
# {'juice', 'tomatoes', 'eggs', 'butter'}: 2
# {'juice', 'tomatoes', 'potatoes', 'butter'}: 2
# {'juice', 'cereal', 'butter'}: 3
# {'juice', 'cereal', 'coffee', 'butter'}: 2
# {'juice', 'butter', 'bananas'}: 4
# {'juice', 'potatoes', 'butter'}: 4
# {'juice', 'potatoes', 'butter', 'bananas'}: 3
# {'juice', 'eggs', 'potatoes', 'butter'}: 2
# {'juice', 'eggs', 'bananas', 'potatoes', 'butter'}: 2
# {'juice', 'coffee', 'potatoes', 'butter'}: 2
# {'juice', 'oranges', 'potatoes', 'butter'}: 2
# {'juice', 'coffee', 'butter'}: 3
# {'juice', 'coffee', 'butter', 'bananas'}: 2
# {'juice', 'oranges', 'butter'}: 3
# {'juice', 'oranges', 'coffee', 'butter'}: 2
# {'juice', 'oranges', 'cereal', 'butter'}: 2
# {'juice', 'coffee', 'oranges', 'cereal', 'butter'}: 2
# {'juice', 'oranges', 'butter', 'bananas'}: 2
# {'juice', 'cheese', 'butter'}: 2
# {'juice', 'cheese', 'butter', 'bananas'}: 2
# {'juice', 'coffee', 'cheese', 'butter'}: 2
# {'juice', 'coffee', 'cheese', 'bananas', 'butter'}: 2
# {'juice', 'milk'}: 4
# {'juice', 'milk', 'eggs'}: 3
# {'juice', 'milk', 'tomatoes'}: 3
# {'juice', 'milk', 'eggs', 'tomatoes'}: 3
# {'juice', 'milk', 'potatoes', 'tomatoes'}: 2
# {'juice', 'milk', 'eggs', 'tomatoes', 'potatoes'}: 2
# {'juice', 'milk', 'sugar'}: 2
# {'juice', 'milk', 'eggs', 'sugar'}: 2
# {'juice', 'milk', 'tomatoes', 'sugar'}: 2
# {'juice', 'milk', 'eggs', 'sugar', 'tomatoes'}: 2
# {'juice', 'milk', 'butter'}: 3
# {'juice', 'milk', 'eggs', 'butter'}: 2
# {'juice', 'milk', 'tomatoes', 'butter'}: 2
# {'juice', 'milk', 'eggs', 'tomatoes', 'butter'}: 2
# {'juice', 'milk', 'butter', 'bananas'}: 2
# {'juice', 'milk', 'potatoes', 'butter'}: 2
# {'juice', 'milk', 'bananas', 'potatoes', 'butter'}: 2
# {'juice', 'milk', 'potatoes'}: 3
# {'juice', 'milk', 'eggs', 'potatoes'}: 2
# {'juice', 'milk', 'potatoes', 'bananas'}: 2
# {'juice', 'milk', 'bananas'}: 2
# {'juice', 'bananas'}: 8
# {'juice', 'coffee'}: 9
# {'juice', 'coffee', 'bananas'}: 3
# {'juice', 'cereal'}: 5
# {'juice', 'cereal', 'coffee'}: 2
# {'juice', 'cereal', 'bananas'}: 2
# {'juice', 'yogurt'}: 6
# {'juice', 'yogurt', 'coffee'}: 3
# {'juice', 'yogurt', 'eggs'}: 2
# {'juice', 'yogurt', 'eggs', 'coffee'}: 2
# {'juice', 'yogurt', 'potatoes'}: 3
# {'juice', 'yogurt', 'potatoes', 'coffee'}: 2
# {'juice', 'tomatoes', 'yogurt'}: 2
# {'juice', 'tomatoes', 'yogurt', 'potatoes'}: 2
# {'juice', 'yogurt', 'sugar'}: 3
# {'juice', 'yogurt', 'coffee', 'sugar'}: 2
# {'juice', 'yogurt', 'potatoes', 'sugar'}: 3
# {'juice', 'coffee', 'yogurt', 'sugar', 'potatoes'}: 2
# {'juice', 'tomatoes', 'yogurt', 'sugar'}: 2
# {'juice', 'yogurt', 'sugar', 'tomatoes', 'potatoes'}: 2
# {'juice', 'yogurt', 'bananas'}: 2
# {'juice', 'oranges', 'yogurt'}: 2
# {'juice', 'oranges', 'yogurt', 'bananas'}: 2
# {'juice', 'yogurt', 'cheese'}: 3
# {'juice', 'yogurt', 'cheese', 'bananas'}: 2
# {'juice', 'oranges', 'yogurt', 'cheese'}: 2
# {'juice', 'oranges', 'yogurt', 'cheese', 'bananas'}: 2
# {'juice', 'cereal', 'yogurt', 'cheese'}: 2
# {'juice', 'cereal', 'yogurt'}: 2
# {'juice', 'potatoes'}: 8
# {'juice', 'potatoes', 'coffee'}: 5
# {'juice', 'eggs', 'potatoes'}: 3
# {'juice', 'eggs', 'potatoes', 'coffee'}: 2
# {'juice', 'eggs', 'potatoes', 'bananas'}: 2
# {'juice', 'potatoes', 'bananas'}: 4
# {'juice', 'oranges', 'potatoes'}: 3
# {'juice', 'oranges', 'potatoes', 'bananas'}: 2
# {'juice', 'cheese', 'potatoes'}: 2
# {'juice', 'cheese', 'potatoes', 'bananas'}: 2
# {'juice', 'apples'}: 2
# {'juice', 'apples', 'coffee'}: 2
# {'juice', 'apples', 'potatoes'}: 2
# {'juice', 'apples', 'potatoes', 'coffee'}: 2
# {'juice', 'apples', 'sugar'}: 2
# {'juice', 'apples', 'coffee', 'sugar'}: 2
# {'juice', 'apples', 'potatoes', 'sugar'}: 2
# {'juice', 'coffee', 'sugar', 'apples', 'potatoes'}: 2
# {'juice', 'yogurt', 'apples'}: 2
# {'juice', 'yogurt', 'apples', 'coffee'}: 2
# {'juice', 'yogurt', 'apples', 'potatoes'}: 2
# {'juice', 'coffee', 'yogurt', 'apples', 'potatoes'}: 2
# {'juice', 'yogurt', 'apples', 'sugar'}: 2
# {'juice', 'coffee', 'yogurt', 'sugar', 'apples'}: 2
# {'juice', 'yogurt', 'sugar', 'apples', 'potatoes'}: 2
# {'juice', 'coffee', 'yogurt', 'sugar', 'apples', 'potatoes'}: 2
# {'juice', 'cheese'}: 5
# {'juice', 'cheese', 'bananas'}: 3
# {'juice', 'oranges', 'cheese'}: 2
# {'juice', 'oranges', 'cheese', 'bananas'}: 2
# {'juice', 'cereal', 'cheese'}: 2
# {'juice', 'cheese', 'coffee'}: 2
# {'juice', 'cheese', 'coffee', 'bananas'}: 2
# {'juice', 'oranges'}: 4
# {'juice', 'oranges', 'bananas'}: 3
# {'juice', 'oranges', 'coffee'}: 2
# {'juice', 'oranges', 'cereal'}: 2
# {'juice', 'oranges', 'cereal', 'coffee'}: 2
# {'juice', 'bread'}: 5
# {'juice', 'bread', 'coffee'}: 3
# {'juice', 'cereal', 'bread'}: 2
# {'juice', 'cereal', 'bread', 'coffee'}: 2
# {'juice', 'oranges', 'bread'}: 3
# {'juice', 'oranges', 'bread', 'coffee'}: 2
# {'juice', 'oranges', 'cereal', 'bread'}: 2
# {'juice', 'coffee', 'oranges', 'bread', 'cereal'}: 2
# {'juice', 'oranges', 'bread', 'bananas'}: 2
# {'juice', 'potatoes', 'bread'}: 3
# {'juice', 'potatoes', 'bread', 'coffee'}: 2
# {'juice', 'potatoes', 'oranges', 'bread'}: 2
# {'juice', 'bread', 'butter'}: 3
# {'juice', 'coffee', 'bread', 'butter'}: 2
# {'juice', 'cereal', 'bread', 'butter'}: 2
# {'juice', 'coffee', 'bread', 'cereal', 'butter'}: 2
# {'juice', 'oranges', 'bread', 'butter'}: 3
# {'juice', 'coffee', 'oranges', 'bread', 'butter'}: 2
# {'juice', 'oranges', 'bread', 'cereal', 'butter'}: 2
# {'juice', 'oranges', 'coffee', 'bread', 'cereal', 'butter'}: 2
# {'juice', 'oranges', 'bread', 'bananas', 'butter'}: 2
# {'juice', 'potatoes', 'bread', 'butter'}: 2
# {'juice', 'oranges', 'bread', 'potatoes', 'butter'}: 2
# {'juice', 'bread', 'butter', 'bananas'}: 2
# {'juice', 'yogurt', 'bread'}: 2
# {'juice', 'yogurt', 'bread', 'coffee'}: 2
# {'juice', 'bread', 'bananas'}: 3

# %% [markdown]
# ## Implementasi Assosiasi

# %%
# mencari aturan asosiasi
from mlxtend.frequent_patterns import association_rules

# Buat aturan asosiasi dengan minimum confidence 0.1
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

print("\nAturan Asosiasi:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])

# Visualisasi scatter plot confidence vs lift
plt.figure(figsize=(8, 5))
sns.scatterplot(data=rules, x='confidence', y='lift', size='support', sizes=(20, 200), alpha=0.7)
plt.title('Confidence vs Lift of Association Rules')
plt.xlabel('Confidence')
plt.ylabel('Lift')
plt.grid(True)
plt.tight_layout()
plt.show()

# Visualisasi top 10 aturan berdasarkan lift
top_rules = rules.nlargest(10, 'lift')
plt.figure(figsize=(10, 6))
y_pos = range(len(top_rules))
plt.barh(y_pos, top_rules['lift'], color='skyblue')
plt.yticks(y_pos, [f"{set(row['antecedents'])} → {set(row['consequents'])}" for _, row in top_rules.iterrows()])
plt.xlabel('Lift')
plt.title('Top 10 Association Rules by Lift')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# Aturan Asosiasi:
#                          antecedents  \
# 0         (coffee, cereal, potatoes)
# 1        (oranges, cereal, potatoes)
# 2                (oranges, potatoes)
# 3                 (oranges, bananas)
# 4                (potatoes, bananas)
# ...                              ...
# 1838664        (eggs, yogurt, bread)
# 1838665      (eggs, yogurt, bananas)
# 1838666       (eggs, bread, bananas)
# 1838667     (yogurt, bread, bananas)
# 1838668                (eggs, bread)
#
#                                       consequents   support  confidence  \
# 0                                       (oranges)  0.006536       0.500
# 1                                        (coffee)  0.006536       0.500
# 2                                       (bananas)  0.032680       0.500
# 3                                      (potatoes)  0.032680       0.625
# 4                                       (oranges)  0.032680       0.500
# ...                                           ...       ...         ...
# 1838664          (coffee, juice, butter, bananas)  0.006536       0.500
# 1838665            (coffee, juice, bread, butter)  0.006536       0.500
# 1838666           (coffee, yogurt, juice, butter)  0.006536       1.000
# 1838667             (coffee, eggs, juice, butter)  0.006536       1.000
# 1838668  (coffee, juice, butter, yogurt, bananas)  0.006536       0.500
#
#                lift
# 0          2.637931
# 1          2.318182
# 2          2.067568
# 3          3.541667
# 4          2.637931
# ...             ...
# 1838664   38.250000
# 1838665   38.250000
# 1838666  153.000000
# 1838667   76.500000
# 1838668   76.500000
#
# [1838669 rows x 5 columns]

# %%
# mencari nilai lift ratio
# Menyaring aturan dengan lift > 1 (hubungan yang kuat)
strong_rules = rules[rules['lift'] > 1]
print("\nAturan asosiasi dengan hubungan yang kuat (lift > 1):")
print(strong_rules[['antecedents', 'consequents', 'confidence', 'lift']])

# Visualisasi hubungan lift dan confidence
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
sns.scatterplot(data=strong_rules, x='confidence', y='lift', hue='lift', palette='viridis', s=100)
plt.title('Visualisasi Hubungan Confidence vs Lift')
plt.xlabel('Confidence')
plt.ylabel('Lift')
plt.legend(title='Lift')
plt.grid(True)
plt.show()
# Out:
# Aturan asosiasi dengan hubungan yang kuat (lift > 1):
#                          antecedents  \
# 0         (coffee, cereal, potatoes)
# 1        (oranges, cereal, potatoes)
# 2                (oranges, potatoes)
# 3                 (oranges, bananas)
# 4                (potatoes, bananas)
# ...                              ...
# 1838664        (eggs, yogurt, bread)
# 1838665      (eggs, yogurt, bananas)
# 1838666       (eggs, bread, bananas)
# 1838667     (yogurt, bread, bananas)
# 1838668                (eggs, bread)
#
#                                       consequents  confidence        lift
# 0                                       (oranges)       0.500    2.637931
# 1                                        (coffee)       0.500    2.318182
# 2                                       (bananas)       0.500    2.067568
# 3                                      (potatoes)       0.625    3.541667
# 4                                       (oranges)       0.500    2.637931
# ...                                           ...         ...         ...
# 1838664          (coffee, juice, butter, bananas)       0.500   38.250000
# 1838665            (coffee, juice, bread, butter)       0.500   38.250000
# 1838666           (coffee, yogurt, juice, butter)       1.000  153.000000
# 1838667             (coffee, eggs, juice, butter)       1.000   76.500000
# 1838668  (coffee, juice, butter, yogurt, bananas)       0.500   76.500000
#
# [1838669 rows x 4 columns]

# %% [markdown]
# # Kesimpulan Sementara

# %% [markdown]
# ## 1. Preprocessing Data
# - Dataset berisi 153 transaksi dengan 19 item unik (produk makanan)
# - Data sudah bersih tanpa nilai null
# - Item names dinormalisasi ke lowercase untuk konsistensi
# - Data dikonversi ke format binary encoding untuk algoritma FP-Growth
#
# ## 2. Implementasi FP-Growth Algorithm
# - Minimum Support : 2 (item harus muncul minimal 2 kali)
# - Minimum Confidence : 0.5 (50%)
# - Algoritma berhasil menemukan frequent itemsets dengan berbagai kombinasi item
# - Implementasi menggunakan struktur data FP-Tree
#
# ## 3. Hasil Frequent Itemsets
# Beberapa frequent itemsets yang ditemukan:
#
# - Single items: eggs (27), coffee (24), butter (23)
# - Kombinasi 2 items: {eggs, bananas} (7), {juice, butter} (8)
# - Kombinasi kompleks: {coffee, cheese, butter, yogurt, eggs, cereal} (2)
#
# ## 4. Association Rules
# - Ditemukan 1,838,669 aturan asosiasi dengan confidence ≥ 0.5
# - Semua aturan memiliki lift > 1, menunjukkan hubungan positif antar item
# - Contoh aturan kuat: {bananas, tomatoes, oranges} → {potatoes} dengan confidence 100% dan lift 5.67

# %%
# Tambahkan cell baru untuk analisis dan visualisasi kesimpulan
from collections import Counter

# 1. Visualisasi Top 10 Frequent Items
item_support = {}
for itemset, support in frequent_patterns.items():
    if len(itemset) == 1:
        item_support[list(itemset)[0]] = support

top_items = sorted(item_support.items(), key=lambda x: x[1], reverse=True)[:10]

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
items, supports = zip(*top_items)
plt.bar(items, supports, color='skyblue')
plt.title('Top 10 Most Frequent Items')
plt.xlabel('Items')
plt.ylabel('Support Count')
plt.xticks(rotation=45)

# 2. Distribusi Ukuran Itemsets
itemset_sizes = [len(itemset) for itemset in frequent_patterns.keys()]
size_counts = Counter(itemset_sizes)

plt.subplot(1, 2, 2)
sizes = list(size_counts.keys())
counts = list(size_counts.values())
plt.bar(sizes, counts, color='lightcoral')
plt.title('Distribution of Frequent Itemset Sizes')
plt.xlabel('Itemset Size')
plt.ylabel('Number of Itemsets')

plt.tight_layout()
plt.show()

# 3. Analisis Top Association Rules
print("\n=== ANALISIS KESIMPULAN ===")
print(f"Total transaksi: {len(transactions)}")
print(f"Total item unik: {len(set([item for transaction in transactions for item in transaction]))}")
print(f"Total frequent itemsets: {len(frequent_patterns)}")
print(f"Total association rules: {len(rules)}")

# Top 10 rules berdasarkan lift
top_rules = rules.nlargest(10, 'lift')
print("\nTop 10 Association Rules (berdasarkan lift):")
for idx, rule in top_rules.iterrows():
    antecedents = ', '.join(list(rule['antecedents']))
    consequents = ', '.join(list(rule['consequents']))
    print(f"{antecedents} → {consequents}")
    print(f"  Support: {rule['support']:.3f}, Confidence: {rule['confidence']:.3f}, Lift: {rule['lift']:.3f}")
    print()

# 4. Visualisasi Confidence vs Lift
plt.figure(figsize=(10, 6))
plt.scatter(rules['confidence'], rules['lift'], alpha=0.6, s=30)
plt.xlabel('Confidence')
plt.ylabel('Lift')
plt.title('Association Rules: Confidence vs Lift')
plt.axhline(y=1, color='red', linestyle='--', alpha=0.7, label='Lift = 1')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# 5. Heatmap untuk item co-occurrence
from itertools import combinations

# Buat matrix co-occurrence untuk top items
top_item_names = [item for item, _ in top_items[:8]]  # Ambil 8 item teratas
co_occurrence = np.zeros((len(top_item_names), len(top_item_names)))

for i, item1 in enumerate(top_item_names):
    for j, item2 in enumerate(top_item_names):
        if i != j:
            # Cari support untuk pasangan item
            pair = frozenset([item1, item2])
            if pair in frequent_patterns:
                co_occurrence[i][j] = frequent_patterns[pair]

plt.figure(figsize=(10, 8))
sns.heatmap(co_occurrence, 
            xticklabels=top_item_names, 
            yticklabels=top_item_names,
            annot=True, 
            fmt='.0f',
            cmap='YlOrRd')
plt.title('Co-occurrence Heatmap of Top Items')
plt.show()

# 6. Summary Statistics
print("\n=== STATISTIK RINGKASAN ===")
print(f"Rata-rata confidence: {rules['confidence'].mean():.3f}")
print(f"Rata-rata lift: {rules['lift'].mean():.3f}")
print(f"Rata-rata support: {rules['support'].mean():.3f}")
print(f"Jumlah rules dengan lift > 2: {len(rules[rules['lift'] > 2])}")
print(f"Jumlah rules dengan confidence > 0.8: {len(rules[rules['confidence'] > 0.8])}")

# 7. Rekomendasi Bisnis
print("\n=== REKOMENDASI BISNIS ===")
print("1. Item yang sering dibeli bersama:")
for itemset, support in list(frequent_patterns.items())[:10]:
    if len(itemset) >= 2:
        items_str = ', '.join(sorted(list(itemset)))
        print(f"   - {items_str} (support: {support})")

print("\n2. Strategi Cross-selling berdasarkan rules dengan lift tinggi:")
high_lift_rules = rules[rules['lift'] > 5].head(5)
for idx, rule in high_lift_rules.iterrows():
    antecedents = ', '.join(list(rule['antecedents']))
    consequents = ', '.join(list(rule['consequents']))
    print(f"   - Jika customer membeli {antecedents}, rekomendasikan {consequents}")
    print(f"     (Confidence: {rule['confidence']:.1%}, Lift: {rule['lift']:.2f})")
# Out:
# === ANALISIS KESIMPULAN ===
# Total transaksi: 153
# Total item unik: 19
# Total frequent itemsets: 1477
# Total association rules: 1838669
#
# Top 10 Association Rules (berdasarkan lift):
# eggs, oranges, cheese, butter → cereal, yogurt, bananas
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# cereal, yogurt, bananas → eggs, oranges, cheese, butter
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# coffee, oranges, eggs, butter → cereal, yogurt, bananas
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# yogurt, cereal, butter, bananas → coffee, oranges, eggs
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# coffee, oranges, eggs → yogurt, cereal, butter, bananas
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# cereal, yogurt, bananas → coffee, oranges, eggs, butter
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# yogurt, cheese, butter, bananas → coffee, oranges, eggs
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# coffee, oranges, eggs → yogurt, cheese, butter, bananas
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# coffee, oranges, cheese, butter → cereal, yogurt, bananas
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
#
# oranges, yogurt, cheese, butter → coffee, cereal, bananas
#   Support: 0.007, Confidence: 1.000, Lift: 153.000
# === STATISTIK RINGKASAN ===
# Rata-rata confidence: 0.895
# Rata-rata lift: 94.373
# Rata-rata support: 0.007
# Jumlah rules dengan lift > 2: 1838669
# Jumlah rules dengan confidence > 0.8: 1451417
#
# === REKOMENDASI BISNIS ===
# 1. Item yang sering dibeli bersama:
#    - bananas, eggs (support: 7)
#    - cereal, eggs (support: 7)
#    - bananas, cereal, eggs (support: 3)
#    - cereal, coffee, eggs (support: 2)
#    - coffee, eggs (support: 6)
#    - bananas, coffee, eggs (support: 2)
#    - cheese, eggs (support: 5)
#    - cereal, cheese, eggs (support: 3)
#    - cereal, cheese, coffee, eggs (support: 2)
#
# 2. Strategi Cross-selling berdasarkan rules dengan lift tinggi:
#    - Jika customer membeli tomatoes, cereal, bananas, rekomendasikan eggs
#      (Confidence: 100.0%, Lift: 5.67)
#    - Jika customer membeli eggs, tomatoes, coffee, rekomendasikan potatoes
#      (Confidence: 100.0%, Lift: 5.67)
#    - Jika customer membeli coffee, cereal, bananas, rekomendasikan eggs
#      (Confidence: 100.0%, Lift: 5.67)
#    - Jika customer membeli eggs, cereal, coffee, rekomendasikan cheese
#      (Confidence: 100.0%, Lift: 5.46)
#    - Jika customer membeli coffee, potatoes, cheese, bananas, rekomendasikan eggs
#      (Confidence: 100.0%, Lift: 5.67)
